# %%
import json
import os

# %%
with open('unlabeled.json', 'r') as f:
    unlabeled = json.load(f)

# %%
with open('iters/iter=0/prediction_0.json', 'r') as f:
    pred0 = json.load(f)
with open('iters/iter=0/prediction_1.json', 'r') as f:
    pred1 = json.load(f)

# %%
def convert_to_word_atoms(prediction, model_num):
    all_atoms = []
    for row in prediction:
        atoms = []
        tokens = row['tokens']
        entities = row['entities']
        relations = row['relations']
        for ent in entities:
            c = 'atom({}("{}"), {}).'.format(ent[2].lower(), "+".join(tokens[ent[0]:ent[1]]), model_num)
            atoms.append(c)
        for rel in relations:
            c = 'atom({}("{}", "{}"), {}).'.format(''.join([rel[4].split('_')[0].lower(), *rel[4].split('_')[1:]]), 
                                    "+".join(tokens[rel[0]:rel[1]]), 
                                    "+".join(tokens[rel[2]:rel[3]]), model_num)
            atoms.append(c)
        all_atoms.append(atoms)
    return all_atoms

# %%
all_atoms0 = convert_to_word_atoms(pred0)
all_atoms1 = convert_to_word_atoms(pred1)

# %%
for r in range(4):
    os.makedirs(f'iters_atoms/iter={r}', exist_ok=True)
    with open(f'iters/iter={r}/prediction_0.json', 'r') as f:
        pred0 = json.load(f)
    with open(f'iters/iter={r}/prediction_1.json', 'r') as f:
        pred1 = json.load(f)
    all_atoms0 = convert_to_word_atoms(pred0)
    all_atoms1 = convert_to_word_atoms(pred1)
    with open(f'iters_atoms/iter={r}/all_atoms_0.json', 'w') as f:
        json.dump(all_atoms0, f)
    with open(f'iters_atoms/iter={r}/all_atoms_1.json', 'w') as f:
        json.dump(all_atoms1, f)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-899cbe4b251a> in <module>
#       5     with open(f'iters/iter={r}/prediction_1.json', 'r') as f:
#       6         pred1 = json.load(f)
# ----> 7     all_atoms0 = convert_to_word_atoms(pred0)
#       8     all_atoms1 = convert_to_word_atoms(pred1)
#       9     with open(f'iters_atoms/iter={r}/all_atoms_0.json', 'w') as f:
#
# TypeError: convert_to_word_atoms() missing 1 required positional argument: 'model_num'

# %%
import shutil

if os.path.exists('iters_atoms'):
    shutil.rmtree('iters_atoms')
for r in range(4):
    os.makedirs(f'iters_atoms/iter={r}', exist_ok=True)
    with open(f'iters/iter={r}/prediction_0.json', 'r') as f:
        pred0 = json.load(f)
    with open(f'iters/iter={r}/prediction_1.json', 'r') as f:
        pred1 = json.load(f)
    all_atoms0 = convert_to_word_atoms(pred0, model_num=1)
    all_atoms1 = convert_to_word_atoms(pred1, model_num=2)
    
    for i, (atoms0, atoms1) in enumerate(zip(all_atoms0, all_atoms1)):
        with open(f'iters_atoms/iter={r}/{i}.1.txt', 'w') as f:
            f.writelines(map(lambda x: x+'\n', atoms0))
        with open(f'iters_atoms/iter={r}/{i}.2.txt', 'w') as f:
            f.writelines(map(lambda x: x+'\n', atoms1))

# %%
match_idx = []
unmatch_idx = []
for i, (atoms0, atoms1) in enumerate(zip(all_atoms0, all_atoms1)):
    if set(atoms0) == set(atoms1):
        match_idx.append(i)
    else:
        unmatch_idx.append(i)

# %%
len(match_idx)
# Out:
# 242

# %%
len(all_atoms0)
# Out:
# 646

# %%
incorrect_idx = []
for i in match_idx:
    pred = [tuple(e) for e in pred0[i]['entities']]
    gt = pred0[i]['entity_gts']
    gt = [tuple(e[:3]) for e in gt]
    if set(pred) != set(gt):
        incorrect_idx.append(i)

# %%
len(incorrect_idx)
# Out:
# 64

# %%
pred0[48]
# Out:
# {'tokens': ['`',
#   '`',
#   'Please',
#   'don',
#   "'t",
#   'execute',
#   'him',
#   ',',
#   'please',
#   ',',
#   "'",
#   "'",
#   'said',
#   'Mrs.',
#   'Cicippio',
#   ',',
#   'who',
#   'works',
#   'at',
#   'the',
#   'American',
#   'Embassy',
#   'in',
#   'east',
#   'Beirut.'],
#  'entities': [[13, 15, 'Peop'], [20, 22, 'Org'], [24, 25, 'Loc']],
#  'relations': [[20, 22, 24, 25, 'OrgBased_In'],
#   [13, 15, 20, 22, 'Work_For'],
#   [13, 15, 24, 25, 'Live_In']],
#  'entity_gts': [[13, 15, 'Peop', 'Mrs. Cicippio'],
#   [20, 22, 'Loc', 'American Embassy'],
#   [24, 25, 'Loc', 'Beirut.']],
#  'relation_gts': [[13, 15, 24, 25, 'Live_In', 'Mrs. Cicippio', 'Beirut.'],
#   [20, 22, 24, 25, 'Located_In', 'American Embassy', 'Beirut.']],
#  'entities_': [[13, 15, 'Peop', 'Mrs. Cicippio', [1.0, 1.0]],
#   [20, 22, 'Org', 'American Embassy', [0.9951382279396057, 1.0]],
#   [24, 25, 'Loc', 'Beirut.', [1.0]]],
#  'relations_': [[20,
#    22,
#    24,
#    25,
#    'OrgBased_In',
#    'American Embassy',
#    'Beirut.',
#    [[0.9809473752975464], [0.9999958276748657]]],
#   [13,
#    15,
#    20,
#    22,
#    'Work_For',
#    'Mrs. Cicippio',
#    'American Embassy',
#    [[0.9999998807907104, 0.8422638177871704],
#     [0.9998775720596313, 0.999680757522583]]],
#   [13,
#    15,
#    24,
#    25,
#    'Live_In',
#    'Mrs. Cicippio',
#    'Beirut.',
#    [[0.8807289600372314], [0.5289496183395386]]]],
#  'agg_probs': 0.5289496183395386}

# %%
k = 642
print('entities: ', pred0[k]['entity_gts'])
print('==========================')
print('relations: ', pred0[k]['relation_gts'])
# Out:
# entities:  [[0, 1, 'Other', 'An-a-one'], [18, 20, 'Peop', 'Lawrence Welk'], [21, 23, 'Loc', 'North Dakota'], [34, 35, 'Org', 'Congress']]
# ==========================
# relations:  [[18, 20, 21, 23, 'Live_In', 'Lawrence Welk', 'North Dakota']]

# %%
17 / len(incorrect_idx)
# Out:
# 0.265625

# %%
interesting_cases = [1, 2, 34, 75]

# %%
for i, idx in enumerate(incorrect_idx):
    print(idx, all_atoms0[idx])
# Out:
# 4 ['Peop(John Wilkes Booth)', 'Peop(Abraham Lincoln)', 'Kill(John Wilkes Booth, Abraham Lincoln)']
# 44 ['Loc(U.S.)', 'Peop(Marvin Feuerwerger)', 'Org(Washington Institute)', 'Org(Near East Policy)', 'Work_For(Marvin Feuerwerger, Near East Policy)', 'Work_For(Marvin Feuerwerger, Washington Institute)']
# 48 ['Peop(Mrs. Cicippio)', 'Org(American Embassy)', 'Loc(Beirut.)', 'OrgBased_In(American Embassy, Beirut.)', 'Work_For(Mrs. Cicippio, American Embassy)', 'Live_In(Mrs. Cicippio, Beirut.)']
# 54 ['Peop(William Leonard Jennings)', 'Loc(Yorkshire)', 'Peop(Stephen)', 'Other(Dec.)']
# 62 ['Other(80 mph)', 'Loc(Covington)', 'Loc(Okla.)', 'Located_In(Covington, Okla.)']
# 70 ['Other(Jan.)', 'Peop(Elvis Presley)', 'Loc(Tupelo , Miss)', 'Live_In(Elvis Presley, Tupelo , Miss)']
# 87 ['Peop(Birand)', 'Loc(Germany)']
# 93 ['Peop(Emily Dickinson)', 'Loc(Amherst , Mass .)', 'Live_In(Emily Dickinson, Amherst , Mass .)']
# 126 ['Loc(Modesto)', 'Peop(George Lucas)', 'Live_In(George Lucas, Modesto)']
# 129 ['Peop(Sevket Kazan)', 'Org(Welfare Party)', 'Work_For(Sevket Kazan, Welfare Party)']
# 133 ['Peop(David Peterson)', 'Org(Connecticut Valley Hospital)', 'Loc(Middletown)', 'OrgBased_In(Connecticut Valley Hospital, Middletown)', 'Work_For(David Peterson, Connecticut Valley Hospital)']
# 148 ['Peop(Mr. Vishnu Hari Dalmia)']
# 167 ['Loc(Portland)', 'Loc(Maine)', 'Other(11 fair ;)', 'Located_In(Portland, Maine)']
# 180 ['Loc(Heuchelheim)', 'Other(Jan.)']
# 182 ['Loc(Hefei)', 'Other(February 11)', 'Org(XINHUA)', 'Loc(Anhui)', 'OrgBased_In(XINHUA, Hefei)']
# 196 ['Peop(Ciacelli)', 'Loc(Dallas County Historical Association)', 'Peop(Lee Harvey Oswald)', 'Peop(Kennedy)', 'Kill(Lee Harvey Oswald, Kennedy)']
# 211 ['Loc(Athens)', 'Org(KATHIMERINI)', 'OrgBased_In(KATHIMERINI, Athens)']
# 224 ['Other(200 acres)', 'Loc(Orange County)', 'Org(county Fire Department)', 'Peop(Hugh Madlock)', 'Work_For(Hugh Madlock, county Fire Department)']
# 229 ['Peop(Dole)', 'Loc(North Carolina)', 'Peop(Elizabeth.)', 'Live_In(Dole, North Carolina)']
# 242 ['Peop(Antonio Vasquez Ochoa)', 'Peop(John Walker)', 'Peop(Alberto Radelat)', 'Other(Jan. 30)', 'Loc(Guadalajara)']
# 251 ['Peop(Martin Luther King Jr.)', 'Peop(James Earl Ray)', 'Kill(James Earl Ray, Martin Luther King Jr.)']
# 259 ['Other(March)', 'Peop(Miss Bickel)', 'Loc(Tempe)', 'Peop(Richard Pavese)', 'Live_In(Miss Bickel, Tempe)', 'Live_In(Richard Pavese, Tempe)']
# 265 ['Peop(Sanders)', 'Peop(Daniel Dewey)', 'Org(CBOT)', 'Org(Treasury)', 'Work_For(Daniel Dewey, CBOT)']
# 272 ['Peop(Emily Dickinson)', 'Loc(Amherst , Mass .)', 'Live_In(Emily Dickinson, Amherst , Mass .)']
# 277 ['Loc(Greenville)', 'Loc(S.C.)', 'Peop(Jesse Jackson)', 'Located_In(Greenville, S.C.)']
# 278 ['Loc(Brazil)', 'Org(Brazilian Space Program)', 'Loc(Sao Paulo)', 'Org(GAZETA MERCANTIL)', 'Other(27-29 Nov 93)', 'OrgBased_In(GAZETA MERCANTIL, Sao Paulo)', 'OrgBased_In(Brazilian Space Program, Brazil)', 'OrgBased_In(GAZETA MERCANTIL, Brazil)', 'OrgBased_In(Brazilian Space Program, Sao Paulo)']
# 293 ['Loc(United States)', 'Other(34 percent)', 'Org(FBI)']
# 317 ['Loc(Shanghai)', 'Loc(San Francisco)', 'Loc(Shanghai)', 'Loc(United States.)']
# 319 ['Peop(Edward M. Kennedy)', 'Loc(Dallas)', 'Peop(Lee Harvey Oswald)', 'Peop(President John F. Kennedy)', 'Kill(Lee Harvey Oswald, President John F. Kennedy)']
# 328 ['Peop(Charles McC.)']
# 331 ['Loc(Rochester)', 'Peop(Peter McWalters)', 'Live_In(Peter McWalters, Rochester)']
# 332 ['Loc(Argentina)', 'Other(31 million)', 'Loc(Buenos Aires)', 'Peop(Antonio Cafiero.)']
# 355 ['Peop(King)', 'Peop(James Earl Ray)', 'Other(April)', 'Kill(James Earl Ray, King)']
# 383 ['Peop(An Wang)', 'Loc(Shanghai)', 'Loc(China)', 'Live_In(An Wang, China)', 'Located_In(Shanghai, China)', 'Live_In(An Wang, Shanghai)']
# 389 ['Peop(Booth)', 'Peop(Lincoln)', 'Other(10 : 15 p.m.)', 'Other(April)', 'Kill(Booth, Lincoln)']
# 399 ['Loc(Cairo)', 'Other(2 May)', 'Org(MENA)', 'Peop(Husni Mubarak)', 'Loc(Egypt)', 'Live_In(Husni Mubarak, Egypt)', 'OrgBased_In(MENA, Cairo)']
# 405 ['Loc(U.S. Bankruptcy)', 'Peop(Harold Abramson)', 'Peop(William Herbert)', 'Peop(Nancy Hunt)']
# 415 ['Org(CIA)', 'Peop(Sohn Ho Young)', 'Loc(New York City)', 'Work_For(Sohn Ho Young, CIA)']
# 416 ['Other(15 March)', 'Other(15 March 1994)', 'Loc(Mexico)', 'Loc(San Cristobal)']
# 426 ['Loc(Texas Theater)', 'Peop(Lee Harvey Oswald)', 'Peop(President Kennedy)', 'Kill(Lee Harvey Oswald, President Kennedy)']
# 429 ['Other($2.3 million)', 'Peop(Lee Harvey Oswald)', 'Peop(Kennedy)', 'Other(Nov.)', 'Kill(Lee Harvey Oswald, Kennedy)']
# 431 ['Other(33 degrees)', 'Loc(Truckee)', 'Loc(Calif.)', 'Located_In(Truckee, Calif.)']
# 433 ['Other(Jan.)', 'Peop(Elvis Presley)', 'Loc(Tupelo , Miss)', 'Live_In(Elvis Presley, Tupelo , Miss)']
# 437 ['Org(Associated Press bureau)', 'Loc(Beirut)', 'OrgBased_In(Associated Press bureau, Beirut)']
# 457 ['Loc(Pittsburgh)', 'Peop(Richard C. Wallace)', 'Live_In(Richard C. Wallace, Pittsburgh)']
# 506 ['Peop(Lennon)', 'Loc(West Side)', 'Other(Dec.)', 'Peop(Mark David Chapman)', 'Kill(Mark David Chapman, Lennon)']
# 533 ['Org(FAA)', 'Peop(Fred Farrar)', 'Org(British Midland)', 'Work_For(Fred Farrar, FAA)']
# 540 ['Peop(Herschel Grynszpan)', 'Loc(Poland)', 'Peop(Ernst vom Rath)', 'Loc(Paris)', 'Other(Nov.)']
# 542 ['Peop(Allen Harker)', 'Org(Coast Guard)', 'Work_For(Allen Harker, Coast Guard)']
# 544 ['Peop(Sirhan Bishara Sirhan)', 'Peop(Kennedy)', 'Other(June 5)', 'Kill(Sirhan Bishara Sirhan, Kennedy)']
# 547 ['Loc(ROCK HILL)', 'Loc(S.C .)', 'Located_In(ROCK HILL, S.C .)']
# 549 ['Loc(America)', 'Other(Statue)', 'Other(June 5)']
# 553 ['Peop(Quayles)', 'Peop(Tucker)', 'Peop(Benjamin)', 'Peop(Corinne)', 'Org(Naval Observatory)', 'Loc(Washington)', 'OrgBased_In(Naval Observatory, Washington)']
# 554 ['Org(GSA Depot)', 'Loc(Watertown)', 'Loc(Mass.)', 'OrgBased_In(GSA Depot, Mass.)', 'Located_In(Watertown, Mass.)', 'OrgBased_In(GSA Depot, Watertown)']
# 559 ['Org(Foreign Ministry)', 'Loc(Beijing)', 'Peop(Li Zhaoxing)', 'Loc(China)', 'Loc(Vietnam)', 'OrgBased_In(Foreign Ministry, Beijing)', 'Live_In(Li Zhaoxing, China)']
# 570 ['Peop(George Eastman)', 'Loc(Waterville , N. Y.)', 'Live_In(George Eastman, Waterville , N. Y.)']
# 578 ['Peop(Bossi)', 'Peop(Fini)', 'Loc(Italy)', 'Peop(Minoli)', 'Peop(Benito Mussolini)', 'Peop(Fini)', 'Loc(Italy)', 'Live_In(Fini, Italy)']
# 590 ['Other(University)', 'Loc(Texas)', 'Peop(Wright)', 'Peop(Nixon)']
# 594 ['Loc(Texas)', 'Peop(President Nixon)', 'Loc(U.S.)']
# 632 ['Peop(Edward Roybal)', 'Org(House)', 'Peop(Mrs. Quayle)', 'Work_For(Edward Roybal, House)']
# 634 ['Loc(Texas Theater)', 'Loc(Dallas)', 'Peop(Lee Harvey Oswald)', 'Peop(President John F. Kennedy)', 'Kill(Lee Harvey Oswald, President John F. Kennedy)']
# 635 ['Loc(Washington)', 'Loc(U.S.)', 'Loc(Pyongyang)']
# 641 ['Peop(Mark David Chapman)', 'Peop(John Lennon)', 'Peop(Ono)', 'Kill(Mark David Chapman, John Lennon)']
# 642 ['Peop(Lawrence Welk)', 'Loc(North Dakota)', 'Org(Congress)', 'Live_In(Lawrence Welk, North Dakota)']

# %%
for i, idx in enumerate(unmatch_idx):
    print(idx, all_atoms0[idx])
    print(idx, all_atoms1[idx])
    print('=======================================')
# Out:
# 0 ['atom(peop("Annie+Oakley")).', 'atom(peop("Phoebe+Ann+Moses")).', 'atom(loc("Willowdell+,+Darke+County")).', 'atom(liveIn("Phoebe+Ann+Moses", "Willowdell+,+Darke+County")).']
# 0 ['atom(peop("Annie+Oakley")).', 'atom(peop("Phoebe+Ann+Moses")).', 'atom(loc("Willowdell")).', 'atom(loc("Darke+County")).', 'atom(liveIn("Phoebe+Ann+Moses", "Darke+County")).', 'atom(liveIn("Phoebe+Ann+Moses", "Willowdell")).', 'atom(liveIn("Annie+Oakley", "Willowdell")).']
# =======================================
# 1 ['atom(loc("Anhui")).', 'atom(loc("Beijing")).', 'atom(org("XINHUA")).', 'atom(other("1313+GMT")).', 'atom(other("11+Feb+94")).', 'atom(orgbasedIn("XINHUA", "Anhui")).', 'atom(orgbasedIn("XINHUA", "Beijing")).']
# 1 ['atom(loc("Beijing")).', 'atom(org("XINHUA")).', 'atom(other("1313+GMT")).', 'atom(other("11+Feb+94")).', 'atom(orgbasedIn("XINHUA", "Beijing")).']
# =======================================
# 2 ['atom(peop("Shi+Liming")).', 'atom(org("Institute+of+Zoology")).', 'atom(loc("Kunming")).', 'atom(liveIn("Shi+Liming", "Kunming")).', 'atom(workFor("Shi+Liming", "Institute+of+Zoology")).', 'atom(orgbasedIn("Institute+of+Zoology", "Kunming")).']
# 2 ['atom(peop("Shi+Liming")).', 'atom(loc("Kunming")).', 'atom(liveIn("Shi+Liming", "Kunming")).']
# =======================================
# 3 ['atom(peop("Lucille+Ball")).', 'atom(other("Aug.")).', 'atom(loc("Jamestown+N.Y.")).', 'atom(peop("Desiree+Ball.")).', 'atom(liveIn("Desiree+Ball.", "Jamestown+N.Y.")).', 'atom(liveIn("Lucille+Ball", "Jamestown+N.Y.")).']
# 3 ['atom(peop("Lucille+Ball")).', 'atom(other("Aug.")).', 'atom(loc("Jamestown+N.Y.")).', 'atom(peop("Desiree+Ball.")).', 'atom(liveIn("Lucille+Ball", "Jamestown+N.Y.")).']
# =======================================
# 5 ['atom(peop("Kennedy")).', 'atom(peop("Oswald")).', 'atom(peop("President+Kennedy")).', 'atom(peop("Officer+Tippit")).', 'atom(peop("Earl+Warren")).', 'atom(org("Warren+Commission.")).', 'atom(kill("Oswald", "President+Kennedy")).', 'atom(kill("Oswald", "Officer+Tippit")).']
# 5 ['atom(peop("Kennedy")).', 'atom(peop("Oswald")).', 'atom(peop("President+Kennedy")).', 'atom(peop("Tippit")).', 'atom(peop("Earl+Warren")).', 'atom(org("Warren+Commission.")).', 'atom(kill("Oswald", "President+Kennedy")).', 'atom(kill("Tippit", "President+Kennedy")).']
# =======================================
# 6 ['atom(peop("Bob+Boyd")).', 'atom(loc("Chattanooga")).', 'atom(other("35+years")).', 'atom(liveIn("Bob+Boyd", "Chattanooga")).']
# 6 ['atom(peop("Bob+Boyd")).', 'atom(loc("Chattanooga")).', 'atom(loc("Tenn.")).', 'atom(other("35")).', 'atom(liveIn("Bob+Boyd", "Tenn.")).', 'atom(liveIn("Bob+Boyd", "Chattanooga")).', 'atom(locatedIn("Chattanooga", "Tenn.")).']
# =======================================
# 7 ['atom(org("Harvard")).', 'atom(peop("_Ronald")).', 'atom(loc("U.S.")).']
# 7 ['atom(org("State+Department")).', 'atom(org("Harvard")).', 'atom(peop("_Ronald")).', 'atom(loc("U.S.")).', 'atom(workFor("_Ronald", "State+Department")).', 'atom(liveIn("_Ronald", "U.S.")).']
# =======================================
# 11 ['atom(loc("Beijing")).', 'atom(org("XINHUA+Domestic+Service")).', 'atom(other("1149+GMT")).', 'atom(other("29+Apr+94")).', 'atom(orgbasedIn("XINHUA+Domestic+Service", "Beijing")).']
# 11 ['atom(loc("Beijing")).', 'atom(org("XINHUA")).', 'atom(other("1149+GMT")).', 'atom(other("29+Apr+94")).', 'atom(orgbasedIn("XINHUA", "Beijing")).']
# =======================================
# 12 ['atom(loc("Santa")).', 'atom(other("100+mph")).', 'atom(loc("Southern+California")).']
# 12 ['atom(loc("Santa+Ana")).', 'atom(other("100+mph")).', 'atom(loc("Southern+California")).', 'atom(locatedIn("Santa+Ana", "Southern+California")).']
# =======================================
# 13 ['atom(peop("President+James+Garfield")).', 'atom(peop("Charles+Guiteau")).', 'atom(peop("Jonathan+Hadary")).', 'atom(kill("Charles+Guiteau", "President+James+Garfield")).', 'atom(kill("Jonathan+Hadary", "President+James+Garfield")).']
# 13 ['atom(peop("James+Garfield")).', 'atom(peop("Charles+Guiteau")).', 'atom(peop("Jonathan+Hadary")).', 'atom(kill("Jonathan+Hadary", "James+Garfield")).', 'atom(kill("Charles+Guiteau", "James+Garfield")).']
# =======================================
# 14 ['atom(loc("SPACE+CENTER")).', 'atom(loc("Houston")).', 'atom(org("AP")).', 'atom(orgbasedIn("AP", "Houston")).', 'atom(orgbasedIn("AP", "SPACE+CENTER")).', 'atom(locatedIn("SPACE+CENTER", "Houston")).']
# 14 ['atom(loc("SPACE+CENTER")).', 'atom(loc("Houston")).', 'atom(org("AP")).', 'atom(locatedIn("SPACE+CENTER", "Houston")).']
# =======================================
# 15 ['atom(peop("Woodrow+Wilson")).', 'atom(other("Dec.")).', 'atom(loc("Staunton+,+Va")).', 'atom(liveIn("Woodrow+Wilson", "Staunton+,+Va")).']
# 15 ['atom(peop("Woodrow+Wilson")).', 'atom(loc("President")).', 'atom(other("Dec.")).', 'atom(other("or+29")).', 'atom(loc("Staunton+,+Va")).', 'atom(liveIn("Woodrow+Wilson", "Staunton+,+Va")).']
# =======================================
# 16 ['atom(peop("Peter+Butler")).', 'atom(other("A.+Copeland+Enterprises+Inc.")).', 'atom(loc("New")).', 'atom(org("Popeyes")).', 'atom(peop("Henry+A.+Politz")).', 'atom(loc("U.S.+Circuit+Court")).', 'atom(orgbasedIn("Popeyes", "New")).']
# 16 ['atom(peop("Peter+Butler")).', 'atom(other("A.+Copeland+Enterprises+Inc.")).', 'atom(loc("New")).', 'atom(peop("Henry+A.+Politz")).', 'atom(loc("U.S.+Circuit+Court")).', 'atom(workFor("Henry+A.+Politz", "U.S.+Circuit+Court")).', 'atom(workFor("Peter+Butler", "A.+Copeland+Enterprises+Inc.")).']
# =======================================
# 17 ['atom(loc("PURCHASE")).', 'atom(loc("N.Y+.")).', 'atom(locatedIn("PURCHASE", "N.Y+.")).']
# 17 ['atom(loc("PURCHASE")).', 'atom(loc("N.Y")).', 'atom(locatedIn("PURCHASE", "N.Y")).']
# =======================================
# 18 ['atom(loc("United+States")).', 'atom(org("Martin+Van+Buren")).', 'atom(loc("Kinderhook+,+N.Y.")).', 'atom(peop("Wolfgang+Amadeus+Mozart")).', 'atom(loc("Vienna+,+Austria")).', 'atom(liveIn("Martin+Van+Buren", "Kinderhook+,+N.Y.")).', 'atom(liveIn("Wolfgang+Amadeus+Mozart", "Vienna+,+Austria")).']
# 18 ['atom(loc("United+States")).', 'atom(peop("Martin+Van+Buren")).', 'atom(loc("Kinderhook+,+N.Y.")).', 'atom(peop("Wolfgang+Amadeus+Mozart")).', 'atom(loc("Vienna")).', 'atom(loc("Austria")).', 'atom(liveIn("Wolfgang+Amadeus+Mozart", "Vienna")).', 'atom(liveIn("Martin+Van+Buren", "Kinderhook+,+N.Y.")).']
# =======================================
# 19 ['atom(org("U.S.+Coast+Guard+Training+Center")).', 'atom(loc("Petaluma")).', 'atom(loc("Calif.")).', 'atom(orgbasedIn("U.S.+Coast+Guard+Training+Center", "Petaluma")).', 'atom(locatedIn("Petaluma", "Calif.")).', 'atom(orgbasedIn("U.S.+Coast+Guard+Training+Center", "Calif.")).']
# 19 ['atom(loc("U.S.")).', 'atom(org("Coast+Guard")).', 'atom(loc("Training+Center")).', 'atom(loc("Petaluma")).', 'atom(loc("Calif.")).', 'atom(locatedIn("U.S.", "Calif.")).', 'atom(orgbasedIn("Coast+Guard", "Petaluma")).', 'atom(locatedIn("Training+Center", "Petaluma")).', 'atom(locatedIn("Petaluma", "Calif.")).', 'atom(locatedIn("U.S.", "Petaluma")).', 'atom(orgbasedIn("Coast+Guard", "Calif.")).', 'atom(locatedIn("Training+Center", "Calif.")).']
# =======================================
# 20 ['atom(peop("Vyacheslav+Chornovil")).', 'atom(org("Ukrainian+Popular")).', 'atom(other("26+June")).', 'atom(other(",+1994")).', 'atom(org("INTERFAX-Ukraine")).', 'atom(workFor("Vyacheslav+Chornovil", "Ukrainian+Popular")).']
# 20 ['atom(peop("Vyacheslav+Chornovil")).', 'atom(other("26+June+,+1994")).']
# =======================================
# 21 ['atom(peop("Slavko+Mestrovic")).', 'atom(org("Croatian+People+\'s+Party")).', 'atom(loc("Croatian")).', 'atom(workFor("Slavko+Mestrovic", "Croatian+People+\'s+Party")).']
# 21 ['atom(peop("Slavko+Mestrovic")).', 'atom(org("Croatian+People+\'s+Party")).', 'atom(workFor("Slavko+Mestrovic", "Croatian+People+\'s+Party")).']
# =======================================
# 22 ['atom(org("CDT")).', 'atom(loc("Port+Arther")).', 'atom(loc("Galveston")).', 'atom(loc("Texas.")).', 'atom(locatedIn("Galveston", "Texas.")).', 'atom(locatedIn("Port+Arther", "Texas.")).', 'atom(orgbasedIn("CDT", "Texas.")).']
# 22 ['atom(loc("Port+Arther")).', 'atom(loc("Galveston")).', 'atom(loc("Texas.")).', 'atom(locatedIn("Port+Arther", "Texas.")).', 'atom(locatedIn("Galveston", "Texas.")).']
# =======================================
# 23 ['atom(peop("George+Tompkins")).', 'atom(loc("Soviet")).', 'atom(other("hundreds")).', 'atom(liveIn("George+Tompkins", "Soviet")).']
# 23 ['atom(peop("George+Tompkins")).', 'atom(loc("Soviet")).', 'atom(loc("Russian")).', 'atom(liveIn("George+Tompkins", "Soviet")).']
# =======================================
# 24 ['atom(peop("Jack+Ruby")).', 'atom(loc("Dallas")).', 'atom(peop("Oswald")).', 'atom(peop("Kennedy")).']
# 24 ['atom(peop("Jack+Ruby")).', 'atom(loc("Dallas")).', 'atom(peop("Oswald")).', 'atom(peop("Kennedy")).', 'atom(kill("Jack+Ruby", "Oswald")).']
# =======================================
# 28 ['atom(org("Environmental+Protection+Agency")).', 'atom(peop("Robin+Woods")).', 'atom(loc("Washington+,+D.C.")).', 'atom(peop("Woods")).', 'atom(liveIn("Robin+Woods", "Washington+,+D.C.")).']
# 28 ['atom(org("Environmental+Protection+Agency")).', 'atom(peop("Robin+Woods")).', 'atom(loc("Washington")).', 'atom(peop("Woods")).']
# =======================================
# 30 ['atom(loc("Cambodia")).', 'atom(loc("Phnom+Penh")).', 'atom(loc("Jakarta")).']
# 30 ['atom(peop("Prince+Ranariddh")).', 'atom(loc("Cambodia")).', 'atom(loc("Phnom+Penh")).', 'atom(loc("Jakarta")).', 'atom(liveIn("Prince+Ranariddh", "Cambodia")).', 'atom(liveIn("Prince+Ranariddh", "Jakarta")).', 'atom(liveIn("Prince+Ranariddh", "Phnom+Penh")).']
# =======================================
# 31 ['atom(peop("Church")).', 'atom(loc("San+Antonio")).', 'atom(liveIn("Church", "San+Antonio")).']
# 31 ['atom(loc("San+Antonio")).']
# =======================================
# 34 ['atom(org("GSA+Depot")).', 'atom(loc("Davisville")).', 'atom(loc("R.I.")).', 'atom(loc("Mineral+Wells")).', 'atom(loc("Texas")).', 'atom(locatedIn("Mineral+Wells", "Texas")).', 'atom(orgbasedIn("GSA+Depot", "R.I.")).', 'atom(locatedIn("Davisville", "R.I.")).', 'atom(orgbasedIn("GSA+Depot", "Davisville")).']
# 34 ['atom(org("GSA+Depot")).', 'atom(loc("Davisville")).', 'atom(loc("R.I.")).', 'atom(loc("Mineral+Wells")).', 'atom(loc("Texas")).', 'atom(orgbasedIn("GSA+Depot", "Davisville")).', 'atom(locatedIn("GSA+Depot", "R.I.")).', 'atom(locatedIn("Mineral+Wells", "Texas")).', 'atom(locatedIn("Davisville", "R.I.")).']
# =======================================
# 35 ['atom(peop("Kennedy")).', 'atom(loc("California")).', 'atom(peop("Sirhan")).', 'atom(loc("Los+Angeles")).', 'atom(other("June+5")).', 'atom(kill("Sirhan", "Kennedy")).']
# 35 ['atom(peop("Kennedy")).', 'atom(loc("California")).', 'atom(peop("Sirhan")).', 'atom(loc("Los+Angeles")).', 'atom(other("June+5+,")).', 'atom(liveIn("Kennedy", "California")).', 'atom(kill("Sirhan", "Kennedy")).']
# =======================================
# 36 ['atom(peop("Dan+Quayle")).', 'atom(loc("Caracas")).', 'atom(loc("Venezuela")).', 'atom(peop("Carlos+Andres+Perez")).', 'atom(other("Feb.")).']
# 36 ['atom(peop("Dan+Quayle")).', 'atom(loc("Caracas")).', 'atom(loc("Venezuela")).', 'atom(peop("Carlos+Andres+Perez")).', 'atom(other("Feb.")).', 'atom(peop("Bush")).', 'atom(locatedIn("Caracas", "Venezuela")).', 'atom(liveIn("Carlos+Andres+Perez", "Venezuela")).']
# =======================================
# 38 ['atom(other("University")).', 'atom(loc("Nsukka")).', 'atom(peop("U.+Umeh")).', 'atom(orgbasedIn("University", "Nsukka")).']
# 38 ['atom(other("University")).', 'atom(loc("Nigeria")).', 'atom(loc("Nsukka")).', 'atom(peop("U.+Umeh")).', 'atom(workFor("U.+Umeh", "University")).', 'atom(locatedIn("Nsukka", "Nigeria")).', 'atom(orgbasedIn("University", "Nsukka")).', 'atom(liveIn("U.+Umeh", "Nsukka")).']
# =======================================
# 39 ['atom(loc("Colorado")).', 'atom(loc("Denver")).']
# 39 ['atom(loc("Colorado")).', 'atom(other("13+inches")).', 'atom(loc("Denver")).']
# =======================================
# 42 ['atom(peop("Aleksandr+Kruhlow")).', 'atom(loc("Sevastopol")).', 'atom(peop("Nakhimov+Square")).', 'atom(loc("Sevastopol")).', 'atom(loc("Crimea")).', 'atom(loc("Russia")).', 'atom(locatedIn("Crimea", "Russia")).', 'atom(liveIn("Aleksandr+Kruhlow", "Sevastopol")).', 'atom(locatedIn("Sevastopol", "Russia")).']
# 42 ['atom(peop("Aleksandr+Kruhlow")).', 'atom(loc("Sevastopol")).', 'atom(loc("Nakhimov+Square")).', 'atom(loc("Crimea")).', 'atom(loc("Russia")).', 'atom(liveIn("Aleksandr+Kruhlow", "Sevastopol")).', 'atom(locatedIn("Crimea", "Russia")).']
# =======================================
# 45 ['atom(loc("St.+Petersburg")).', 'atom(org("Atomenergoproekt+institute")).', 'atom(orgbasedIn("Atomenergoproekt+institute", "St.+Petersburg")).']
# 45 ['atom(loc("St.+Petersburg")).']
# =======================================
# 46 ['atom(peop("Wright")).', 'atom(peop("Barry+Goldwater")).', 'atom(loc("Arizona")).', 'atom(liveIn("Barry+Goldwater", "Arizona")).']
# 46 ['atom(peop("Wright")).', 'atom(peop("Barry+Goldwater")).', 'atom(loc("Arizona")).', 'atom(liveIn("Barry+Goldwater", "Arizona")).', 'atom(kill("Wright", "Barry+Goldwater")).']
# =======================================
# 50 ['atom(loc("BELGRADE")).', 'atom(loc("Yugoslavia")).', 'atom(org("AP")).', 'atom(locatedIn("BELGRADE", "Yugoslavia")).', 'atom(orgbasedIn("AP", "Yugoslavia")).', 'atom(orgbasedIn("AP", "BELGRADE")).']
# 50 ['atom(loc("BELGRADE")).', 'atom(loc("Yugoslavia")).', 'atom(org("AP")).', 'atom(locatedIn("BELGRADE", "Yugoslavia")).']
# =======================================
# 51 ['atom(loc("Placerville")).', 'atom(peop("Kenneth+Earl+Millikan")).', 'atom(org("Bay+Area+Rapid+Transit+District")).', 'atom(peop("Peter+J.+Martinelli")).', 'atom(org("BART")).', 'atom(peop("Nello+Bianco.")).', 'atom(workFor("Peter+J.+Martinelli", "BART")).', 'atom(workFor("Nello+Bianco.", "BART")).']
# 51 ['atom(loc("Placerville")).', 'atom(peop("Kenneth+Earl+Millikan")).', 'atom(org("Bay+Area+Rapid+Transit+District")).', 'atom(peop("Peter+J.+Martinelli")).', 'atom(org("BART")).', 'atom(peop("Nello+Bianco.")).', 'atom(workFor("Peter+J.+Martinelli", "Bay+Area+Rapid+Transit+District")).', 'atom(workFor("Peter+J.+Martinelli", "BART")).', 'atom(workFor("Nello+Bianco.", "BART")).', 'atom(workFor("Kenneth+Earl+Millikan", "Bay+Area+Rapid+Transit+District")).', 'atom(liveIn("Kenneth+Earl+Millikan", "Placerville")).']
# =======================================
# 53 ['atom(loc("Modesto")).', 'atom(peop("George+Lucas")).', 'atom(other("15+years")).', 'atom(liveIn("George+Lucas", "Modesto")).']
# 53 ['atom(loc("Modesto")).', 'atom(peop("George+Lucas")).', 'atom(other("15")).', 'atom(liveIn("George+Lucas", "Modesto")).']
# =======================================
# 55 ['atom(peop("John+Lennon")).', 'atom(peop("Chapman")).', 'atom(loc("Attica+state+prison")).', 'atom(other("20+years")).']
# 55 ['atom(peop("John+Lennon")).', 'atom(peop("Chapman")).', 'atom(loc("Attica+state")).', 'atom(liveIn("Chapman", "Attica+state")).']
# =======================================
# 56 ['atom(loc("STOCKTON-ON-TEES")).', 'atom(loc("England")).', 'atom(org("AP")).', 'atom(peop("Michael+Minns")).', 'atom(other("$160+,+000")).', 'atom(other("World+War+II")).', 'atom(locatedIn("STOCKTON-ON-TEES", "England")).', 'atom(orgbasedIn("AP", "England")).', 'atom(orgbasedIn("AP", "STOCKTON-ON-TEES")).']
# 56 ['atom(loc("STOCKTON-ON-TEES")).', 'atom(loc("England")).', 'atom(org("AP")).', 'atom(peop("Michael+Minns")).', 'atom(locatedIn("STOCKTON-ON-TEES", "England")).', 'atom(orgbasedIn("AP", "STOCKTON-ON-TEES")).', 'atom(liveIn("Michael+Minns", "STOCKTON-ON-TEES")).']
# =======================================
# 58 ['atom(peop("Lee")).', 'atom(other("Army")).', 'atom(peop("Booth")).', 'atom(peop("Lincoln")).', 'atom(peop("Tidwell")).', 'atom(org("CIA")).', 'atom(kill("Booth", "Lincoln")).', 'atom(workFor("Tidwell", "CIA")).']
# 58 ['atom(peop("Lee")).', 'atom(other("Army")).', 'atom(loc("Northern+Virginia")).', 'atom(peop("Booth")).', 'atom(peop("Lincoln")).', 'atom(peop("Tidwell")).', 'atom(org("CIA")).', 'atom(kill("Booth", "Lincoln")).', 'atom(kill("Tidwell", "Lincoln")).', 'atom(workFor("Tidwell", "CIA")).', 'atom(liveIn("Lee", "Northern+Virginia")).', 'atom(kill("Lee", "Lincoln")).']
# =======================================
# 60 ['atom(org("Vatican")).', 'atom(loc("Moscow")).', 'atom(org("Roman+Catholic+Church")).', 'atom(loc("Soviet+bloc.")).', 'atom(orgbasedIn("Roman+Catholic+Church", "Moscow")).', 'atom(orgbasedIn("Roman+Catholic+Church", "Soviet+bloc.")).']
# 60 ['atom(loc("Vatican")).', 'atom(loc("Moscow")).', 'atom(org("Roman+Catholic")).', 'atom(loc("Soviet+bloc.")).']
# =======================================
# 61 ['atom(peop("Edgar+Allan+Poe")).', 'atom(loc("Boston")).', 'atom(liveIn("Edgar+Allan+Poe", "Boston")).']
# 61 ['atom(peop("Edgar+Allan+Poe")).', 'atom(loc("Boston+.")).', 'atom(liveIn("Edgar+Allan+Poe", "Boston+.")).']
# =======================================
# 63 ['atom(peop("Michael+Holtcamp")).', 'atom(loc("Huntsville+,+Alabama")).', 'atom(liveIn("Michael+Holtcamp", "Huntsville+,+Alabama")).']
# 63 ['atom(peop("Michael+Holtcamp")).', 'atom(loc("Huntsville")).', 'atom(loc("Alabama")).', 'atom(liveIn("Michael+Holtcamp", "Alabama")).', 'atom(locatedIn("Huntsville", "Alabama")).']
# =======================================
# 64 ['atom(peop("W.+Dale+Nelson")).', 'atom(other("White+House")).', 'atom(org("Associated+Press")).', 'atom(workFor("W.+Dale+Nelson", "Associated+Press")).']
# 64 ['atom(peop("W.+Dale+Nelson")).', 'atom(org("White+House")).', 'atom(org("Associated+Press")).', 'atom(workFor("W.+Dale+Nelson", "White+House")).', 'atom(workFor("W.+Dale+Nelson", "Associated+Press")).']
# =======================================
# 65 ['atom(peop("President+Boris+Yeltsin")).', 'atom(peop("Bill+Clinton")).', 'atom(peop("Lee+Harvey+Oswald")).', 'atom(peop("President+Kennedy")).', 'atom(kill("Lee+Harvey+Oswald", "President+Kennedy")).']
# 65 ['atom(peop("Boris+Yeltsin")).', 'atom(peop("Bill+Clinton")).', 'atom(peop("Lee+Harvey+Oswald")).', 'atom(peop("President+Kennedy")).', 'atom(kill("Lee+Harvey+Oswald", "President+Kennedy")).', 'atom(kill("Boris+Yeltsin", "Bill+Clinton")).']
# =======================================
# 67 ['atom(peop("Ray")).', 'atom(loc("Tennessee")).', 'atom(loc("Brushy+Mountain+State+Prison")).', 'atom(other("April")).', 'atom(peop("King")).', 'atom(liveIn("Ray", "Brushy+Mountain+State+Prison")).', 'atom(locatedIn("Brushy+Mountain+State+Prison", "Tennessee")).', 'atom(liveIn("Ray", "Tennessee")).']
# 67 ['atom(peop("Ray")).', 'atom(loc("Tennessee")).', 'atom(loc("Brushy+Mountain+State")).', 'atom(other("April")).', 'atom(peop("King")).', 'atom(liveIn("Ray", "Tennessee")).', 'atom(kill("Ray", "King")).', 'atom(locatedIn("Brushy+Mountain+State", "Tennessee")).']
# =======================================
# 68 ['atom(org("Pacific+Fleet")).', 'atom(peop("Igor+Khmelnov")).', 'atom(org("Pacific+Fleet+air+wing")).', 'atom(org("Russian+Defence+Ministry")).', 'atom(org("ITAR-TASS")).', 'atom(workFor("Igor+Khmelnov", "Pacific+Fleet")).', 'atom(workFor("Igor+Khmelnov", "Pacific+Fleet+air+wing")).']
# 68 ['atom(org("Pacific+Fleet")).', 'atom(peop("Igor+Khmelnov")).', 'atom(org("Pacific+Fleet")).', 'atom(loc("air")).', 'atom(org("Defence+Ministry")).', 'atom(workFor("Igor+Khmelnov", "Pacific+Fleet")).', 'atom(workFor("Igor+Khmelnov", "Defence+Ministry")).', 'atom(workFor("Igor+Khmelnov", "Pacific+Fleet")).']
# =======================================
# 71 ['atom(loc("ADDIS+ABABA")).', 'atom(loc("Ethiopia")).', 'atom(org("AP")).', 'atom(orgbasedIn("AP", "Ethiopia")).', 'atom(orgbasedIn("AP", "ADDIS+ABABA")).', 'atom(locatedIn("ADDIS+ABABA", "Ethiopia")).']
# 71 ['atom(loc("ADDIS+ABABA")).', 'atom(loc("Ethiopia")).', 'atom(org("AP")).', 'atom(orgbasedIn("AP", "ADDIS+ABABA")).', 'atom(locatedIn("ADDIS+ABABA", "Ethiopia")).']
# =======================================
# 72 ['atom(peop("Robert+F.+Kennedy")).', 'atom(peop("Davis")).', 'atom(peop("Kennedy")).', 'atom(peop("Sirhan+B.+Sirhan")).', 'atom(kill("Sirhan+B.+Sirhan", "Robert+F.+Kennedy")).', 'atom(kill("Sirhan+B.+Sirhan", "Kennedy")).']
# 72 ['atom(peop("Robert+F.+Kennedy")).', 'atom(peop("Davis")).', 'atom(peop("Kennedy")).', 'atom(peop("Sirhan+B.+Sirhan")).', 'atom(kill("Sirhan+B.+Sirhan", "Kennedy")).', 'atom(kill("Davis", "Robert+F.+Kennedy")).', 'atom(kill("Sirhan+B.+Sirhan", "Robert+F.+Kennedy")).']
# =======================================
# 73 ['atom(peop("Leroy+Ivy")).', 'atom(loc("Oxford")).', 'atom(peop("John+Henry+Ivy")).', 'atom(loc("Tupelo")).', 'atom(loc("Lee+County+Circuit")).', 'atom(peop("Thomas+Gardner+III.")).', 'atom(liveIn("John+Henry+Ivy", "Tupelo")).', 'atom(liveIn("Leroy+Ivy", "Oxford")).']
# 73 ['atom(peop("Leroy+Ivy")).', 'atom(loc("Oxford")).', 'atom(peop("John+Henry+Ivy")).', 'atom(loc("Tupelo")).', 'atom(loc("Lee+County+Circuit")).', 'atom(peop("Thomas+Gardner+III.")).', 'atom(liveIn("Leroy+Ivy", "Tupelo")).', 'atom(liveIn("John+Henry+Ivy", "Tupelo")).', 'atom(liveIn("Leroy+Ivy", "Oxford")).']
# =======================================
# 74 ['atom(peop("Madonna")).', 'atom(loc("Bay+City")).', 'atom(loc("Mich.")).', 'atom(liveIn("Madonna", "Mich.")).', 'atom(liveIn("Madonna", "Bay+City")).', 'atom(locatedIn("Bay+City", "Mich.")).']
# 74 ['atom(peop("Madonna")).', 'atom(loc("Bay+City")).', 'atom(loc("Mich.")).', 'atom(loc("lower+peninsula")).', 'atom(locatedIn("Bay+City", "Mich.")).', 'atom(liveIn("Madonna", "Bay+City")).', 'atom(liveIn("Madonna", "Mich.")).']
# =======================================
# 75 ['atom(loc("Cape+Town")).', 'atom(org("Supreme+Court")).', 'atom(peop("J.H.+Berman")).', 'atom(loc("Port+Nolloth")).', 'atom(workFor("J.H.+Berman", "Supreme+Court")).', 'atom(orgbasedIn("Supreme+Court", "Cape+Town")).', 'atom(workFor("J.H.+Berman", "Port+Nolloth")).']
# 75 ['atom(loc("Cape+Town")).', 'atom(org("Supreme+Court")).', 'atom(peop("J.H.+Berman")).', 'atom(loc("Port+Nolloth")).', 'atom(workFor("J.H.+Berman", "Cape+Town")).', 'atom(liveIn("J.H.+Berman", "Port+Nolloth")).', 'atom(workFor("J.H.+Berman", "Supreme+Court")).']
# =======================================
# 78 ['atom(org("Warren+Commission")).', 'atom(peop("Lee+Harvey+Oswald")).', 'atom(peop("Kennedy")).', 'atom(other("Nov.+22")).', 'atom(kill("Lee+Harvey+Oswald", "Kennedy")).']
# 78 ['atom(org("Warren+Commission")).', 'atom(peop("Lee+Harvey+Oswald")).', 'atom(peop("Kennedy")).', 'atom(other("Nov.")).', 'atom(kill("Lee+Harvey+Oswald", "Kennedy")).']
# =======================================
# 79 ['atom(other("24-31+May")).', 'atom(loc("valley")).', 'atom(org("National+Action+Party")).', 'atom(peop("Fernandez+de+Cevallos")).', 'atom(other("42+percent")).', 'atom(workFor("Fernandez+de+Cevallos", "National+Action+Party")).']
# 79 ['atom(other("24-31+May")).', 'atom(loc("valley")).', 'atom(loc("Mexico")).', 'atom(org("National+Action+Party")).', 'atom(peop("Fernandez+de+Cevallos")).', 'atom(other("42+percent")).', 'atom(workFor("Fernandez+de+Cevallos", "National+Action+Party")).']
# =======================================
# 80 ['atom(peop("Anderson")).', 'atom(peop("Peggy+Say")).', 'atom(loc("Batavia")).', 'atom(loc("N.Y.")).', 'atom(liveIn("Peggy+Say", "Batavia")).', 'atom(liveIn("Anderson", "Batavia")).', 'atom(locatedIn("Batavia", "N.Y.")).', 'atom(liveIn("Peggy+Say", "N.Y.")).']
# 80 ['atom(peop("Anderson")).', 'atom(peop("Peggy+Say")).', 'atom(loc("Batavia")).', 'atom(loc("N.Y.")).', 'atom(liveIn("Anderson", "Batavia")).', 'atom(liveIn("Peggy+Say", "N.Y.")).', 'atom(kill("Peggy+Say", "Anderson")).', 'atom(locatedIn("Batavia", "N.Y.")).', 'atom(liveIn("Peggy+Say", "Batavia")).']
# =======================================
# 83 ['atom(other("Ten+years")).', 'atom(peop("James+Earl+Ray")).', 'atom(peop("Martin+Luther+King+Jr.")).', 'atom(peop("Anna+Sandhu")).', 'atom(loc("Brushy+Mountain+Penitentiary")).', 'atom(kill("James+Earl+Ray", "Martin+Luther+King+Jr.")).', 'atom(liveIn("Anna+Sandhu", "Brushy+Mountain+Penitentiary")).']
# 83 ['atom(peop("James+Earl+Ray")).', 'atom(peop("Martin+Luther+King+Jr.")).', 'atom(peop("Anna+Sandhu")).', 'atom(loc("Brushy+Mountain")).', 'atom(loc("Tennessee")).', 'atom(liveIn("Anna+Sandhu", "Tennessee")).', 'atom(locatedIn("Brushy+Mountain", "Tennessee")).', 'atom(kill("James+Earl+Ray", "Martin+Luther+King+Jr.")).', 'atom(liveIn("Anna+Sandhu", "Brushy+Mountain")).']
# =======================================
# 85 ['atom(other("One+hundred+years")).', 'atom(other("Oct.")).', 'atom(peop("Dwight+D.+Eisenhower")).', 'atom(loc("United+States")).', 'atom(loc("Denison+,+Texas")).', 'atom(liveIn("Dwight+D.+Eisenhower", "Denison+,+Texas")).']
# 85 ['atom(other("One")).', 'atom(other("Oct.")).', 'atom(peop("Dwight+D.+Eisenhower")).', 'atom(loc("United+States")).', 'atom(loc("Denison+,")).', 'atom(loc("Texas")).', 'atom(liveIn("Dwight+D.+Eisenhower", "Texas")).', 'atom(liveIn("Dwight+D.+Eisenhower", "Denison+,")).']
# =======================================
# 90 ['atom(loc("Carbondale")).', 'atom(org("Mining+Technology+Center")).', 'atom(loc("Carterville")).', 'atom(loc("Ill.")).', 'atom(locatedIn("Carbondale", "Ill.")).', 'atom(orgbasedIn("Mining+Technology+Center", "Ill.")).', 'atom(orgbasedIn("Mining+Technology+Center", "Carterville")).', 'atom(locatedIn("Carbondale", "Carterville")).', 'atom(locatedIn("Carterville", "Ill.")).']
# 90 ['atom(loc("Carbondale")).', 'atom(loc("Carterville")).', 'atom(loc("Ill.")).', 'atom(locatedIn("Carbondale", "Carterville")).', 'atom(locatedIn("Carbondale", "Ill.")).', 'atom(locatedIn("Carterville", "Ill.")).']
# =======================================
# 91 ['atom(peop("Campbell")).', 'atom(peop("Mary")).', 'atom(loc("Rock+Hill")).', 'atom(liveIn("Campbell", "Rock+Hill")).', 'atom(liveIn("Mary", "Rock+Hill")).']
# 91 ['atom(peop("Campbell")).', 'atom(peop("Mary")).', 'atom(loc("Rock+Hill")).', 'atom(liveIn("Mary", "Rock+Hill")).']
# =======================================
# 94 ['atom(org("Warren+Commission")).', 'atom(peop("Lee+Harvey+Oswald")).', 'atom(peop("Kennedy")).', 'atom(loc("Dallas+County")).', 'atom(other("Nov.+22")).', 'atom(kill("Lee+Harvey+Oswald", "Kennedy")).']
# 94 ['atom(org("Warren+Commission")).', 'atom(peop("Lee+Harvey+Oswald")).', 'atom(peop("Kennedy")).', 'atom(loc("Dallas+County+Administration")).', 'atom(other("Nov.")).', 'atom(kill("Lee+Harvey+Oswald", "Kennedy")).']
# =======================================
# 95 ['atom(loc("U.S.")).', 'atom(peop("Sara+Matzar")).', 'atom(loc("Pabnjachel")).', 'atom(loc("Solola")).', 'atom(locatedIn("Pabnjachel", "Solola")).', 'atom(liveIn("Sara+Matzar", "Pabnjachel")).', 'atom(liveIn("Sara+Matzar", "Solola")).']
# 95 ['atom(loc("U.S.")).', 'atom(peop("Sara+Matzar")).', 'atom(loc("Pabnjachel")).', 'atom(loc("Solola")).', 'atom(liveIn("Sara+Matzar", "Solola")).', 'atom(locatedIn("Pabnjachel", "Solola")).', 'atom(liveIn("Sara+Matzar", "Pabnjachel")).', 'atom(liveIn("Sara+Matzar", "U.S.")).']
# =======================================
# 97 ['atom(org("INPE")).', 'atom(org("Finep")).', 'atom(loc("China")).', 'atom(org("Great+Wall+firm")).', 'atom(orgbasedIn("Great+Wall+firm", "China")).', 'atom(orgbasedIn("INPE", "China")).']
# 97 ['atom(org("INPE")).', 'atom(loc("China")).', 'atom(org("Great+Wall+firm")).', 'atom(orgbasedIn("INPE", "China")).', 'atom(orgbasedIn("Great+Wall+firm", "China")).']
# =======================================
# 98 ['atom(other("65+miles")).', 'atom(loc("Baghdad")).', 'atom(loc("Iraq")).', 'atom(locatedIn("Baghdad", "Iraq")).']
# 98 ['atom(other("65+miles")).', 'atom(loc("Baghdad")).', 'atom(loc("Iraq")).']
# =======================================
# 99 ['atom(peop("Derwinski")).', 'atom(org("Senate")).', 'atom(peop("Alan+Cranston")).', 'atom(org("Senate")).', 'atom(workFor("Alan+Cranston", "Senate")).']
# 99 ['atom(peop("Derwinski")).', 'atom(org("Senate")).', 'atom(org("Veterans+Department")).', 'atom(peop("Alan+Cranston")).', 'atom(org("Senate")).', 'atom(workFor("Alan+Cranston", "Senate")).']
# =======================================
# 100 ['atom(peop("Gerald+McEntee")).', 'atom(org("American+Federation")).', 'atom(org("State")).', 'atom(org("Municipal+Employees")).', 'atom(peop("Michael+Harrington")).', 'atom(workFor("Gerald+McEntee", "Municipal+Employees")).', 'atom(workFor("Gerald+McEntee", "State")).', 'atom(workFor("Gerald+McEntee", "American+Federation")).']
# 100 ['atom(peop("Gerald+McEntee")).', 'atom(peop("Michael+Harrington")).']
# =======================================
# 101 ['atom(peop("Hernandez+Galicia")).', 'atom(loc("Ciudad+Madero")).']
# 101 ['atom(peop("Hernandez+Galicia")).', 'atom(loc("Ciudad+Madero")).', 'atom(liveIn("Hernandez+Galicia", "Ciudad+Madero")).']
# =======================================
# 102 ['atom(loc("South+Korean")).', 'atom(loc("South+Korean")).', 'atom(loc("Alaska+pollock")).', 'atom(loc("Kamchatka")).', 'atom(loc("Okhotsk+Sea")).', 'atom(loc("Kamchatka")).', 'atom(peop("Kuzmenko")).', 'atom(loc("Okhotsk")).', 'atom(peop("Korochkin")).']
# 102 ['atom(loc("South")).', 'atom(other("500")).', 'atom(loc("Alaska")).', 'atom(loc("Kamchatka")).', 'atom(loc("Okhotsk+Sea")).', 'atom(loc("Kamchatka")).', 'atom(peop("Kuzmenko")).', 'atom(loc("Okhotsk+Sea.")).', 'atom(peop("Korochkin")).']
# =======================================
# 103 ['atom(peop("Jean+Hackett")).', 'atom(loc("New+York+City")).', 'atom(liveIn("Jean+Hackett", "New+York+City")).']
# 103 ['atom(peop("Psacharapoulos")).', 'atom(peop("Jean+Hackett")).', 'atom(loc("New+York+City")).', 'atom(liveIn("Jean+Hackett", "New+York+City")).']
# =======================================
# 104 ['atom(peop("Vasquez")).', 'atom(loc("Guadalajara")).', 'atom(loc("U.S.")).', 'atom(peop("John+Walker")).', 'atom(peop("Alberto+Radelat")).', 'atom(other("January+1985")).', 'atom(liveIn("Vasquez", "Guadalajara")).']
# 104 ['atom(peop("Vasquez")).', 'atom(loc("Guadalajara")).', 'atom(loc("U.S.")).', 'atom(peop("John+Walker")).', 'atom(peop("Alberto+Radelat")).', 'atom(kill("Alberto+Radelat", "John+Walker")).']
# =======================================
# 106 ['atom(peop("President+Kennedy")).', 'atom(peop("Lee+Harvey+Oswald")).', 'atom(other("27+years")).', 'atom(kill("Lee+Harvey+Oswald", "President+Kennedy")).']
# 106 ['atom(peop("President+Kennedy")).', 'atom(peop("Lee+Harvey+Oswald")).', 'atom(kill("Lee+Harvey+Oswald", "President+Kennedy")).']
# =======================================
# 107 ['atom(loc("Ohio")).', 'atom(peop("Richard+Celeste.")).', 'atom(liveIn("Richard+Celeste.", "Ohio")).']
# 107 ['atom(other("Ohio")).', 'atom(peop("Richard+Celeste.")).', 'atom(liveIn("Richard+Celeste.", "Ohio")).']
# =======================================
# 111 ['atom(peop("Jesse+Jackson")).', 'atom(loc("South+Carolina")).']
# 111 ['atom(peop("Jesse+Jackson")).', 'atom(other("Sunday")).', 'atom(loc("South+Carolina")).']
# =======================================
# 113 ['atom(peop("Dennis+DeConcini")).', 'atom(org("Senate")).', 'atom(other("Bush")).', 'atom(workFor("Dennis+DeConcini", "Senate")).']
# 113 ['atom(peop("Dennis+DeConcini")).', 'atom(org("Senate")).', 'atom(peop("Bush")).', 'atom(workFor("Dennis+DeConcini", "Senate")).']
# =======================================
# 114 ['atom(org("Pacific+Marine+Inc.")).', 'atom(loc("Houston")).', 'atom(other("15+miles")).', 'atom(loc("Grand+Isle.")).', 'atom(orgbasedIn("Pacific+Marine+Inc.", "Houston")).', 'atom(orgbasedIn("Pacific+Marine+Inc.", "Grand+Isle.")).']
# 114 ['atom(org("Pacific+Marine+Inc.")).', 'atom(loc("Houston")).', 'atom(other("15+miles")).', 'atom(loc("Grand+Isle.")).', 'atom(orgbasedIn("Pacific+Marine+Inc.", "Houston")).']
# =======================================
# 115 ['atom(org("The")).', 'atom(loc("Hague")).', 'atom(org("ANP")).', 'atom(orgbasedIn("ANP", "The")).', 'atom(orgbasedIn("ANP", "Hague")).']
# 115 ['atom(loc("Hague")).', 'atom(org("ANP")).', 'atom(orgbasedIn("ANP", "Hague")).']
# =======================================
# 116 ['atom(peop("Andric")).', 'atom(peop("Gavrilo")).', 'atom(peop("Archduke+Ferdinand")).', 'atom(loc("Sarajevo")).', 'atom(kill("Gavrilo", "Archduke+Ferdinand")).']
# 116 ['atom(peop("Andric")).', 'atom(peop("Gavrilo+Princip")).', 'atom(peop("Archduke+Ferdinand")).', 'atom(loc("Sarajevo")).', 'atom(kill("Gavrilo+Princip", "Archduke+Ferdinand")).']
# =======================================
# 118 ['atom(loc("Mlita+hill")).', 'atom(loc("Iqlim+al-Tuffah")).']
# 118 ['atom(loc("Mlita+hill")).']
# =======================================
# 119 ['atom(peop("James+G.+Blight")).', 'atom(peop("David+A.+Welch")).', 'atom(org("Harvard+University")).', 'atom(other("John+F.+Kennedy+School+of+Government")).', 'atom(other("10+o")).', 'atom(other("Oct.")).', 'atom(other("several")).', 'atom(other("hundred+miles")).', 'atom(loc("Cuba.")).', 'atom(workFor("David+A.+Welch", "Harvard+University")).', 'atom(workFor("James+G.+Blight", "Harvard+University")).']
# 119 ['atom(peop("James+G.+Blight")).', 'atom(peop("David+A.+Welch")).', 'atom(org("Harvard+University")).', 'atom(peop("John+F.+Kennedy+School")).', 'atom(other("10+o")).', 'atom(other("Wednesday+morning")).', 'atom(other("Oct.")).', 'atom(other("hundred+miles")).', 'atom(loc("Cuba.")).', 'atom(workFor("David+A.+Welch", "Harvard+University")).', 'atom(workFor("James+G.+Blight", "Harvard+University")).']
# =======================================
# 120 ['atom(peop("Lee+Harvey+Oswald")).', 'atom(loc("Texas")).', 'atom(peop("President+John+F.+Kennedy")).', 'atom(kill("Lee+Harvey+Oswald", "President+John+F.+Kennedy")).']
# 120 ['atom(peop("Lee+Harvey+Oswald")).', 'atom(loc("Texas")).', 'atom(peop("John+Connally")).', 'atom(peop("President+John+F.+Kennedy")).', 'atom(kill("Lee+Harvey+Oswald", "John+Connally")).']
# =======================================
# 122 ['atom(peop("Robert+Weisner")).', 'atom(loc("Washington")).', 'atom(loc("Austrian")).', 'atom(liveIn("Robert+Weisner", "Washington")).']
# 122 ['atom(peop("Robert+Weisner")).', 'atom(loc("Washington")).', 'atom(loc("Austrian+television.")).', 'atom(liveIn("Robert+Weisner", "Washington")).', 'atom(liveIn("Robert+Weisner", "Austrian+television.")).']
# =======================================
# 123 ['atom(peop("President+Reagan")).', 'atom(loc("U.S.")).']
# 123 ['atom(peop("Reagan")).', 'atom(org("State+Department")).', 'atom(loc("U.S.")).', 'atom(workFor("Reagan", "State+Department")).']
# =======================================
# 124 ['atom(peop("Mrs.+Rose")).', 'atom(peop("Abebe+Worke")).', 'atom(loc("Ethiopia")).', 'atom(liveIn("Abebe+Worke", "Ethiopia")).', 'atom(liveIn("Mrs.+Rose", "Ethiopia")).']
# 124 ['atom(peop("Mrs.+Rose")).', 'atom(peop("Abebe+Worke")).', 'atom(loc("Ethiopia")).', 'atom(org("High+Court")).', 'atom(liveIn("Abebe+Worke", "Ethiopia")).', 'atom(liveIn("Mrs.+Rose", "Ethiopia")).', 'atom(workFor("Abebe+Worke", "High+Court")).']
# =======================================
# 127 ['atom(org("PRI")).', 'atom(other("37+percent")).', 'atom(peop("Cardenas")).', 'atom(org("Party+of+the+Democratic+Revolution")).', 'atom(other("9+percent")).', 'atom(workFor("Cardenas", "PRI")).', 'atom(workFor("Cardenas", "Party+of+the+Democratic+Revolution")).']
# 127 ['atom(other("37+percent")).', 'atom(peop("Cardenas")).', 'atom(other("9+percent")).']
# =======================================
# 128 ['atom(peop("Ludwig+Rinn")).', 'atom(loc("Riga")).', 'atom(loc("Latvia")).', 'atom(loc("Soviet+Union")).', 'atom(liveIn("Ludwig+Rinn", "Soviet+Union")).', 'atom(locatedIn("Riga", "Soviet+Union")).']
# 128 ['atom(peop("Ludwig+Rinn")).', 'atom(loc("Riga")).', 'atom(loc("Latvia")).', 'atom(loc("Soviet+Union")).', 'atom(liveIn("Ludwig+Rinn", "Riga")).', 'atom(locatedIn("Riga", "Latvia")).', 'atom(liveIn("Ludwig+Rinn", "Soviet+Union")).']
# =======================================
# 131 ['atom(peop("Angie+Dickinson")).', 'atom(loc("Kulm")).', 'atom(loc("N.D.")).', 'atom(other("Academy+Awards")).', 'atom(locatedIn("Kulm", "N.D.")).', 'atom(liveIn("Angie+Dickinson", "N.D.")).', 'atom(liveIn("Angie+Dickinson", "Kulm")).']
# 131 ['atom(peop("Angie+Dickinson")).', 'atom(loc("Kulm+,+N.D.")).', 'atom(other("1966+Academy+Awards")).', 'atom(liveIn("Angie+Dickinson", "Kulm+,+N.D.")).']
# =======================================
# 137 ['atom(loc("Bangkok")).', 'atom(org("DAO")).', 'atom(loc("SIAM")).', 'atom(other("20+Nov+93")).', 'atom(orgbasedIn("DAO", "Bangkok")).', 'atom(orgbasedIn("SIAM", "Bangkok")).']
# 137 ['atom(loc("Bangkok")).', 'atom(org("DAO+SIAM")).', 'atom(other("20+Nov+93")).', 'atom(orgbasedIn("DAO+SIAM", "Bangkok")).']
# =======================================
# 138 ['atom(loc("SEOUL")).', 'atom(loc("South+Korea")).', 'atom(org("AP")).', 'atom(orgbasedIn("AP", "SEOUL")).', 'atom(locatedIn("SEOUL", "South+Korea")).']
# 138 ['atom(loc("SEOUL")).', 'atom(loc("South+Korea")).', 'atom(org("AP")).', 'atom(locatedIn("SEOUL", "South+Korea")).']
# =======================================
# 139 ['atom(peop("Vicente+Licona")).', 'atom(org("Labor+Party")).', 'atom(peop("Cecilia+Soto")).', 'atom(workFor("Vicente+Licona", "Labor+Party")).', 'atom(workFor("Cecilia+Soto", "Labor+Party")).']
# 139 ['atom(peop("Harris")).', 'atom(peop("Vicente+Licona")).', 'atom(org("Labor+Party")).', 'atom(peop("Cecilia+Soto")).', 'atom(workFor("Vicente+Licona", "Labor+Party")).', 'atom(workFor("Cecilia+Soto", "Labor+Party")).']
# =======================================
# 140 ['atom(loc("Angola")).', 'atom(loc("United+Nations")).']
# 140 ['atom(loc("Angola")).', 'atom(org("United+Nations")).']
# =======================================
# 142 ['atom(loc("Moscow")).', 'atom(org("State+Duma")).', 'atom(peop("Konstantin+Zatulin")).', 'atom(loc("Crimea")).', 'atom(orgbasedIn("State+Duma", "Moscow")).', 'atom(workFor("Konstantin+Zatulin", "State+Duma")).']
# 142 ['atom(loc("Moscow")).', 'atom(peop("Konstantin+Zatulin")).', 'atom(loc("Crimea")).']
# =======================================
# 143 ['atom(loc("San+Diego+County")).', 'atom(other("60+mph")).', 'atom(loc("Ramona")).', 'atom(loc("California")).', 'atom(locatedIn("Ramona", "California")).']
# 143 ['atom(loc("San+Diego+County")).', 'atom(other("60+mph")).', 'atom(loc("Ramona")).', 'atom(loc("California+Department")).', 'atom(locatedIn("Ramona", "California+Department")).']
# =======================================
# 145 ['atom(peop("Jim+Bowell")).', 'atom(org("Butler+Township+Fire")).', 'atom(other("4+:+45+a.m.")).', 'atom(other("100+yards")).', 'atom(workFor("Jim+Bowell", "Butler+Township+Fire")).']
# 145 ['atom(peop("Jim+Bowell")).', 'atom(org("Butler+Township+Fire+Department")).', 'atom(other("4+:")).', 'atom(other("45+a.m.")).', 'atom(other("100+yards")).', 'atom(workFor("Jim+Bowell", "Butler+Township+Fire+Department")).']
# =======================================
# 146 ['atom(loc("TRENTON")).', 'atom(loc("N.J.")).', 'atom(locatedIn("TRENTON", "N.J.")).']
# 146 ['atom(loc("TRENTON+,")).', 'atom(loc("N.J.")).']
# =======================================
# 147 ['atom(peop("Judy+Kaye")).', 'atom(org("Broadway")).', 'atom(loc("New+York")).', 'atom(org("Opera+Repertory+Theater")).', 'atom(peop("Abbie")).', 'atom(orgbasedIn("Opera+Repertory+Theater", "New+York")).']
# 147 ['atom(peop("Judy+Kaye")).', 'atom(loc("Broadway")).', 'atom(org("New+York+Opera+Repertory+Theater")).', 'atom(peop("Abbie")).', 'atom(liveIn("Judy+Kaye", "Broadway")).', 'atom(workFor("Judy+Kaye", "New+York+Opera+Repertory+Theater")).']
# =======================================
# 149 ['atom(peop("President+Kennedy")).', 'atom(org("Texas+Schoolbook+Depository")).', 'atom(peop("Lee+Harvey+Oswald")).', 'atom(other("Presidents")).']
# 149 ['atom(peop("President+Kennedy")).', 'atom(org("Texas+Schoolbook+Depository")).', 'atom(peop("Lee+Harvey+Oswald")).', 'atom(loc("Presidents")).']
# =======================================
# 150 ['atom(peop("Ernest+L.+Boyer")).', 'atom(org("Carnegie+Foundation")).']
# 150 ['atom(peop("Ernest+L.+Boyer")).', 'atom(org("Carnegie+Foundation")).', 'atom(workFor("Ernest+L.+Boyer", "Carnegie+Foundation")).']
# =======================================
# 151 ['atom(peop("Martina+Matzar")).', 'atom(loc("Santa+Catarina+Palopo")).', 'atom(loc("Solola")).', 'atom(locatedIn("Santa+Catarina+Palopo", "Solola")).']
# 151 ['atom(peop("Martina+Matzar")).', 'atom(loc("Santa+Catarina+Palopo")).', 'atom(loc("Solola")).', 'atom(locatedIn("Santa+Catarina+Palopo", "Solola")).', 'atom(liveIn("Martina+Matzar", "Santa+Catarina+Palopo")).', 'atom(liveIn("Martina+Matzar", "Solola")).']
# =======================================
# 153 ['atom(peop("Gary+H.+Heichel")).', 'atom(org("USDA")).']
# 153 ['atom(peop("Gary+H.+Heichel")).', 'atom(org("USDA")).', 'atom(workFor("Gary+H.+Heichel", "USDA")).']
# =======================================
# 154 ['atom(loc("Sao+Paulo")).', 'atom(org("O+ESTADO+DE+SAO+PAULO")).', 'atom(orgbasedIn("O+ESTADO+DE+SAO+PAULO", "Sao+Paulo")).']
# 154 ['atom(loc("Sao+Paulo")).', 'atom(org("O+ESTADO+DE")).', 'atom(loc("SAO+PAULO")).', 'atom(orgbasedIn("O+ESTADO+DE", "Sao+Paulo")).', 'atom(orgbasedIn("O+ESTADO+DE", "SAO+PAULO")).']
# =======================================
# 155 ['atom(loc("UnitedStates")).', 'atom(org("Martin+Van+Buren")).', 'atom(loc("Kinderhook+,+N.Y.")).', 'atom(liveIn("Martin+Van+Buren", "Kinderhook+,+N.Y.")).']
# 155 ['atom(loc("UnitedStates")).', 'atom(peop("Martin+Van+Buren")).', 'atom(loc("Kinderhook+,+N.Y.")).', 'atom(liveIn("Martin+Van+Buren", "Kinderhook+,+N.Y.")).']
# =======================================
# 156 ['atom(org("FBI")).', 'atom(org("Environmental+Protection+Agency")).', 'atom(loc("Rocky+Flats")).', 'atom(loc("Colorado")).', 'atom(loc("Fernald")).', 'atom(loc("Ohio")).', 'atom(locatedIn("Rocky+Flats", "Ohio")).', 'atom(locatedIn("Fernald", "Ohio")).', 'atom(locatedIn("Rocky+Flats", "Colorado")).']
# 156 ['atom(org("FBI")).', 'atom(org("Environmental+Protection+Agency")).', 'atom(loc("Rocky+Flats")).', 'atom(loc("Colorado")).', 'atom(peop("Fernald")).', 'atom(loc("Ohio")).', 'atom(liveIn("Fernald", "Ohio")).', 'atom(locatedIn("Rocky+Flats", "Colorado")).']
# =======================================
# 157 ['atom(loc("KHARTOUM")).', 'atom(loc("Sudan")).', 'atom(org("AP")).', 'atom(locatedIn("KHARTOUM", "Sudan")).', 'atom(orgbasedIn("AP", "Sudan")).', 'atom(orgbasedIn("AP", "KHARTOUM")).']
# 157 ['atom(loc("KHARTOUM")).', 'atom(loc("Sudan")).', 'atom(org("AP")).', 'atom(locatedIn("KHARTOUM", "Sudan")).', 'atom(orgbasedIn("AP", "KHARTOUM")).']
# =======================================
# 158 ['atom(peop("James+Cirona")).', 'atom(org("Federal+Home+Loan+Bank+of+San+Francisco")).', 'atom(workFor("James+Cirona", "Federal+Home+Loan+Bank+of+San+Francisco")).']
# 158 ['atom(peop("James+Cirona")).', 'atom(org("Federal+Home+Loan+Bank")).', 'atom(loc("San+Francisco")).', 'atom(workFor("James+Cirona", "Federal+Home+Loan+Bank")).', 'atom(liveIn("James+Cirona", "San+Francisco")).']
# =======================================
# 160 ['atom(other("April")).', 'atom(peop("Lincoln")).', 'atom(peop("John+Wilkes+Booth")).', 'atom(loc("Ford")).', 'atom(kill("John+Wilkes+Booth", "Lincoln")).']
# 160 ['atom(other("April")).', 'atom(peop("Lincoln")).', 'atom(loc("president")).', 'atom(peop("John+Wilkes+Booth")).', 'atom(other("Ford")).', 'atom(other("Theatre")).', 'atom(kill("John+Wilkes+Booth", "Lincoln")).']
# =======================================
# 161 ['atom(other("15+December+1993")).', 'atom(loc("Marrackech")).', 'atom(loc("Morocco")).', 'atom(other("12+April")).', 'atom(locatedIn("Marrackech", "Morocco")).']
# 161 ['atom(other("15+December+1993")).', 'atom(loc("Marrackech")).', 'atom(loc("Morocco")).', 'atom(other("12+April+this")).', 'atom(locatedIn("Marrackech", "Morocco")).']
# =======================================
# 162 ['atom(peop("Reuven+Pedatzur")).', 'atom(org("Jaffe+Center+for+Strategic+Studies")).', 'atom(workFor("Reuven+Pedatzur", "Jaffe+Center+for+Strategic+Studies")).']
# 162 ['atom(peop("IAI")).', 'atom(peop("Reuven+Pedatzur")).', 'atom(org("Jaffe+Center+for+Strategic+Studies")).', 'atom(workFor("Reuven+Pedatzur", "Jaffe+Center+for+Strategic+Studies")).']
# =======================================
# 164 ['atom(peop("Jace+Alexander")).', 'atom(peop("Lee+Harvey+Oswald")).', 'atom(peop("Victor+Garber")).', 'atom(peop("John+Wilkes+Booth")).', 'atom(peop("Debra+Monk")).', 'atom(peop("Sara+Jane+Moore")).', 'atom(peop("Greg+Germann")).', 'atom(peop("John+Hinckley")).', 'atom(peop("Annie+Golden")).', 'atom(peop("Lynette")).', 'atom(peop("Fromme")).', 'atom(peop("President+Ford")).', 'atom(peop("Terrence+Mann")).', 'atom(peop("Leon+Czolgosz")).', 'atom(peop("President+McKinley")).', 'atom(kill("Leon+Czolgosz", "President+McKinley")).']
# 164 ['atom(peop("Jace+Alexander")).', 'atom(peop("Lee+Harvey+Oswald")).', 'atom(peop("Victor+Garber")).', 'atom(peop("John+Wilkes+Booth")).', 'atom(peop("Debra+Monk")).', 'atom(peop("Sara+Jane+Moore")).', 'atom(peop("Greg+Germann")).', 'atom(peop("John+Hinckley")).', 'atom(peop("Annie+Golden")).', 'atom(peop("Lynette")).', 'atom(peop("President+Ford")).', 'atom(peop("Terrence+Mann")).', 'atom(peop("Leon+Czolgosz")).', 'atom(peop("President+McKinley")).', 'atom(kill("Jace+Alexander", "Lee+Harvey+Oswald")).', 'atom(kill("Greg+Germann", "John+Hinckley")).', 'atom(kill("Leon+Czolgosz", "President+McKinley")).', 'atom(kill("Victor+Garber", "John+Wilkes+Booth")).', 'atom(kill("Terrence+Mann", "President+McKinley")).']
# =======================================
# 165 ['atom(peop("Samuel+Mudd")).', 'atom(peop("Lincoln")).', 'atom(peop("John+Wilkes+Booth")).', 'atom(peop("Booth")).', 'atom(kill("John+Wilkes+Booth", "Lincoln")).', 'atom(kill("Samuel+Mudd", "Lincoln")).']
# 165 ['atom(other("Army")).', 'atom(peop("Samuel+Mudd")).', 'atom(peop("Lincoln")).', 'atom(peop("John+Wilkes+Booth")).', 'atom(peop("Booth")).', 'atom(kill("John+Wilkes+Booth", "Lincoln")).', 'atom(kill("Samuel+Mudd", "Lincoln")).']
# =======================================
# 166 ['atom(peop("Anderson")).', 'atom(peop("E.+Howard+Hunt")).', 'atom(peop("James+Earl+Ray")).', 'atom(peop("Martin+Luther+King+Jr")).', 'atom(kill("James+Earl+Ray", "E.+Howard+Hunt")).', 'atom(kill("E.+Howard+Hunt", "Martin+Luther+King+Jr")).', 'atom(kill("James+Earl+Ray", "Martin+Luther+King+Jr")).']
# 166 ['atom(peop("Anderson")).', 'atom(peop("E.+Howard+Hunt")).', 'atom(peop("James+Earl+Ray")).', 'atom(peop("Martin+Luther+King+Jr")).', 'atom(kill("James+Earl+Ray", "Martin+Luther+King+Jr")).', 'atom(kill("James+Earl+Ray", "E.+Howard+Hunt")).']
# =======================================
# 169 ['atom(peop("Nils+Bemer")).', 'atom(peop("Tomas+Nilsen")).', 'atom(other("START+II")).', 'atom(loc("Russia")).']
# 169 ['atom(peop("Bellona")).', 'atom(peop("Nils+Bemer")).', 'atom(peop("Tomas+Nilsen")).', 'atom(org("Northern+Fleet")).', 'atom(loc("Russia")).']
# =======================================
# 170 ['atom(loc("Moscow")).', 'atom(org("KRASNAYA+ZVEZDA")).', 'atom(other("16+Feb+94")).', 'atom(orgbasedIn("KRASNAYA+ZVEZDA", "Moscow")).']
# 170 ['atom(loc("Moscow")).', 'atom(org("KRASNAYA")).', 'atom(other("16+Feb+94")).', 'atom(orgbasedIn("KRASNAYA", "Moscow")).']
# =======================================
# 171 ['atom(loc("Panama+City")).', 'atom(org("Circuito+RPC+Television")).', 'atom(other("0200+GMT")).', 'atom(other("9+March")).', 'atom(other("Democracy+94")).', 'atom(peop("Ruben+Blades")).', 'atom(org("Papa+Egoro+Movement")).', 'atom(peop("Hugo+Enrique+Famania")).', 'atom(workFor("Ruben+Blades", "Papa+Egoro+Movement")).', 'atom(orgbasedIn("Circuito+RPC+Television", "Panama+City")).', 'atom(workFor("Hugo+Enrique+Famania", "Papa+Egoro+Movement")).']
# 171 ['atom(loc("Panama+City")).', 'atom(org("Circuito+RPC+Television")).', 'atom(other("0200+GMT")).', 'atom(other("9+March")).', 'atom(peop("Ruben+Blades")).', 'atom(org("Papa+Egoro+Movement")).', 'atom(peop("Hugo+Enrique+Famania")).', 'atom(orgbasedIn("Circuito+RPC+Television", "Panama+City")).', 'atom(workFor("Hugo+Enrique+Famania", "Papa+Egoro+Movement")).', 'atom(workFor("Ruben+Blades", "Papa+Egoro+Movement")).']
# =======================================
# 173 ['atom(peop("John+Harvey+Adamson")).', 'atom(peop("Don+Bolles")).']
# 173 ['atom(peop("John+Harvey+Adamson")).', 'atom(peop("Don+Bolles")).', 'atom(kill("John+Harvey+Adamson", "Don+Bolles")).']
# =======================================
# ...
# 589 ['atom(peop("Abraham+Lincoln")).', 'atom(loc("President")).', 'atom(other("Feb.")).', 'atom(loc("Hodgenville+,+Ky.")).', 'atom(liveIn("Abraham+Lincoln", "Hodgenville+,+Ky.")).']
# =======================================
# 591 ['atom(loc("Madrid")).', 'atom(org("RNE+International")).', 'atom(orgbasedIn("RNE+International", "Madrid")).']
# 591 ['atom(loc("Madrid")).', 'atom(org("RNE")).', 'atom(orgbasedIn("RNE", "Madrid")).']
# =======================================
# 595 ['atom(peop("President+Bush")).', 'atom(loc("United+States")).', 'atom(other("$50+million")).', 'atom(loc("Poland")).']
# 595 ['atom(peop("Bush")).', 'atom(loc("United+States")).', 'atom(other("$50+million")).', 'atom(loc("Poland")).']
# =======================================
# 596 ['atom(peop("Yount")).', 'atom(loc("Coeur")).', 'atom(peop("James+Marvin+Forsgren")).', 'atom(peop("Pamela+Sue+Rimer")).', 'atom(loc("Luthersberg+,+Pa")).', 'atom(liveIn("Pamela+Sue+Rimer", "Luthersberg+,+Pa")).', 'atom(liveIn("Yount", "Coeur")).']
# 596 ['atom(peop("Yount")).', 'atom(loc("Coeur")).', 'atom(peop("James+Marvin+Forsgren")).', 'atom(peop("Pamela+Sue+Rimer")).', 'atom(loc("Luthersberg")).', 'atom(loc("Pa")).', 'atom(liveIn("Pamela+Sue+Rimer", "Luthersberg")).', 'atom(liveIn("Pamela+Sue+Rimer", "Pa")).', 'atom(liveIn("James+Marvin+Forsgren", "Coeur")).', 'atom(locatedIn("Luthersberg", "Pa")).', 'atom(liveIn("Yount", "Coeur")).']
# =======================================
# 597 ['atom(loc("Magadan")).', 'atom(org("Radio+Magadan")).', 'atom(other("0700+GMT")).', 'atom(other("5+Apr+94")).', 'atom(orgbasedIn("Radio+Magadan", "Magadan")).']
# 597 ['atom(loc("Magadan")).', 'atom(org("Radio")).', 'atom(loc("Magadan")).', 'atom(other("0700+GMT")).', 'atom(other("5+Apr+94")).', 'atom(orgbasedIn("Radio", "Magadan")).', 'atom(orgbasedIn("Radio", "Magadan")).']
# =======================================
# 598 ['atom(loc("London")).', 'atom(org("SUNDAY+TIMES")).', 'atom(other("30+Jan+94")).', 'atom(orgbasedIn("SUNDAY+TIMES", "London")).']
# 598 ['atom(loc("British")).', 'atom(loc("London")).', 'atom(org("THE+SUNDAY+TIMES")).', 'atom(other("30+Jan+94")).', 'atom(orgbasedIn("THE+SUNDAY+TIMES", "London")).', 'atom(orgbasedIn("THE+SUNDAY+TIMES", "British")).']
# =======================================
# 599 ['atom(loc("HIGH+ISLAND")).', 'atom(loc("Texas")).', 'atom(org("AP")).', 'atom(orgbasedIn("AP", "HIGH+ISLAND")).', 'atom(locatedIn("HIGH+ISLAND", "Texas")).']
# 599 ['atom(loc("HIGH+ISLAND")).', 'atom(loc("Texas")).', 'atom(org("AP")).', 'atom(locatedIn("HIGH+ISLAND", "Texas")).']
# =======================================
# 600 ['atom(loc("Broadway")).', 'atom(org("Royal+Alexandra+Theatre")).', 'atom(loc("Toronto")).', 'atom(loc("Canada")).', 'atom(loc("Williamstown")).', 'atom(orgbasedIn("Royal+Alexandra+Theatre", "Toronto")).', 'atom(orgbasedIn("Royal+Alexandra+Theatre", "Canada")).']
# 600 ['atom(loc("Broadway")).', 'atom(org("Royal+Alexandra+Theatre")).', 'atom(loc("Toronto")).', 'atom(loc("Canada")).', 'atom(loc("Williamstown")).', 'atom(orgbasedIn("Royal+Alexandra+Theatre", "Canada")).', 'atom(orgbasedIn("Royal+Alexandra+Theatre", "Toronto")).', 'atom(locatedIn("Toronto", "Canada")).']
# =======================================
# 601 ['atom(peop("Sirhan+Sirhan")).', 'atom(peop("Sen.+Robert+F.+Kennedy")).', 'atom(peop("Kennedy")).', 'atom(loc("Israel")).', 'atom(kill("Sirhan+Sirhan", "Sen.+Robert+F.+Kennedy")).']
# 601 ['atom(peop("Sirhan+Sirhan")).', 'atom(peop("Robert+F.+Kennedy")).', 'atom(peop("Kennedy")).', 'atom(loc("Israel")).', 'atom(liveIn("Kennedy", "Israel")).', 'atom(kill("Sirhan+Sirhan", "Robert+F.+Kennedy")).']
# =======================================
# 602 ['atom(loc("SOLEDAD")).', 'atom(peop("Sirhan+B.+Sirhan")).', 'atom(peop("Robert+F.+Kennedy")).', 'atom(kill("Sirhan+B.+Sirhan", "Robert+F.+Kennedy")).']
# 602 ['atom(loc("SOLEDAD")).', 'atom(loc("Calif.")).', 'atom(peop("Sirhan+B.+Sirhan")).', 'atom(peop("Robert+F.+Kennedy")).', 'atom(locatedIn("SOLEDAD", "Calif.")).', 'atom(kill("Sirhan+B.+Sirhan", "Robert+F.+Kennedy")).']
# =======================================
# 603 ['atom(peop("James+Earl+Ray")).', 'atom(loc("Memphis")).', 'atom(peop("Martin+Luther+King+Junior")).', 'atom(liveIn("James+Earl+Ray", "Memphis")).']
# 603 ['atom(peop("James+Earl+Ray")).', 'atom(loc("Memphis")).', 'atom(loc("Tenn.")).', 'atom(peop("Martin+Luther+King+Junior")).', 'atom(locatedIn("Memphis", "Tenn.")).', 'atom(liveIn("James+Earl+Ray", "Memphis")).', 'atom(liveIn("James+Earl+Ray", "Tenn.")).']
# =======================================
# 604 ['atom(loc("Beijing")).', 'atom(loc("CHINA")).', 'atom(org("DAILY")).', 'atom(org("SCIENCE+MEDICINE")).', 'atom(orgbasedIn("DAILY", "Beijing")).', 'atom(orgbasedIn("SCIENCE+MEDICINE", "Beijing")).', 'atom(orgbasedIn("SCIENCE+MEDICINE", "CHINA")).', 'atom(orgbasedIn("DAILY", "CHINA")).']
# 604 ['atom(loc("Beijing")).', 'atom(org("CHINA")).', 'atom(org("DAILY")).', 'atom(orgbasedIn("DAILY", "CHINA")).', 'atom(orgbasedIn("DAILY", "Beijing")).', 'atom(orgbasedIn("CHINA", "Beijing")).']
# =======================================
# 605 ['atom(peop("Ozawa")).', 'atom(loc("U.S.")).', 'atom(loc("Tokyo")).', 'atom(org("YOMIURI+SHIMBUN")).', 'atom(other("14+Feb+94")).', 'atom(liveIn("Ozawa", "U.S.")).', 'atom(orgbasedIn("YOMIURI+SHIMBUN", "Tokyo")).']
# 605 ['atom(peop("Ozawa")).', 'atom(loc("U.S.")).', 'atom(loc("Tokyo")).', 'atom(org("YOMIURI+SHIMBUN")).', 'atom(other("14+Feb+94")).', 'atom(orgbasedIn("YOMIURI+SHIMBUN", "Tokyo")).']
# =======================================
# 606 ['atom(peop("Weiss")).', 'atom(peop("Huey+Long")).', 'atom(peop("Weiss")).', 'atom(peop("Johnston")).', 'atom(loc("Washington.")).', 'atom(liveIn("Johnston", "Washington.")).']
# 606 ['atom(peop("Weiss")).', 'atom(peop("Huey+Long")).', 'atom(peop("Weiss")).', 'atom(peop("Johnston")).', 'atom(loc("Washington.")).', 'atom(liveIn("Johnston", "Washington.")).', 'atom(kill("Weiss", "Huey+Long")).']
# =======================================
# 608 ['atom(peop("Higgins")).', 'atom(loc("United+Nations")).']
# 608 ['atom(peop("Higgins")).', 'atom(loc("United+Nations")).', 'atom(liveIn("Higgins", "United+Nations")).']
# =======================================
# 610 ['atom(peop("Anderson")).', 'atom(org("GE")).', 'atom(other("June+2")).', 'atom(other("May+1988")).', 'atom(other("July")).', 'atom(org("General+Electric+Aircraft")).', 'atom(workFor("Anderson", "GE")).']
# 610 ['atom(peop("Anderson")).', 'atom(org("GE")).', 'atom(other("June+2+,")).', 'atom(other("late+May+1988")).', 'atom(other("July+1987")).', 'atom(org("GEAE")).', 'atom(org("General+Electric")).', 'atom(workFor("Anderson", "GE")).']
# =======================================
# 611 ['atom(loc("Beijing")).', 'atom(org("XINHUA+Domestic+Service")).', 'atom(orgbasedIn("XINHUA+Domestic+Service", "Beijing")).']
# 611 ['atom(loc("Beijing")).', 'atom(org("XINHUA")).', 'atom(orgbasedIn("XINHUA", "Beijing")).']
# =======================================
# 612 ['atom(org("Warren+Commission")).', 'atom(peop("Lee+Harvey+Oswald")).', 'atom(peop("Kennedy")).', 'atom(peop("Texas+Gov.+John+Connally")).', 'atom(kill("Lee+Harvey+Oswald", "Texas+Gov.+John+Connally")).', 'atom(kill("Lee+Harvey+Oswald", "Kennedy")).']
# 612 ['atom(org("Warren+Commission")).', 'atom(peop("Lee+Harvey+Oswald")).', 'atom(peop("Kennedy")).', 'atom(loc("Texas")).', 'atom(peop("John+Connally")).', 'atom(kill("John+Connally", "Kennedy")).', 'atom(kill("Lee+Harvey+Oswald", "Kennedy")).']
# =======================================
# 613 ['atom(loc("MILLINOCKET")).', 'atom(loc("Maine")).', 'atom(org("AP")).', 'atom(locatedIn("MILLINOCKET", "Maine")).', 'atom(orgbasedIn("AP", "Maine")).', 'atom(orgbasedIn("AP", "MILLINOCKET")).']
# 613 ['atom(loc("MILLINOCKET")).', 'atom(loc("Maine")).', 'atom(org("AP")).', 'atom(locatedIn("MILLINOCKET", "Maine")).']
# =======================================
# 614 ['atom(peop("Mark+David+Chapman")).', 'atom(peop("Beatle+John+Lennon")).', 'atom(kill("Mark+David+Chapman", "Beatle+John+Lennon")).']
# 614 ['atom(peop("Mark+David+Chapman")).', 'atom(other("20")).', 'atom(peop("John+Lennon")).', 'atom(kill("Mark+David+Chapman", "John+Lennon")).']
# =======================================
# 615 ['atom(peop("Booth")).', 'atom(peop("Oswald")).', 'atom(peop("Jack+Kennedy")).', 'atom(kill("Booth", "Jack+Kennedy")).', 'atom(kill("Oswald", "Jack+Kennedy")).']
# 615 ['atom(peop("Booth")).', 'atom(peop("Oswald")).', 'atom(peop("Jack+Kennedy")).', 'atom(kill("Oswald", "Jack+Kennedy")).']
# =======================================
# 618 ['atom(peop("Mauro")).', 'atom(org("Owens-Corning")).', 'atom(loc("Toledo+,+Ohio")).', 'atom(orgbasedIn("Owens-Corning", "Toledo+,+Ohio")).']
# 618 ['atom(peop("Mauro")).', 'atom(org("Owens-Corning")).', 'atom(loc("Toledo")).', 'atom(loc("Ohio")).', 'atom(locatedIn("Toledo", "Ohio")).', 'atom(workFor("Mauro", "Owens-Corning")).']
# =======================================
# 620 ['atom(peop("Maxwell")).', 'atom(loc("Plum")).', 'atom(loc("New+Yorkers")).', 'atom(loc("Manhattan")).', 'atom(other("1980s")).', 'atom(liveIn("Maxwell", "Plum")).']
# 620 ['atom(peop("Maxwell")).', 'atom(loc("New")).', 'atom(other("1960s")).', 'atom(loc("Manhattan")).']
# =======================================
# 621 ['atom(org("Becton")).', 'atom(org("Dickinson+Co.")).', 'atom(loc("Franklin+Lakes")).', 'atom(loc("N.J.")).', 'atom(orgbasedIn("Becton", "N.J.")).', 'atom(orgbasedIn("Dickinson+Co.", "N.J.")).', 'atom(locatedIn("Franklin+Lakes", "N.J.")).', 'atom(orgbasedIn("Dickinson+Co.", "Franklin+Lakes")).']
# 621 ['atom(org("Becton+Dickinson+Co.")).', 'atom(loc("Franklin+Lakes")).', 'atom(loc("N.J.")).', 'atom(orgbasedIn("Becton+Dickinson+Co.", "N.J.")).', 'atom(locatedIn("Franklin+Lakes", "N.J.")).', 'atom(orgbasedIn("Becton+Dickinson+Co.", "Franklin+Lakes")).']
# =======================================
# 622 ['atom(loc("Freeport")).', 'atom(loc("Texas")).', 'atom(loc("Morgan+City")).', 'atom(loc("La.")).', 'atom(locatedIn("Freeport", "Texas")).', 'atom(locatedIn("Freeport", "La.")).', 'atom(locatedIn("Morgan+City", "La.")).']
# 622 ['atom(loc("Freeport")).', 'atom(loc("Texas")).', 'atom(loc("Morgan+City")).', 'atom(loc("La.")).', 'atom(locatedIn("Morgan+City", "La.")).', 'atom(locatedIn("Freeport", "Texas")).']
# =======================================
# 623 ['atom(org("OSHA")).', 'atom(org("S.A.+Healy+Co.")).', 'atom(loc("McCook")).', 'atom(loc("Ill.")).', 'atom(org("CH2M+Hill")).', 'atom(loc("Corvallis")).', 'atom(loc("Ore.")).', 'atom(locatedIn("Corvallis", "Ore.")).', 'atom(orgbasedIn("S.A.+Healy+Co.", "Ill.")).', 'atom(orgbasedIn("CH2M+Hill", "Corvallis")).', 'atom(locatedIn("McCook", "Ill.")).', 'atom(orgbasedIn("CH2M+Hill", "Ore.")).']
# 623 ['atom(org("OSHA")).', 'atom(org("S.A.+Healy+Co.")).', 'atom(loc("McCook")).', 'atom(loc("Ill.")).', 'atom(org("CH2M+Hill")).', 'atom(loc("Corvallis")).', 'atom(loc("Ore.")).', 'atom(orgbasedIn("S.A.+Healy+Co.", "Ill.")).', 'atom(locatedIn("Corvallis", "Ore.")).', 'atom(orgbasedIn("CH2M+Hill", "Corvallis")).', 'atom(orgbasedIn("CH2M+Hill", "Ore.")).', 'atom(orgbasedIn("S.A.+Healy+Co.", "McCook")).', 'atom(locatedIn("McCook", "Ill.")).']
# =======================================
# 624 ['atom(peop("George+Shibley")).', 'atom(peop("Robert+F.+Kennedy")).', 'atom(peop("Sirhan+Sirhan")).', 'atom(kill("Sirhan+Sirhan", "Robert+F.+Kennedy")).']
# 624 ['atom(peop("George+Shibley")).', 'atom(peop("Robert+F.+Kennedy")).', 'atom(peop("Sirhan+Sirhan")).', 'atom(kill("Sirhan+Sirhan", "Robert+F.+Kennedy")).', 'atom(kill("George+Shibley", "Robert+F.+Kennedy")).']
# =======================================
# 627 ['atom(peop("Baruch+Arensberg")).', 'atom(loc("Tel+Aviv+Univerisity")).', 'atom(loc("Israel.")).', 'atom(workFor("Baruch+Arensberg", "Tel+Aviv+Univerisity")).']
# 627 ['atom(peop("Baruch+Arensberg")).', 'atom(loc("Tel+Aviv")).', 'atom(loc("Israel.")).', 'atom(liveIn("Baruch+Arensberg", "Tel+Aviv")).']
# =======================================
# 630 ['atom(peop("Pramot")).', 'atom(peop("Suraphong+Khemasingkhi")).', 'atom(org("BPP")).', 'atom(org("BPP")).', 'atom(workFor("Suraphong+Khemasingkhi", "BPP")).']
# 630 ['atom(peop("Pramot")).', 'atom(org("Police")).', 'atom(peop("Suraphong+Khemasingkhi")).', 'atom(org("BPP")).', 'atom(workFor("Suraphong+Khemasingkhi", "BPP")).']
# =======================================
# 631 ['atom(other("11+April")).', 'atom(loc("Jakarta")).', 'atom(org("BISNIS+INDONESIA")).', 'atom(other("East+Asian+Growth+Area")).', 'atom(loc("Indonesia")).', 'atom(loc("Sabah")).', 'atom(loc("Sarawak")).', 'atom(loc("Brunei")).', 'atom(loc("Mindanao+islands")).', 'atom(loc("Philippines")).', 'atom(loc("Indonesia")).', 'atom(locatedIn("Mindanao+islands", "Philippines")).', 'atom(orgbasedIn("BISNIS+INDONESIA", "Jakarta")).']
# 631 ['atom(other("11+April+Jakarta+BISNIS+INDONESIA")).', 'atom(org("East+Asian+Growth+Area")).', 'atom(loc("Indonesia")).', 'atom(loc("Sarawak")).', 'atom(loc("Brunei")).', 'atom(loc("Mindanao+islands")).', 'atom(loc("Philippines")).', 'atom(loc("Indonesia")).', 'atom(locatedIn("Mindanao+islands", "Philippines")).']
# =======================================
# 633 ['atom(org("SOVETSKAYA+ROSSIA")).', 'atom(loc("Russia")).', 'atom(org("Russian")).', 'atom(loc("Kremlin")).']
# 633 ['atom(peop("SOVETSKAYA+ROSSIA")).', 'atom(loc("Russia")).']
# =======================================
# 636 ['atom(loc("Riga")).', 'atom(org("Radio+Riga+Network")).', 'atom(other("1700+GMT")).', 'atom(other("7+Jun+94")).', 'atom(orgbasedIn("Radio+Riga+Network", "Riga")).']
# 636 ['atom(loc("Riga")).', 'atom(org("Radio")).', 'atom(loc("Riga+Network")).', 'atom(other("1700+GMT")).', 'atom(other("7+Jun+94")).', 'atom(orgbasedIn("Radio", "Riga")).', 'atom(orgbasedIn("Riga+Network", "Riga")).']
# =======================================
# 637 ['atom(peop("Lord+Moyne")).', 'atom(peop("Folke+Bernadotte.")).']
# 637 ['atom(peop("Lehi")).', 'atom(org("Stern+Gang")).', 'atom(peop("Lord+Moyne")).', 'atom(peop("Folke+Bernadotte.")).', 'atom(workFor("Lehi", "Stern+Gang")).', 'atom(workFor("Folke+Bernadotte.", "Stern+Gang")).']
# =======================================
# 638 ['atom(org("Japan+Renewal+Party")).', 'atom(peop("Takeshi+Sasaki")).', 'atom(loc("Tokyo+University")).', 'atom(other("13+February")).', 'atom(peop("Shoichi+Oikawa")).', 'atom(org("YOMIURI+SHIMBUN")).', 'atom(org("YOMIURI+SHIMBUN")).', 'atom(peop("Ichiro+Ozawa")).', 'atom(org("Shinseito")).', 'atom(other("13+February")).', 'atom(workFor("Shoichi+Oikawa", "YOMIURI+SHIMBUN")).', 'atom(workFor("Takeshi+Sasaki", "Tokyo+University")).', 'atom(workFor("Ichiro+Ozawa", "Shinseito")).']
# 638 ['atom(loc("Japan")).', 'atom(org("Renewal+Party")).', 'atom(peop("Takeshi+Sasaki")).', 'atom(loc("Tokyo+University")).', 'atom(other("13+February")).', 'atom(peop("Shoichi+Oikawa")).', 'atom(org("YOMIURI+SHIMBUN")).', 'atom(peop("YOMIURI+SHIMBUN")).', 'atom(peop("YOMIURI+SHIMBUN")).', 'atom(peop("Ichiro+Ozawa")).', 'atom(other("13+February")).', 'atom(workFor("Shoichi+Oikawa", "YOMIURI+SHIMBUN")).', 'atom(workFor("Takeshi+Sasaki", "Tokyo+University")).', 'atom(orgbasedIn("Renewal+Party", "Japan")).']
# =======================================
# 640 ['atom(peop("Wang+Shaohua")).', 'atom(loc("China")).', 'atom(loc("San+Francisco")).', 'atom(loc("China.")).', 'atom(liveIn("Wang+Shaohua", "San+Francisco")).', 'atom(locatedIn("San+Francisco", "China")).', 'atom(liveIn("Wang+Shaohua", "China")).']
# 640 ['atom(peop("Wang+Shaohua")).', 'atom(loc("China")).', 'atom(loc("San+Francisco")).', 'atom(loc("China.")).', 'atom(liveIn("Wang+Shaohua", "China")).', 'atom(liveIn("Wang+Shaohua", "China.")).']
# =======================================
# 644 ['atom(loc("Geneva")).', 'atom(peop("Ejup+Ganic")).', 'atom(org("TV")).']
# 644 ['atom(loc("Geneva")).', 'atom(peop("Ejup+Ganic")).', 'atom(loc("Bosnia-Herzegovina+Radio")).']
# =======================================
# 645 ['atom(org("Eaglebrook+East")).', 'atom(loc("Middletown")).', 'atom(orgbasedIn("Eaglebrook+East", "Middletown")).']
# 645 ['atom(org("Eaglebrook+East")).', 'atom(loc("Middletown")).', 'atom(liveIn("Eaglebrook+East", "Middletown")).']
# =======================================

# %%
k = 75
all_atoms1[k]
# Out:
# ['Loc(Cape+Town)',
#  'Org(Supreme+Court)',
#  'Peop(J.H.+Berman)',
#  'Loc(Port+Nolloth)',
#  'Work_For(J.H.+Berman, Cape+Town)',
#  'Live_In(J.H.+Berman, Port+Nolloth)',
#  'Work_For(J.H.+Berman, Supreme+Court)']

# %%
'Loc(Cape+Town)', 
'Org(Supreme+Court)', 
'Peop(J.H.+Berman)', 
'Loc(Port+Nolloth)', 
'Work_For(J.H.+Berman, Supreme+Court)', 
'OrgBased_In(Supreme+Court, Cape+Town)', 
'Live_In(J.H.+Berman, Port+Nolloth)'

# %%
print('entities: ', pred1[k]['entity_gts'])
print('==========================')
print('relations: ', pred1[k]['relation_gts'])
# Out:
# entities:  [[0, 2, 'Loc', 'Cape Town'], [2, 4, 'Org', 'Supreme Court'], [5, 7, 'Peop', 'J.H. Berman'], [10, 12, 'Loc', 'Port Nolloth']]
# ==========================
# relations:  [[2, 4, 0, 2, 'OrgBased_In', 'Supreme Court', 'Cape Town'], [5, 7, 0, 2, 'Live_In', 'J.H. Berman', 'Cape Town'], [5, 7, 2, 4, 'Work_For', 'J.H. Berman', 'Supreme Court']]

# %%
pred1[k]
# Out:
# {'tokens': ['Meanwhile',
#   ',',
#   'Shi',
#   'Liming',
#   'at',
#   'the',
#   'Institute',
#   'of',
#   'Zoology',
#   'of',
#   'Kunming',
#   'found',
#   'that',
#   'pandas',
#   'lack',
#   'variety',
#   'in',
#   'their',
#   'protein',
#   'heredity',
#   ',',
#   'which',
#   'may',
#   'serve',
#   'as',
#   'one',
#   'of',
#   'the',
#   'major',
#   'reasons',
#   'for',
#   'pandas',
#   "'",
#   'near',
#   'extinction',
#   '.'],
#  'entities': [[2, 4, 'Peop'], [10, 11, 'Loc']],
#  'relations': [[2, 4, 10, 11, 'Live_In']],
#  'entity_gts': [[2, 4, 'Peop', 'Shi Liming'],
#   [6, 9, 'Org', 'Institute of Zoology'],
#   [10, 11, 'Loc', 'Kunming']],
#  'relation_gts': [[2,
#    4,
#    6,
#    9,
#    'Work_For',
#    'Shi Liming',
#    'Institute of Zoology'],
#   [6, 9, 10, 11, 'OrgBased_In', 'Institute of Zoology', 'Kunming']],
#  'entities_': [[2, 4, 'Peop', 'Shi Liming', [1.0, 1.0]],
#   [10, 11, 'Loc', 'Kunming', [1.0]]],
#  'relations_': [[2,
#    4,
#    10,
#    11,
#    'Live_In',
#    'Shi Liming',
#    'Kunming',
#    [[0.9999998807907104], [1.0]]]],
#  'agg_probs': 0.999202311038971}
