# %%
import pandas as pd
import numpy as np
from tqdm import tqdm
import matplotlib.pyplot as plt
import random

# %%
def standardize_data(data):
    for row in data:
        tokens = row['tokens']
        for entity in row['entities']:
            entity.append(' '.join(tokens[entity[0]: entity[1]]))
        for relation in row['relations']:
            relation.append(' '.join(tokens[relation[0]: relation[1]]))
            relation.append(' '.join(tokens[relation[2]: relation[3]]))
    return data

# %%
with open('../asp/satisfiable.lp') as f:
    satisfiable_program = f.read()

# %%
with open('../asp/inference.lp') as f:
    inference_program = f.read()

# %%
with open('conll04_10_fold_10_unlabeled_prediction.json', 'r') as f:
    data = standardize_data(json.load(f))
# with open('conll04_10_fold_10_unlabeled_prediction.json', 'r') as f:
#     fold9 = json.load(f)
# with open('conll04_10_fold_10_unlabeled_prediction.json', 'r') as f:
#     fold8 = json.load(f)
# with open('conll04_10_fold_10_unlabeled_prediction.json', 'r') as f:
#     fold7 = json.load(f)
# with open('conll04_10_fold_10_unlabeled_prediction.json', 'r') as f:
#     fold6 = json.load(f)

# %%
import json
import subprocess
import ast

clingo_path = 'clingo'
clingo_options = ['--outf=2', '-n 0']
clingo_command = [clingo_path] + clingo_options

drive_command = ['clingo', '../asp/compute.lp',
                 '../asp/p2.lp', '../asp/p3.lp', '--outf=3']


def solve(program):
    input = program.encode()
    process = subprocess.Popen(clingo_command, stdin=subprocess.PIPE, stderr=subprocess.PIPE, stdout=subprocess.PIPE)
    output, error = process.communicate(input)
    result = json.loads(output.decode())
    if result['Result'] == 'SATISFIABLE' or result['Result'] == 'OPTIMUM FOUND':
        solutions = [value['Value'] for value in result['Call'][0]['Witnesses']]
        return union_all_solutions(solutions)
    else:
        return None
    
    
def solve_v2(program):
    # Write the program to a file
    with open('../asp/p3.lp', 'w') as f:
        f.write(program)
    process = subprocess.Popen(drive_command, stdin=subprocess.PIPE, stderr=subprocess.PIPE, stdout=subprocess.PIPE)
    output, error = process.communicate()
    result = ast.literal_eval(output.decode().split('\n')[-2])
    return result

# %%
def concat_facts(es, rs):
    output = []
    for e in es:
        output.append(e)
    for r in rs:
        output.append(r)
    return '\n'.join(output)

def union_all_solutions(solutions):
    union = set()
    for solution in solutions:
        for atom in solution:
            if not atom.startswith('nOfOKAtoms'):
                union.add(atom)
    return list(union)

def format_for_asp(s, type):
    if type == 'entity':
        return s.lower()
    else:
        splits = s.split('_')
        if len(splits) > 1:
            return '{}{}'.format(splits[0].lower(), splits[1].capitalize())
        return splits[0].lower()
    
def convert_original_to_atoms(data, dtype, wrap=True):
    result = []
    for d in data:
        if dtype == 'entity':
            if wrap:
                e = 'atom({}("{}")).'.format(format_for_asp(d[2], 'entity'),
                                             str(d[0]) + '+' + str(d[1]))
            else:
                e = '{}("{}").'.format(format_for_asp(d[2], 'entity'),
                                       str(d[0]) + '+' + str(d[1]))
            result.append(e)
        else:
            if wrap:
                r = 'atom({}("{}","{}")).'.format(format_for_asp(d[4], 'relation'),
                                             str(d[0]) + '+' + str(d[1]), str(d[2]) + '+' + str(d[3]))
            else:
                r = '{}("{}","{}").'.format(format_for_asp(d[4], 'relation'),
                                            str(d[0]) + '+' + str(d[1]), str(d[2]) + '+' + str(d[3]))
            result.append(r)
    return result


def convert_solutions_back(solution):
    es = []
    rs = []
    for atom in solution:
        atom = atom.replace('ok(', '', 1).replace(')', '', 1) + '.'
        if atom.startswith('loc(') or atom.startswith('peop(') or \
                atom.startswith('org(') or atom.startswith('other('):
            es.append(atom)
        else:
            rs.append(atom)
    return es, rs

# %%
def is_consistent(entities, relations, satisfiable_program, model_type, wrap=False):
    assert model_type in ['twoone', 'spert']
    if model_type == 'spert':
        entities = spert_to_twoone(entities, relations, 'entity')
        relations = spert_to_twoone(entities, relations, 'relation')

    e_atoms = convert_original_to_atoms(entities, 'entity', wrap)
    r_atoms = convert_original_to_atoms(relations, 'relation', wrap)
    program = satisfiable_program + '\n' + concat_facts(e_atoms, r_atoms)
    solution = solve(program)
    if solution:
        return True
    return False

# %%
def is_inferable(entities, relations, inference_program, model_type, wrap=False):
    assert model_type in ['twoone', 'spert']
    if model_type == 'spert':
        entities = spert_to_twoone(entities, relations, 'entity')
        relations = spert_to_twoone(entities, relations, 'relation')

    e_atoms = convert_original_to_atoms(entities, 'entity', wrap)
    r_atoms = convert_original_to_atoms(relations, 'relation', wrap)
    program = inference_program + '\n' + concat_facts(e_atoms, r_atoms)
    solution = solve(program)
    return len(solution) > len(entities) + len(relations)

# %%
def verify_and_infer(entities, relations, inference_program, model_type):
    assert model_type in ['twoone', 'spert']
    if model_type == 'spert':
        entities = spert_to_twoone(entities, relations, 'entity')
        relations = spert_to_twoone(entities, relations, 'relation')
    final_outputs = []
    # Remove connected components
    e_atoms = convert_original_to_atoms(entities, 'entity')
    r_atoms = convert_original_to_atoms(relations, 'relation')
    program = concat_facts(e_atoms, r_atoms)
    answer_sets = solve_v2(program)
    for answer_set in answer_sets:
        es, rs = convert_solutions_back(answer_set)
        # Inference starts here
        program = inference_program + '\n' + concat_facts(es, rs)
        solution = solve(program)
        if not solution:
            continue
        solution = ['ok(' + atom + ')' for atom in solution]
        es, rs = convert_solutions_back(solution)
        # Inference ends here
        final_outputs.append(es + rs)
    return final_outputs, e_atoms + r_atoms

# %%
sample = data[0]

# %%
sample
# Out:
# {'tokens': ['Newspaper',
#   '`',
#   'Explains',
#   "'",
#   'U.S.',
#   'Interests',
#   'Section',
#   'Events',
#   'FL1402001894',
#   'Havana',
#   'Radio',
#   'Reloj',
#   'Network',
#   'in',
#   'Spanish',
#   '2100',
#   'GMT',
#   '13',
#   'Feb',
#   '94'],
#  'entities': [[4, 5, 'Loc', 'U.S.'],
#   [9, 10, 'Loc', 'Havana'],
#   [10, 13, 'Org', 'Radio Reloj Network'],
#   [15, 17, 'Other', '2100 GMT'],
#   [17, 20, 'Other', '13 Feb 94']],
#  'relations': [[10, 13, 9, 10, 'OrgBased_In', 'Radio Reloj Network', 'Havana'],
#   [10, 13, 4, 5, 'OrgBased_In', 'Radio Reloj Network', 'U.S.']],
#  'entity_gts': [[4, 5, 'Loc', 'U.S.'],
#   [9, 10, 'Loc', 'Havana'],
#   [10, 13, 'Org', 'Radio Reloj Network'],
#   [15, 17, 'Other', '2100 GMT'],
#   [17, 20, 'Other', '13 Feb 94']],
#  'relation_gts': [[10,
#    13,
#    9,
#    10,
#    'OrgBased_In',
#    'Radio Reloj Network',
#    'Havana']]}

# %%
is_consistent(sample['entities'], sample['relations'], satisfiable_program, 'twoone')
# Out:
# True

# %%
len(sample['entities']) + len(sample['relations'])
# Out:
# 7

# %%
is_inferable(sample['entities'], sample['relations'], inference_program, 'twoone')
# Out:
# False

# %%
def consistent_but_inferable(data):
    num_consistent_but_inferable = 0
    num_inconsistent = 0
    for row in tqdm(data):
        if is_consistent(row['entities'], row['relations'], satisfiable_program, 'twoone'):
            if is_inferable(row['entities'], row['relations'], inference_program, 'twoone'):
                num_consistent_but_inferable += 1
        else:
            num_inconsistent += 1
    return num_consistent_but_inferable, num_inconsistent

# %%
def collect_inconsistent_samples(data):
    inconsistents = []
    indicies = []
    for i, row in enumerate(data):
        if not is_consistent(row['entities'], row['relations'], satisfiable_program, 'twoone'):
            inconsistents.append(row)
            indicies.append(i)
    return inconsistents, indicies

# %%
num_consistent_but_inferable, num_inconsistent = consistent_but_inferable(data)
print('Number of sentences that are consistent but inferable: ', num_consistent_but_inferable)
print('Number of sentences that are inconsistent: ', num_inconsistent)
# Out:
# 100%|██████████| 830/830 [00:08<00:00, 98.80it/s]
# Number of sentences that are consistent but inferable:  0
# Number of sentences that are inconsistent:  43

# %%
def missing_stats(data):
    ...

# %%
def redudant_stats(data):
    ...

# %%
def num_non_empty_entries(data, f1, f2):
    total_lens = []
    for row in data:
        ent_len = 0
        rel_len = 0
        for ent in row[f1]:
            ent_len += ent[1] - ent[0]
        for rel in row[f2]:
            rel_len += (rel[1] - rel[0]) * (rel[3] - rel[2])
        total_lens.append(ent_len + rel_len)
    return total_lens

# %%
total_lens_predicted = num_non_empty_entries(data, 'entities', 'relations')
total_lens_gt = num_non_empty_entries(data, 'entity_gts', 'relation_gts')

# %%
fig, axes = plt.subplots(ncols=2, figsize=(10, 5))
axes[0].hist(total_lens_predicted, bins=30)
axes[1].hist(total_lens_gt, bins=30)
plt.show()

# %%
df = pd.DataFrame({'total_lens_predicted': total_lens_predicted, 
                   'total_lens_gt': total_lens_gt,
                   'sent_len': [len(row['tokens']) for row in data]
                  })

# %%
df.head()
# Out:
#    total_lens_predicted  total_lens_gt  sent_len
# 0                    16             13        20
# 1                     3             20        50
# 2                     6              8        32
# 3                    17             49        25
# 4                     8             11        22

# %%
df.describe()
# Out:
#        total_lens_predicted  total_lens_gt
# count            830.000000     830.000000
# mean               9.255422      12.203614
# std                5.495019       7.946032
# min                0.000000       3.000000
# 25%                5.000000       7.000000
# 50%                8.000000      10.000000
# 75%               12.000000      16.000000
# max               41.000000      83.000000

# %%
np.corrcoef(df['total_lens_predicted'], df['sent_len'])
# Out:
# array([[1.        , 0.32988423],
#        [0.32988423, 1.        ]])

# %%
np.corrcoef(df['total_lens_gt'], df['sent_len'])
# Out:
# array([[1.        , 0.46573011],
#        [0.46573011, 1.        ]])

# %%
def num_atoms_per_sentences(data):
    num_entities = []
    num_relations = []
    num_gt_entities = []
    num_gt_relations = []
    for row in tqdm(data):
        num_entities.append(len(row['entities']))
        num_relations.append(len(row['relations']))
        num_gt_entities.append(len(row['entity_gts']))
        num_gt_relations.append(len(row['relation_gts']))
    return num_entities, num_relations, num_gt_entities, num_gt_relations

# %%
num_entities, num_relations, num_gt_entities, num_gt_relations = num_atoms_per_sentences(data)
# Out:
# 100%|██████████| 830/830 [00:00<00:00, 1200024.93it/s]

# %%
df = pd.DataFrame({'num_entities': num_entities, 'num_relations': num_relations, 
                   'num_gt_entities': num_gt_entities, 'num_gt_relations': num_gt_relations})

# %%
df.describe()
# Out:
#        num_entities  num_relations  num_gt_entities  num_gt_relations
# count    830.000000     830.000000       830.000000        830.000000
# mean       3.539759       1.159036         3.687952          1.401205
# std        1.753916       0.919568         1.829981          0.946964
# min        0.000000       0.000000         2.000000          1.000000
# 25%        2.000000       1.000000         2.000000          1.000000
# 50%        3.000000       1.000000         3.000000          1.000000
# 75%        4.000000       1.000000         4.000000          1.000000
# max       24.000000       6.000000        24.000000         10.000000

# %%
fig, axes = plt.subplots(ncols=4, figsize=(20, 5))

axes[0].hist(num_entities, bins=10)
axes[1].hist(num_relations, bins=10)
axes[2].hist(num_gt_entities, bins=10)
axes[3].hist(num_gt_relations, bins=10)
plt.show()

# %%
print(np.mean(num_entities))
print(np.mean(num_relations))
print(np.mean(num_gt_entities))
print(np.mean(num_gt_relations))
# Out:
# 3.539759036144578
# 1.1590361445783133
# 3.6879518072289157
# 1.4012048192771085

# %%
inconsistents, indicies = collect_inconsistent_samples(data)

# %%
inconsistents
# Out:
# [{'tokens': ['DIMA',
#    "'s",
#    'technical',
#    'manager',
#    ',',
#    'engineer',
#    'Jose',
#    'Tulio',
#    'Gomez',
#    ',',
#    'said',
#    'that',
#    'in',
#    'addition',
#    'to',
#    'industrial',
#    'wastes',
#    ',',
#    'the',
#    'rivers',
#    'are',
#    'also',
#    'contaminated',
#    'by',
#    'human',
#    'waste',
#    ',',
#    'and',
#    'diesel',
#    'and',
#    'petroleum',
#    'residues',
#    'discarded',
#    'by',
#    'a',
#    'number',
#    'of',
#    'factories',
#    '.'],
#   'entities': [[0, 1, 'Org', 'DIMA'], [6, 9, 'Peop', 'Jose Tulio Gomez']],
#   'relations': [[6, 9, 0, 1, 'Live_In', 'Jose Tulio Gomez', 'DIMA']],
#   'entity_gts': [[0, 1, 'Org', 'DIMA'], [6, 9, 'Peop', 'Jose Tulio Gomez']],
#   'relation_gts': [[6, 9, 0, 1, 'Work_For', 'Jose Tulio Gomez', 'DIMA']]},
#  {'tokens': ['`',
#    '`',
#    'There',
#    'is',
#    'a',
#    'great',
#    'demand',
#    'for',
#    'recovered',
#    'plastic',
#    ',',
#    'but',
#    'the',
#    'material',
#    'has',
#    'to',
#    'be',
#    'clean',
#    ',',
#    "'",
#    "'",
#    'said',
#    'Andrew',
#    'Stephens',
#    ',',
#    'president',
#    'of',
#    'Eaglebrook',
#    'Plastics',
#    '.'],
#   'entities': [[22, 24, 'Peop', 'Andrew Stephens'],
#    [27, 29, 'Org', 'Eaglebrook Plastics']],
#   'relations': [[22,
#     24,
#     27,
#     29,
#     'Live_In',
#     'Andrew Stephens',
#     'Eaglebrook Plastics']],
#   'entity_gts': [[22, 24, 'Peop', 'Andrew Stephens'],
#    [27, 29, 'Org', 'Eaglebrook Plastics']],
#   'relation_gts': [[22,
#     24,
#     27,
#     29,
#     'Work_For',
#     'Andrew Stephens',
#     'Eaglebrook Plastics']]},
#  {'tokens': ['Carbondale',
#    'Mining',
#    'Technology',
#    'Center',
#    ',',
#    'Carterville',
#    ',',
#    'Ill.',
#    ';'],
#   'entities': [[0, 1, 'Org', 'Carbondale'],
#    [5, 6, 'Loc', 'Carterville'],
#    [7, 8, 'Loc', 'Ill.']],
#   'relations': [[0, 1, 7, 8, 'Located_In', 'Carbondale', 'Ill.'],
#    [5, 6, 7, 8, 'Located_In', 'Carterville', 'Ill.']],
#   'entity_gts': [[0, 4, 'Loc', 'Carbondale Mining Technology Center'],
#    [5, 6, 'Loc', 'Carterville'],
#    [7, 8, 'Loc', 'Ill.']],
#   'relation_gts': [[0,
#     4,
#     5,
#     6,
#     'Located_In',
#     'Carbondale Mining Technology Center',
#     'Carterville'],
#    [0, 4, 7, 8, 'Located_In', 'Carbondale Mining Technology Center', 'Ill.'],
#    [5, 6, 7, 8, 'Located_In', 'Carterville', 'Ill.']]},
#  {'tokens': ['In',
#    'San',
#    'Diego',
#    'County',
#    ',',
#    'a',
#    '50-acre',
#    'fire',
#    'fanned',
#    'by',
#    '60',
#    'mph',
#    'winds',
#    'burned',
#    'out',
#    'of',
#    'control',
#    'Thursday',
#    'afternoon',
#    'near',
#    'the',
#    'city',
#    'of',
#    'Ramona',
#    ',',
#    'the',
#    'California',
#    'Department',
#    'of',
#    'Forestry',
#    'reported',
#    '.'],
#   'entities': [[1, 3, 'Loc', 'San Diego'],
#    [10, 11, 'Other', '60'],
#    [23, 24, 'Loc', 'Ramona'],
#    [26, 28, 'Org', 'California Department']],
#   'relations': [[23,
#     24,
#     26,
#     28,
#     'Located_In',
#     'Ramona',
#     'California Department']],
#   'entity_gts': [[1, 3, 'Loc', 'San Diego'],
#    [10, 12, 'Other', '60 mph'],
#    [23, 24, 'Loc', 'Ramona'],
#    [26, 30, 'Org', 'California Department of Forestry']],
#   'relation_gts': [[23, 24, 1, 3, 'Located_In', 'Ramona', 'San Diego']]},
#  {'tokens': ['In',
#    'a',
#    'bizarre',
#    'allegation',
#    ',',
#    'Anderson',
#    'said',
#    'the',
#    'same',
#    'photo',
#    'analysts',
#    'also',
#    'concluded',
#    'that',
#    'a',
#    'picture',
#    'of',
#    'three',
#    'hobos',
#    'near',
#    'the',
#    'shooting',
#    'scene',
#    'taken',
#    'shortly',
#    'after',
#    'the',
#    'killing',
#    'appear',
#    'to',
#    'show',
#    'Watergate',
#    'conspirator',
#    'E.',
#    'Howard',
#    'Hunt',
#    'and',
#    'James',
#    'Earl',
#    'Ray',
#    ',',
#    'the',
#    'killer',
#    'of',
#    'Martin',
#    'Luther',
#    'King',
#    'Jr',
#    '.'],
#   'entities': [[5, 6, 'Peop', 'Anderson'],
#    [31, 32, 'Other', 'Watergate'],
#    [33, 36, 'Peop', 'E. Howard Hunt'],
#    [37, 40, 'Peop', 'James Earl Ray'],
#    [44, 48, 'Org', 'Martin Luther King Jr']],
#   'relations': [[37,
#     40,
#     44,
#     48,
#     'Kill',
#     'James Earl Ray',
#     'Martin Luther King Jr']],
#   'entity_gts': [[5, 6, 'Peop', 'Anderson'],
#    [31, 32, 'Other', 'Watergate'],
#    [33, 36, 'Peop', 'E. Howard Hunt'],
#    [37, 40, 'Peop', 'James Earl Ray'],
#    [44, 48, 'Peop', 'Martin Luther King Jr']],
#   'relation_gts': [[37,
#     40,
#     44,
#     48,
#     'Kill',
#     'James Earl Ray',
#     'Martin Luther King Jr']]},
#  {'tokens': ['"',
#    'We',
#    'didn',
#    "'t",
#    'get',
#    'a',
#    'lot',
#    'of',
#    'the',
#    'test',
#    'objectives',
#    'done',
#    ',',
#    '"',
#    'Col.',
#    'Harold',
#    'Richardson',
#    'of',
#    'the',
#    'U.S.',
#    'Strategic',
#    'Defense',
#    'Initiative',
#    'Office',
#    'told',
#    'the',
#    'U.S.',
#    'magazine',
#    'Defense',
#    'News',
#    '.'],
#   'entities': [[15, 17, 'Peop', 'Harold Richardson'],
#    [19, 23, 'Loc', 'U.S. Strategic Defense Initiative'],
#    [26, 27, 'Loc', 'U.S.']],
#   'relations': [[15,
#     17,
#     19,
#     23,
#     'Work_For',
#     'Harold Richardson',
#     'U.S. Strategic Defense Initiative'],
#    [19,
#     23,
#     26,
#     27,
#     'OrgBased_In',
#     'U.S. Strategic Defense Initiative',
#     'U.S.']],
#   'entity_gts': [[15, 17, 'Peop', 'Harold Richardson'],
#    [19, 24, 'Org', 'U.S. Strategic Defense Initiative Office'],
#    [26, 27, 'Loc', 'U.S.'],
#    [28, 30, 'Other', 'Defense News']],
#   'relation_gts': [[15,
#     17,
#     19,
#     24,
#     'Work_For',
#     'Harold Richardson',
#     'U.S. Strategic Defense Initiative Office']]},
#  {'tokens': ['`',
#    '`',
#    'Weather',
#    'like',
#    'this',
#    'is',
#    'awful',
#    'for',
#    'restaurants',
#    ',',
#    "'",
#    "'",
#    'said',
#    'Lou',
#    'Ray',
#    ',',
#    'owner',
#    'of',
#    'the',
#    'Smokehouse',
#    'cafe',
#    'in',
#    'Fontana',
#    '.'],
#   'entities': [[13, 15, 'Peop', 'Lou Ray'],
#    [19, 21, 'Org', 'Smokehouse cafe'],
#    [22, 23, 'Loc', 'Fontana']],
#   'relations': [[13, 15, 19, 21, 'Live_In', 'Lou Ray', 'Smokehouse cafe'],
#    [19, 21, 22, 23, 'Located_In', 'Smokehouse cafe', 'Fontana'],
#    [13, 15, 22, 23, 'Live_In', 'Lou Ray', 'Fontana']],
#   'entity_gts': [[13, 15, 'Peop', 'Lou Ray'], [22, 23, 'Loc', 'Fontana']],
#   'relation_gts': [[13, 15, 22, 23, 'Live_In', 'Lou Ray', 'Fontana']]},
#  {'tokens': ['944E0738B',
#    'Moscow',
#    'PRAVDA',
#    'in',
#    'Russia',
#    '21',
#    'Apr',
#    '94',
#    'p',
#    '2'],
#   'entities': [[1, 3, 'Loc', 'Moscow PRAVDA'],
#    [4, 5, 'Loc', 'Russia'],
#    [5, 8, 'Other', '21 Apr 94']],
#   'relations': [[1, 3, 4, 5, 'OrgBased_In', 'Moscow PRAVDA', 'Russia']],
#   'entity_gts': [[1, 2, 'Loc', 'Moscow'],
#    [2, 3, 'Org', 'PRAVDA'],
#    [4, 5, 'Loc', 'Russia'],
#    [5, 8, 'Other', '21 Apr 94']],
#   'relation_gts': [[1, 2, 4, 5, 'Located_In', 'Moscow', 'Russia'],
#    [2, 3, 1, 2, 'OrgBased_In', 'PRAVDA', 'Moscow'],
#    [2, 3, 4, 5, 'OrgBased_In', 'PRAVDA', 'Russia']]},
#  {'tokens': ['David',
#    'Leahy',
#    ',',
#    'elections',
#    'supervisor',
#    'for',
#    'Dade',
#    'County',
#    ',',
#    'said',
#    'his',
#    '18',
#    'percent',
#    'turnout',
#    'projection',
#    'was',
#    'a',
#    'guess',
#    'because',
#    'there',
#    'hasn',
#    "'t",
#    'been',
#    'a',
#    'special',
#    'congressional',
#    'election',
#    'in',
#    'recent',
#    'history',
#    ',',
#    'and',
#    'never',
#    'in',
#    'August',
#    ',',
#    'a',
#    'vacation',
#    'month.'],
#   'entities': [[0, 2, 'Peop', 'David Leahy'],
#    [6, 8, 'Org', 'Dade County'],
#    [11, 13, 'Other', '18 percent'],
#    [34, 35, 'Other', 'August']],
#   'relations': [[0, 2, 6, 8, 'Live_In', 'David Leahy', 'Dade County']],
#   'entity_gts': [[0, 2, 'Peop', 'David Leahy'],
#    [6, 8, 'Loc', 'Dade County'],
#    [11, 13, 'Other', '18 percent']],
#   'relation_gts': [[0, 2, 6, 8, 'Live_In', 'David Leahy', 'Dade County']]},
#  {'tokens': ['On',
#    'Monday',
#    ',',
#    'the',
#    'nation',
#    'will',
#    'observe',
#    'the',
#    'birthday',
#    'of',
#    'Martin',
#    'Luther',
#    'King',
#    'Jr.',
#    ',',
#    'who',
#    'was',
#    'cut',
#    'down',
#    'by',
#    'assassin',
#    'James',
#    'Earl',
#    'Ray',
#    'in',
#    '1968',
#    '.'],
#   'entities': [[10, 14, 'Org', 'Martin Luther King Jr.'],
#    [21, 24, 'Peop', 'James Earl Ray']],
#   'relations': [[21,
#     24,
#     10,
#     14,
#     'Kill',
#     'James Earl Ray',
#     'Martin Luther King Jr.']],
#   'entity_gts': [[1, 2, 'Other', 'Monday'],
#    [10, 14, 'Peop', 'Martin Luther King Jr.'],
#    [21, 24, 'Peop', 'James Earl Ray']],
#   'relation_gts': [[21,
#     24,
#     10,
#     14,
#     'Kill',
#     'James Earl Ray',
#     'Martin Luther King Jr.']]},
#  {'tokens': ['Also',
#    'on',
#    'Thursday',
#    ',',
#    'Knight-Ridder',
#    'announced',
#    'that',
#    'it',
#    'has',
#    'named',
#    'Larry',
#    'Jinks',
#    'publisher',
#    'of',
#    'the',
#    'San',
#    'Jose',
#    'Mercury',
#    'News',
#    ',',
#    'succeeding',
#    'William',
#    'A.',
#    'Ott',
#    ',',
#    'who',
#    'will',
#    'be',
#    'the',
#    'newspaper',
#    "'s",
#    'chairman',
#    '.'],
#   'entities': [[10, 12, 'Peop', 'Larry Jinks'],
#    [15, 19, 'Loc', 'San Jose Mercury News'],
#    [21, 24, 'Peop', 'William A. Ott']],
#   'relations': [[10,
#     12,
#     15,
#     19,
#     'Work_For',
#     'Larry Jinks',
#     'San Jose Mercury News']],
#   'entity_gts': [[4, 5, 'Org', 'Knight-Ridder'],
#    [10, 12, 'Peop', 'Larry Jinks'],
#    [15, 19, 'Org', 'San Jose Mercury News'],
#    [21, 24, 'Peop', 'William A. Ott']],
#   'relation_gts': [[10, 12, 4, 5, 'Work_For', 'Larry Jinks', 'Knight-Ridder'],
#    [10, 12, 15, 19, 'Work_For', 'Larry Jinks', 'San Jose Mercury News'],
#    [21, 24, 4, 5, 'Work_For', 'William A. Ott', 'Knight-Ridder'],
#    [21, 24, 15, 19, 'Work_For', 'William A. Ott', 'San Jose Mercury News']]},
#  {'tokens': ['Brazil',
#    ':',
#    'Brazilian',
#    'Space',
#    'Program',
#    'Summarized',
#    '94WS0145A',
#    'Sao',
#    'Paulo',
#    'GAZETA',
#    'MERCANTIL',
#    'in',
#    'Portuguese',
#    '27-29',
#    'Nov',
#    '93',
#    'p',
#    '5'],
#   'entities': [[0, 1, 'Loc', 'Brazil'],
#    [3, 5, 'Org', 'Space Program'],
#    [7, 11, 'Loc', 'Sao Paulo GAZETA MERCANTIL'],
#    [13, 16, 'Other', '27-29 Nov 93']],
#   'relations': [[3, 5, 0, 1, 'OrgBased_In', 'Space Program', 'Brazil'],
#    [7, 11, 0, 1, 'OrgBased_In', 'Sao Paulo GAZETA MERCANTIL', 'Brazil']],
#   'entity_gts': [[7, 9, 'Loc', 'Sao Paulo'],
#    [9, 11, 'Org', 'GAZETA MERCANTIL'],
#    [13, 16, 'Other', '27-29 Nov 93']],
#   'relation_gts': [[9,
#     11,
#     7,
#     9,
#     'OrgBased_In',
#     'GAZETA MERCANTIL',
#     'Sao Paulo']]},
#  {'tokens': ['John',
#    'Ray',
#    ',',
#    'a',
#    'member',
#    'of',
#    'the',
#    'District',
#    'of',
#    'Columbia',
#    'Council',
#    ',',
#    'reported',
#    'raising',
#    '$218',
#    ',',
#    '592',
#    'from',
#    'January',
#    'to',
#    'July',
#    'in',
#    'his',
#    'bid',
#    'for',
#    'the',
#    'Democratic',
#    'nomination',
#    ',',
#    'according',
#    'to',
#    'records',
#    'filed',
#    'with',
#    'the',
#    'city',
#    "'s",
#    'office',
#    'of',
#    'campaign',
#    'finance.'],
#   'entities': [[0, 2, 'Peop', 'John Ray'],
#    [7, 8, 'Org', 'District'],
#    [14, 17, 'Other', '$218 , 592'],
#    [18, 19, 'Other', 'January'],
#    [20, 21, 'Other', 'July']],
#   'relations': [[0, 2, 7, 8, 'Live_In', 'John Ray', 'District']],
#   'entity_gts': [[0, 2, 'Peop', 'John Ray'],
#    [7, 11, 'Org', 'District of Columbia Council'],
#    [14, 17, 'Other', '$218 , 592'],
#    [26, 27, 'Org', 'Democratic']],
#   'relation_gts': [[0,
#     2,
#     7,
#     11,
#     'Work_For',
#     'John Ray',
#     'District of Columbia Council']]},
#  {'tokens': ['`',
#    '`',
#    'We',
#    'chose',
#    'Middletown',
#    'because',
#    'we',
#    "'re",
#    'trying',
#    'to',
#    'access',
#    'the',
#    'New',
#    'York',
#    'City',
#    'market',
#    'but',
#    'we',
#    'wanted',
#    'to',
#    'be',
#    'outside',
#    'the',
#    'high-priced',
#    'metropolitan',
#    'area',
#    ',',
#    "'",
#    "'",
#    'said',
#    'Robert',
#    'Thompson',
#    ',',
#    'Eaglebrook',
#    "'s",
#    'vice',
#    '.'],
#   'entities': [[4, 5, 'Loc', 'Middletown'],
#    [12, 15, 'Loc', 'New York City'],
#    [30, 32, 'Peop', 'Robert Thompson'],
#    [33, 34, 'Peop', 'Eaglebrook']],
#   'relations': [[30, 32, 33, 34, 'Live_In', 'Robert Thompson', 'Eaglebrook']],
#   'entity_gts': [[12, 15, 'Loc', 'New York City'],
#    [30, 32, 'Peop', 'Robert Thompson'],
#    [33, 34, 'Org', 'Eaglebrook']],
#   'relation_gts': [[30,
#     32,
#     33,
#     34,
#     'Work_For',
#     'Robert Thompson',
#     'Eaglebrook']]},
#  {'tokens': ['U.S.',
#    '(',
#    'USTR',
#    ')',
#    'Mickey',
#    'Kantor',
#    ',',
#    'who',
#    'came',
#    'to',
#    'Japan',
#    'amid',
#    'the',
#    'political',
#    'confusion',
#    'within',
#    'the',
#    'Hosokawa',
#    'administration',
#    'caused',
#    'by',
#    'the',
#    'economic',
#    'stimulation',
#    'plan',
#    ',',
#    'stated',
#    'before',
#    'he',
#    'left',
#    'for',
#    'home',
#    'that',
#    '"',
#    'If',
#    'we',
#    'see',
#    'no',
#    'actual',
#    'results',
#    ',',
#    'we',
#    'might',
#    'have',
#    'to',
#    'consider',
#    'other',
#    'options',
#    '.',
#    '"'],
#   'entities': [[0, 1, 'Loc', 'U.S.'],
#    [2, 3, 'Org', 'USTR'],
#    [4, 6, 'Peop', 'Mickey Kantor'],
#    [10, 11, 'Loc', 'Japan'],
#    [17, 18, 'Peop', 'Hosokawa']],
#   'relations': [[4, 6, 2, 3, 'Live_In', 'Mickey Kantor', 'USTR'],
#    [4, 6, 0, 1, 'Live_In', 'Mickey Kantor', 'U.S.'],
#    [2, 3, 0, 1, 'OrgBased_In', 'USTR', 'U.S.'],
#    [4, 6, 10, 11, 'Live_In', 'Mickey Kantor', 'Japan'],
#    [17, 18, 10, 11, 'Live_In', 'Hosokawa', 'Japan']],
#   'entity_gts': [[0, 1, 'Loc', 'U.S.'],
#    [4, 6, 'Peop', 'Mickey Kantor'],
#    [10, 11, 'Loc', 'Japan'],
#    [17, 18, 'Peop', 'Hosokawa']],
#   'relation_gts': [[4, 6, 0, 1, 'Live_In', 'Mickey Kantor', 'U.S.'],
#    [17, 18, 10, 11, 'Live_In', 'Hosokawa', 'Japan']]},
#  {'tokens': ['Miller',
#    'is',
#    'a',
#    'Wilmington',
#    'native',
#    'who',
#    'was',
#    'recruited',
#    'by',
#    'the',
#    'FBI',
#    'shortly',
#    'after',
#    'graduating',
#    'from',
#    'Brigham',
#    'Young',
#    'University',
#    'in',
#    'Utah',
#    '.'],
#   'entities': [[0, 1, 'Peop', 'Miller'],
#    [3, 4, 'Loc', 'Wilmington'],
#    [10, 11, 'Org', 'FBI'],
#    [15, 18, 'Org', 'Brigham Young University'],
#    [19, 20, 'Loc', 'Utah']],
#   'relations': [[0, 1, 10, 11, 'Work_For', 'Miller', 'FBI'],
#    [15, 18, 19, 20, 'Located_In', 'Brigham Young University', 'Utah'],
#    [0, 1, 3, 4, 'Live_In', 'Miller', 'Wilmington']],
#   'entity_gts': [[0, 1, 'Peop', 'Miller'],
#    [3, 4, 'Loc', 'Wilmington'],
#    [10, 11, 'Org', 'FBI'],
#    [15, 18, 'Org', 'Brigham Young University'],
#    [19, 20, 'Loc', 'Utah']],
#   'relation_gts': [[0, 1, 3, 4, 'Live_In', 'Miller', 'Wilmington']]},
#  {'tokens': ['Fort', 'Hamilton', ',', 'Brooklyn', ',', 'N.Y.', ';'],
#   'entities': [[0, 2, 'Loc', 'Fort Hamilton'],
#    [3, 6, 'Loc', 'Brooklyn , N.Y.']],
#   'relations': [[0, 2, 3, 6, 'Live_In', 'Fort Hamilton', 'Brooklyn , N.Y.']],
#   'entity_gts': [[0, 2, 'Loc', 'Fort Hamilton'],
#    [3, 4, 'Loc', 'Brooklyn'],
#    [5, 6, 'Loc', 'N.Y.']],
#   'relation_gts': [[0, 2, 3, 4, 'Located_In', 'Fort Hamilton', 'Brooklyn'],
#    [0, 2, 5, 6, 'Located_In', 'Fort Hamilton', 'N.Y.'],
#    [3, 4, 5, 6, 'Located_In', 'Brooklyn', 'N.Y.']]},
#  {'tokens': ['Andrews',
#    'Lock',
#    'and',
#    'Dam',
#    ',',
#    'Henry',
#    'County',
#    ',',
#    'Ala.',
#    ';'],
#   'entities': [[0, 2, 'Loc', 'Andrews Lock'],
#    [5, 7, 'Loc', 'Henry County'],
#    [8, 9, 'Loc', 'Ala.']],
#   'relations': [[5, 7, 8, 9, 'Located_In', 'Henry County', 'Ala.'],
#    [0, 2, 8, 9, 'Live_In', 'Andrews Lock', 'Ala.']],
#   'entity_gts': [[0, 4, 'Loc', 'Andrews Lock and Dam'],
#    [5, 7, 'Loc', 'Henry County'],
#    [8, 9, 'Loc', 'Ala.']],
#   'relation_gts': [[0,
#     4,
#     5,
#     7,
#     'Located_In',
#     'Andrews Lock and Dam',
#     'Henry County'],
#    [0, 4, 8, 9, 'Located_In', 'Andrews Lock and Dam', 'Ala.'],
#    [5, 7, 8, 9, 'Located_In', 'Henry County', 'Ala.']]},
#  {'tokens': ['Other',
#    'power',
#    'lines',
#    'brought',
#    'down',
#    'by',
#    'high',
#    'winds',
#    'caused',
#    'outages',
#    'that',
#    'affected',
#    'about',
#    '6',
#    ',',
#    '000',
#    'homes',
#    'and',
#    'businesses',
#    'served',
#    'by',
#    'Southern',
#    'California',
#    'Edison',
#    'in',
#    'Los',
#    'Angeles',
#    'and',
#    'Orange',
#    'counties',
#    ',',
#    'said',
#    'Edison',
#    'spokesman',
#    'Kevin',
#    'Kelly',
#    '.'],
#   'entities': [[25, 27, 'Loc', 'Los Angeles'],
#    [28, 29, 'Loc', 'Orange'],
#    [32, 33, 'Loc', 'Edison'],
#    [34, 36, 'Peop', 'Kevin Kelly']],
#   'relations': [[28, 29, 25, 27, 'Located_In', 'Orange', 'Los Angeles'],
#    [34, 36, 32, 33, 'Work_For', 'Kevin Kelly', 'Edison'],
#    [32, 33, 25, 27, 'Located_In', 'Edison', 'Los Angeles']],
#   'entity_gts': [[21, 24, 'Org', 'Southern California Edison'],
#    [25, 27, 'Loc', 'Los Angeles'],
#    [28, 30, 'Loc', 'Orange counties'],
#    [32, 33, 'Org', 'Edison'],
#    [34, 36, 'Peop', 'Kevin Kelly']],
#   'relation_gts': [[34,
#     36,
#     21,
#     24,
#     'Work_For',
#     'Kevin Kelly',
#     'Southern California Edison'],
#    [34, 36, 32, 33, 'Work_For', 'Kevin Kelly', 'Edison']]},
#  {'tokens': ['The',
#    'rig',
#    ',',
#    'leased',
#    'from',
#    'Avis',
#    'Bourg',
#    'Co.',
#    'of',
#    'Folsom',
#    ',',
#    'had',
#    'left',
#    'a',
#    'Chevron',
#    'worksite',
#    'because',
#    'of',
#    'the',
#    'threat',
#    'of',
#    'Chantal.'],
#   'entities': [[5, 8, 'Org', 'Avis Bourg Co.'],
#    [9, 10, 'Loc', 'Folsom'],
#    [14, 15, 'Loc', 'Chevron']],
#   'relations': [[5, 8, 9, 10, 'Live_In', 'Avis Bourg Co.', 'Folsom']],
#   'entity_gts': [[5, 8, 'Org', 'Avis Bourg Co.'], [9, 10, 'Loc', 'Folsom']],
#   'relation_gts': [[5, 8, 9, 10, 'OrgBased_In', 'Avis Bourg Co.', 'Folsom']]},
#  {'tokens': ['Maricopa',
#    'County',
#    'Superior',
#    'Court',
#    'Judge',
#    'Lindsay',
#    'Ellis',
#    'also',
#    'ordered',
#    'Miss',
#    'Bickel',
#    'to',
#    'pay',
#    '$5',
#    ',',
#    '500',
#    'in',
#    'restitution',
#    'to',
#    'Miss',
#    'Tomazin',
#    "'s",
#    'family',
#    'and',
#    'to',
#    'perform',
#    '40',
#    'hours',
#    'per',
#    'week',
#    'of',
#    'community',
#    'service',
#    'indefinitely',
#    '.'],
#   'entities': [[0, 2, 'Org', 'Maricopa County'],
#    [5, 7, 'Peop', 'Lindsay Ellis'],
#    [9, 11, 'Peop', 'Miss Bickel'],
#    [13, 16, 'Other', '$5 , 500'],
#    [26, 27, 'Other', '40']],
#   'relations': [[5, 7, 0, 2, 'Live_In', 'Lindsay Ellis', 'Maricopa County']],
#   'entity_gts': [[0, 2, 'Loc', 'Maricopa County'],
#    [2, 4, 'Org', 'Superior Court'],
#    [5, 7, 'Peop', 'Lindsay Ellis'],
#    [9, 11, 'Peop', 'Miss Bickel'],
#    [13, 16, 'Other', '$5 , 500'],
#    [19, 21, 'Peop', 'Miss Tomazin']],
#   'relation_gts': [[2,
#     4,
#     0,
#     2,
#     'OrgBased_In',
#     'Superior Court',
#     'Maricopa County'],
#    [5, 7, 2, 4, 'Work_For', 'Lindsay Ellis', 'Superior Court']]},
#  {'tokens': ['In',
#    '1978',
#    ',',
#    'James',
#    'Earl',
#    'Ray',
#    ',',
#    'convicted',
#    'assassin',
#    'of',
#    'Dr.',
#    'Martin',
#    'Luther',
#    'King',
#    'Jr.',
#    ',',
#    'told',
#    'a',
#    'Capitol',
#    'Hill',
#    'hearing',
#    'he',
#    'did',
#    'not',
#    'commit',
#    'the',
#    'crime',
#    ',',
#    'saying',
#    'he',
#    "'d",
#    'been',
#    'set',
#    'up',
#    'by',
#    'a',
#    'mysterious',
#    'man',
#    'called',
#    '`',
#    '`',
#    'Raoul.',
#    "'",
#    "'"],
#   'entities': [[3, 6, 'Peop', 'James Earl Ray'],
#    [10, 15, 'Org', 'Dr. Martin Luther King Jr.'],
#    [18, 20, 'Org', 'Capitol Hill']],
#   'relations': [[3,
#     6,
#     10,
#     15,
#     'Kill',
#     'James Earl Ray',
#     'Dr. Martin Luther King Jr.']],
#   'entity_gts': [[3, 6, 'Peop', 'James Earl Ray'],
#    [10, 15, 'Peop', 'Dr. Martin Luther King Jr.'],
#    [18, 20, 'Org', 'Capitol Hill'],
#    [41, 42, 'Peop', 'Raoul.']],
#   'relation_gts': [[3,
#     6,
#     10,
#     15,
#     'Kill',
#     'James Earl Ray',
#     'Dr. Martin Luther King Jr.']]},
#  {'tokens': ['JN1404193394',
#    'Damascus',
#    'Syrian',
#    'Arab',
#    'Republic',
#    'Radio',
#    'Network',
#    'in',
#    'Arabic',
#    '1530',
#    'GMT',
#    '14',
#    'Apr',
#    '94'],
#   'entities': [[1, 2, 'Loc', 'Damascus'],
#    [2, 3, 'Org', 'Syrian'],
#    [3, 7, 'Other', 'Arab Republic Radio Network'],
#    [9, 11, 'Other', '1530 GMT'],
#    [11, 14, 'Other', '14 Apr 94']],
#   'relations': [[2, 3, 1, 2, 'OrgBased_In', 'Syrian', 'Damascus'],
#    [3, 7, 1, 2, 'OrgBased_In', 'Arab Republic Radio Network', 'Damascus']],
#   'entity_gts': [[1, 2, 'Loc', 'Damascus'],
#    [2, 7, 'Org', 'Syrian Arab Republic Radio Network'],
#    [9, 11, 'Other', '1530 GMT'],
#    [11, 14, 'Other', '14 Apr 94']],
#   'relation_gts': [[2,
#     7,
#     1,
#     2,
#     'OrgBased_In',
#     'Syrian Arab Republic Radio Network',
#     'Damascus']]},
#  {'tokens': ['To',
#    'handle',
#    'these',
#    'tasks',
#    ',',
#    'new',
#    'advanced',
#    'satellites',
#    'are',
#    'to',
#    'be',
#    'developed',
#    'as',
#    'outlined',
#    'by',
#    'Academician',
#    'M.',
#    'F.',
#    'Reshetnov',
#    ',',
#    'general',
#    'designer',
#    'and',
#    'director',
#    'of',
#    'the',
#    'Scientific',
#    'Production',
#    'Association',
#    'of',
#    'Applied',
#    'Mechanics',
#    '.'],
#   'entities': [],
#   'relations': [],
#   'entity_gts': [[16, 19, 'Peop', 'M. F. Reshetnov'],
#    [26, 32, 'Org', 'Scientific Production Association of Applied Mechanics']],
#   'relation_gts': [[16,
#     19,
#     26,
#     32,
#     'Work_For',
#     'M. F. Reshetnov',
#     'Scientific Production Association of Applied Mechanics']]},
#  {'tokens': ['OSHA',
#    'now',
#    'wants',
#    'the',
#    'civil',
#    'cases',
#    'postponed',
#    'so',
#    'the',
#    'case',
#    'can',
#    'be',
#    'reviewed',
#    'for',
#    'possible',
#    'criminal',
#    'violations',
#    ',',
#    'U.S.',
#    'Elizabeth',
#    'Dole',
#    'said',
#    'in',
#    'a',
#    'statement',
#    'Tuesday.'],
#   'entities': [[0, 1, 'Org', 'OSHA'], [18, 21, 'Loc', 'U.S. Elizabeth Dole']],
#   'relations': [[18, 21, 0, 1, 'Work_For', 'U.S. Elizabeth Dole', 'OSHA']],
#   'entity_gts': [[0, 1, 'Org', 'OSHA'],
#    [18, 19, 'Loc', 'U.S.'],
#    [19, 21, 'Peop', 'Elizabeth Dole']],
#   'relation_gts': [[19, 21, 18, 19, 'Live_In', 'Elizabeth Dole', 'U.S.']]},
#  {'tokens': ['Andrews',
#    'Lock',
#    'and',
#    'Dam',
#    ',',
#    'Early',
#    'County',
#    ',',
#    'Ga.',
#    ';'],
#   'entities': [[0, 1, 'Loc', 'Andrews'],
#    [5, 7, 'Loc', 'Early County'],
#    [8, 9, 'Loc', 'Ga.']],
#   'relations': [[0, 1, 5, 7, 'Live_In', 'Andrews', 'Early County'],
#    [0, 1, 8, 9, 'Live_In', 'Andrews', 'Ga.']],
#   'entity_gts': [[0, 4, 'Loc', 'Andrews Lock and Dam'],
#    [5, 7, 'Loc', 'Early County'],
#    [8, 9, 'Loc', 'Ga.']],
#   'relation_gts': [[0,
#     4,
#     5,
#     7,
#     'Located_In',
#     'Andrews Lock and Dam',
#     'Early County'],
#    [0, 4, 8, 9, 'Located_In', 'Andrews Lock and Dam', 'Ga.'],
#    [5, 7, 8, 9, 'Located_In', 'Early County', 'Ga.']]},
#  {'tokens': ['Mark',
#    'David',
#    'Chapman',
#    ',',
#    'convicted',
#    'of',
#    'killing',
#    'John',
#    'Lennon',
#    ';',
#    'and',
#    'R.',
#    'Foster',
#    'Winans',
#    ',',
#    'a',
#    'former',
#    'Wall',
#    'Street',
#    'Journal',
#    'reporter',
#    'convicted',
#    'of',
#    'insider',
#    'trading.',
#    ';'],
#   'entities': [[0, 3, 'Peop', 'Mark David Chapman'],
#    [7, 9, 'Peop', 'John Lennon'],
#    [11, 14, 'Peop', 'R. Foster Winans'],
#    [17, 20, 'Other', 'Wall Street Journal']],
#   'relations': [[0, 3, 7, 9, 'Kill', 'Mark David Chapman', 'John Lennon'],
#    [11, 14, 7, 9, 'Kill', 'R. Foster Winans', 'John Lennon'],
#    [11, 14, 17, 20, 'Work_For', 'R. Foster Winans', 'Wall Street Journal']],
#   'entity_gts': [[0, 3, 'Peop', 'Mark David Chapman'],
#    [7, 9, 'Peop', 'John Lennon'],
#    [11, 14, 'Peop', 'R. Foster Winans'],
#    [17, 20, 'Org', 'Wall Street Journal']],
#   'relation_gts': [[0, 3, 7, 9, 'Kill', 'Mark David Chapman', 'John Lennon']]},
#  {'tokens': ['They',
#    'were',
#    'imported',
#    'by',
#    'Larami',
#    'Corp.',
#    'of',
#    'Philadelphia.'],
#   'entities': [[4, 6, 'Org', 'Larami Corp.'], [7, 8, 'Loc', 'Philadelphia.']],
#   'relations': [[4, 6, 7, 8, 'Located_In', 'Larami Corp.', 'Philadelphia.']],
#   'entity_gts': [[4, 6, 'Org', 'Larami Corp.'],
#    [7, 8, 'Loc', 'Philadelphia.']],
#   'relation_gts': [[4,
#     6,
#     7,
#     8,
#     'OrgBased_In',
#     'Larami Corp.',
#     'Philadelphia.']]},
#  {'tokens': ['Larry',
#    'Jinks',
#    'has',
#    'been',
#    'named',
#    'publisher',
#    'of',
#    'the',
#    'San',
#    'Jose',
#    'Mercury',
#    'News',
#    ',',
#    'succeeding',
#    'William',
#    'A.',
#    'Ott',
#    ',',
#    'who',
#    'will',
#    'become',
#    'the',
#    'newspaper',
#    "'s",
#    'chairman',
#    ',',
#    'the',
#    'Knight-Ridder',
#    ',',
#    'Inc.',
#    'announced',
#    'Thursday',
#    '.'],
#   'entities': [[0, 2, 'Peop', 'Larry Jinks'],
#    [8, 12, 'Loc', 'San Jose Mercury News'],
#    [14, 17, 'Peop', 'William A. Ott'],
#    [29, 30, 'Org', 'Inc.']],
#   'relations': [[0,
#     2,
#     8,
#     12,
#     'Work_For',
#     'Larry Jinks',
#     'San Jose Mercury News']],
#   'entity_gts': [[0, 2, 'Peop', 'Larry Jinks'],
#    [8, 12, 'Org', 'San Jose Mercury News'],
#    [14, 17, 'Peop', 'William A. Ott'],
#    [27, 30, 'Org', 'Knight-Ridder , Inc.']],
#   'relation_gts': [[0,
#     2,
#     8,
#     12,
#     'Work_For',
#     'Larry Jinks',
#     'San Jose Mercury News'],
#    [14, 17, 8, 12, 'Work_For', 'William A. Ott', 'San Jose Mercury News']]},
#  {'tokens': ['BK2506112994',
#    'Bangkok',
#    'BANGKOK',
#    'POST',
#    'in',
#    'English',
#    '25',
#    'Jun',
#    '94',
#    'pp',
#    '1',
#    ',',
#    '3'],
#   'entities': [[1, 2, 'Loc', 'Bangkok'],
#    [2, 4, 'Loc', 'BANGKOK POST'],
#    [6, 9, 'Other', '25 Jun 94']],
#   'relations': [[2, 4, 1, 2, 'OrgBased_In', 'BANGKOK POST', 'Bangkok']],
#   'entity_gts': [[1, 2, 'Loc', 'Bangkok'],
#    [2, 4, 'Org', 'BANGKOK POST'],
#    [6, 9, 'Other', '25 Jun 94']],
#   'relation_gts': [[2, 4, 1, 2, 'OrgBased_In', 'BANGKOK POST', 'Bangkok']]},
#  {'tokens': ['Tunis', 'Tunisian', 'Republic', 'Radio', 'Network'],
#   'entities': [[0, 1, 'Loc', 'Tunis'],
#    [1, 5, 'Loc', 'Tunisian Republic Radio Network']],
#   'relations': [[1,
#     5,
#     0,
#     1,
#     'OrgBased_In',
#     'Tunisian Republic Radio Network',
#     'Tunis']],
#   'entity_gts': [[0, 1, 'Loc', 'Tunis'],
#    [1, 5, 'Org', 'Tunisian Republic Radio Network']],
#   'relation_gts': [[1,
#     5,
#     0,
#     1,
#     'OrgBased_In',
#     'Tunisian Republic Radio Network',
#     'Tunis']]},
#  {'tokens': ['In',
#    '1968',
#    ',',
#    'authorities',
#    'announced',
#    'the',
#    'capture',
#    'in',
#    'London',
#    'of',
#    'James',
#    'Earl',
#    'Ray',
#    ',',
#    'suspected',
#    'of',
#    'the',
#    'assassination',
#    'of',
#    'civil',
#    'rights',
#    'leader',
#    'Dr.',
#    'Martin',
#    'Luther',
#    'King',
#    'Jr',
#    '.'],
#   'entities': [[10, 13, 'Peop', 'James Earl Ray'],
#    [22, 27, 'Org', 'Dr. Martin Luther King Jr']],
#   'relations': [[10,
#     13,
#     22,
#     27,
#     'Kill',
#     'James Earl Ray',
#     'Dr. Martin Luther King Jr']],
#   'entity_gts': [[8, 9, 'Loc', 'London'],
#    [10, 13, 'Peop', 'James Earl Ray'],
#    [22, 27, 'Peop', 'Dr. Martin Luther King Jr']],
#   'relation_gts': [[10,
#     13,
#     22,
#     27,
#     'Kill',
#     'James Earl Ray',
#     'Dr. Martin Luther King Jr']]},
#  {'tokens': ['I',
#    'was',
#    'keen',
#    'to',
#    'ask',
#    'the',
#    'following',
#    'questions',
#    'in',
#    'an',
#    'interview',
#    'with',
#    'Russian',
#    'Atomic',
#    'Energy',
#    'Minister',
#    'V.',
#    'Mikhaylov',
#    ':',
#    '(',
#    'Gubarev',
#    ')',
#    'How',
#    'did',
#    'Ukraine',
#    'lose',
#    'out',
#    'by',
#    'this',
#    'deal',
#    '?',
#    '(',
#    'Mikhaylov',
#    ')',
#    'The',
#    'level',
#    'of',
#    'Ukraine',
#    "'s",
#    'security',
#    'has',
#    'increased',
#    '--',
#    'so',
#    'in',
#    'fact',
#    'Ukraine',
#    'has',
#    'benefited',
#    '.'],
#   'entities': [[12, 15, 'Loc', 'Russian Atomic Energy'],
#    [16, 18, 'Peop', 'V. Mikhaylov'],
#    [24, 25, 'Loc', 'Ukraine'],
#    [37, 38, 'Loc', 'Ukraine'],
#    [46, 47, 'Loc', 'Ukraine']],
#   'relations': [[16,
#     18,
#     12,
#     15,
#     'Work_For',
#     'V. Mikhaylov',
#     'Russian Atomic Energy']],
#   'entity_gts': [[12, 16, 'Org', 'Russian Atomic Energy Minister'],
#    [16, 18, 'Peop', 'V. Mikhaylov'],
#    [20, 21, 'Peop', 'Gubarev'],
#    [24, 25, 'Loc', 'Ukraine'],
#    [32, 33, 'Peop', 'Mikhaylov'],
#    [37, 38, 'Loc', 'Ukraine'],
#    [46, 47, 'Loc', 'Ukraine']],
#   'relation_gts': [[16,
#     18,
#     12,
#     16,
#     'Work_For',
#     'V. Mikhaylov',
#     'Russian Atomic Energy Minister'],
#    [32,
#     33,
#     12,
#     16,
#     'Work_For',
#     'Mikhaylov',
#     'Russian Atomic Energy Minister']]},
#  {'tokens': ['Keen',
#    'Corp.',
#    'of',
#    'New',
#    'York',
#    ';',
#    'and',
#    'Eagle-Picher',
#    'Industries',
#    'of',
#    'Cincinnati',
#    ',',
#    'claiming',
#    'the',
#    'companies',
#    'failed',
#    'to',
#    'warn',
#    'him',
#    'of',
#    'the',
#    'risk.'],
#   'entities': [[0, 1, 'Loc', 'Keen'],
#    [1, 2, 'Loc', 'Corp.'],
#    [3, 5, 'Loc', 'New York'],
#    [7, 9, 'Org', 'Eagle-Picher Industries'],
#    [10, 11, 'Loc', 'Cincinnati']],
#   'relations': [[7,
#     9,
#     10,
#     11,
#     'Located_In',
#     'Eagle-Picher Industries',
#     'Cincinnati']],
#   'entity_gts': [[0, 2, 'Org', 'Keen Corp.'],
#    [3, 5, 'Loc', 'New York'],
#    [7, 9, 'Org', 'Eagle-Picher Industries'],
#    [10, 11, 'Loc', 'Cincinnati']],
#   'relation_gts': [[0, 2, 3, 5, 'OrgBased_In', 'Keen Corp.', 'New York'],
#    [7, 9, 10, 11, 'OrgBased_In', 'Eagle-Picher Industries', 'Cincinnati']]},
#  {'tokens': ['In',
#    '1854',
#    ',',
#    'George',
#    'Eastman',
#    ',',
#    'inventor',
#    'of',
#    'the',
#    'Kodak',
#    'camera',
#    ',',
#    'was',
#    'born',
#    'in',
#    'Waterville',
#    ',',
#    'N.',
#    'Y.'],
#   'entities': [[3, 5, 'Peop', 'George Eastman'],
#    [9, 10, 'Loc', 'Kodak'],
#    [15, 19, 'Loc', 'Waterville , N. Y.']],
#   'relations': [[3, 5, 9, 10, 'Work_For', 'George Eastman', 'Kodak'],
#    [3, 5, 15, 19, 'Live_In', 'George Eastman', 'Waterville , N. Y.']],
#   'entity_gts': [[3, 5, 'Peop', 'George Eastman'],
#    [9, 10, 'Org', 'Kodak'],
#    [15, 19, 'Loc', 'Waterville , N. Y.']],
#   'relation_gts': [[3,
#     5,
#     15,
#     19,
#     'Live_In',
#     'George Eastman',
#     'Waterville , N. Y.']]},
#  {'tokens': ['Booth',
#    'also',
#    'used',
#    'an',
#    'underground',
#    'intelligence',
#    'network',
#    'for',
#    'his',
#    'escape',
#    'after',
#    'shooting',
#    'Lincoln',
#    'during',
#    'a',
#    'performance',
#    'at',
#    'Ford',
#    "'s",
#    'Theatre',
#    'in',
#    'Washington',
#    ',',
#    'D.C.',
#    ',',
#    'on',
#    'April',
#    '14',
#    ',',
#    '1865',
#    ',',
#    'five',
#    'days',
#    'after',
#    'Gen.',
#    'Robert',
#    'E.',
#    'Lee',
#    "'s",
#    'surrender',
#    'at',
#    'Appomattox',
#    ',',
#    'the',
#    'authors',
#    'contend',
#    '.'],
#   'entities': [[0, 1, 'Peop', 'Booth'],
#    [12, 13, 'Peop', 'Lincoln'],
#    [17, 18, 'Loc', 'Ford'],
#    [21, 22, 'Loc', 'Washington'],
#    [26, 27, 'Other', 'April'],
#    [35, 38, 'Peop', 'Robert E. Lee'],
#    [41, 42, 'Loc', 'Appomattox']],
#   'relations': [[35, 38, 41, 42, 'Live_In', 'Robert E. Lee', 'Appomattox'],
#    [17, 18, 12, 13, 'Kill', 'Ford', 'Lincoln'],
#    [17, 18, 21, 22, 'Live_In', 'Ford', 'Washington']],
#   'entity_gts': [[0, 1, 'Peop', 'Booth'],
#    [12, 13, 'Peop', 'Lincoln'],
#    [17, 18, 'Other', 'Ford'],
#    [19, 20, 'Other', 'Theatre'],
#    [21, 24, 'Loc', 'Washington , D.C.'],
#    [26, 27, 'Other', 'April'],
#    [34, 38, 'Peop', 'Gen. Robert E. Lee'],
#    [41, 42, 'Other', 'Appomattox']],
#   'relation_gts': [[0, 1, 12, 13, 'Kill', 'Booth', 'Lincoln']]},
#  {'tokens': ['The',
#    'New',
#    'York',
#    'Opera',
#    'Repertory',
#    'Theater',
#    'was',
#    'founded',
#    'in',
#    '1977',
#    'by',
#    'Leigh',
#    'Gibbs',
#    'Gore',
#    ',',
#    'who',
#    'conducted',
#    'the',
#    'opera',
#    '.'],
#   'entities': [[1, 6, 'Loc', 'New York Opera Repertory Theater'],
#    [11, 14, 'Peop', 'Leigh Gibbs Gore']],
#   'relations': [[11,
#     14,
#     1,
#     6,
#     'Work_For',
#     'Leigh Gibbs Gore',
#     'New York Opera Repertory Theater']],
#   'entity_gts': [[0, 6, 'Org', 'The New York Opera Repertory Theater'],
#    [9, 10, 'Other', '1977'],
#    [11, 14, 'Peop', 'Leigh Gibbs Gore']],
#   'relation_gts': [[11,
#     14,
#     0,
#     6,
#     'Work_For',
#     'Leigh Gibbs Gore',
#     'The New York Opera Repertory Theater']]},
#  {'tokens': ['Ozawa',
#    'on',
#    'U.S.',
#    'Ties',
#    ',',
#    'Political',
#    'Realignment',
#    'OW1502060194',
#    'Tokyo',
#    'YOMIURI',
#    'SHIMBUN',
#    'in',
#    'Japanese',
#    '14',
#    'Feb',
#    '94',
#    'Morning',
#    'Edition',
#    'p',
#    '6',
#    '--',
#    'FOR',
#    'OFFICIAL',
#    'USE',
#    'ONLY'],
#   'entities': [[2, 3, 'Loc', 'U.S.'],
#    [8, 11, 'Loc', 'Tokyo YOMIURI SHIMBUN'],
#    [13, 16, 'Other', '14 Feb 94']],
#   'relations': [[8, 11, 2, 3, 'OrgBased_In', 'Tokyo YOMIURI SHIMBUN', 'U.S.']],
#   'entity_gts': [[0, 1, 'Peop', 'Ozawa'],
#    [2, 3, 'Loc', 'U.S.'],
#    [8, 9, 'Loc', 'Tokyo'],
#    [9, 11, 'Org', 'YOMIURI SHIMBUN'],
#    [13, 16, 'Other', '14 Feb 94']],
#   'relation_gts': [[9, 11, 8, 9, 'OrgBased_In', 'YOMIURI SHIMBUN', 'Tokyo']]},
#  {'tokens': ['Mauro',
#    'sued',
#    'product',
#    'manufacturers',
#    'Owens-Corning',
#    'Fiberglass',
#    'of',
#    'Toledo',
#    ',',
#    'Ohio',
#    ';'],
#   'entities': [[4, 6, 'Org', 'Owens-Corning Fiberglass'],
#    [7, 8, 'Loc', 'Toledo'],
#    [9, 10, 'Loc', 'Ohio']],
#   'relations': [[4, 6, 7, 8, 'Live_In', 'Owens-Corning Fiberglass', 'Toledo'],
#    [7, 8, 9, 10, 'Located_In', 'Toledo', 'Ohio']],
#   'entity_gts': [[0, 1, 'Peop', 'Mauro'],
#    [4, 6, 'Org', 'Owens-Corning Fiberglass'],
#    [7, 8, 'Loc', 'Toledo'],
#    [9, 10, 'Loc', 'Ohio']],
#   'relation_gts': [[4,
#     6,
#     7,
#     8,
#     'OrgBased_In',
#     'Owens-Corning Fiberglass',
#     'Toledo'],
#    [4, 6, 9, 10, 'OrgBased_In', 'Owens-Corning Fiberglass', 'Ohio'],
#    [7, 8, 9, 10, 'Located_In', 'Toledo', 'Ohio']]},
#  {'tokens': ['OSHA',
#    'had',
#    'already',
#    'filed',
#    'numerous',
#    'civil',
#    'charges',
#    'against',
#    'the',
#    'S.A.',
#    'Healy',
#    'Co.',
#    'of',
#    'McCook',
#    ',',
#    'Ill.',
#    ',',
#    'the',
#    'tunnel',
#    'contractor',
#    ',',
#    'and',
#    'CH2M',
#    'Hill',
#    'of',
#    'Corvallis',
#    ',',
#    'Ore.',
#    ',',
#    'an',
#    'engineering',
#    'firm',
#    'that',
#    'supervised',
#    'the',
#    'work.'],
#   'entities': [[0, 1, 'Org', 'OSHA'],
#    [9, 12, 'Org', 'S.A. Healy Co.'],
#    [13, 14, 'Loc', 'McCook'],
#    [15, 16, 'Loc', 'Ill.'],
#    [22, 24, 'Org', 'CH2M Hill'],
#    [25, 26, 'Loc', 'Corvallis'],
#    [27, 28, 'Loc', 'Ore.']],
#   'relations': [[22, 24, 27, 28, 'Live_In', 'CH2M Hill', 'Ore.'],
#    [25, 26, 27, 28, 'Located_In', 'Corvallis', 'Ore.'],
#    [13, 14, 15, 16, 'Located_In', 'McCook', 'Ill.'],
#    [22, 24, 25, 26, 'Live_In', 'CH2M Hill', 'Corvallis']],
#   'entity_gts': [[0, 1, 'Org', 'OSHA'],
#    [9, 12, 'Org', 'S.A. Healy Co.'],
#    [13, 14, 'Loc', 'McCook'],
#    [15, 16, 'Loc', 'Ill.'],
#    [22, 24, 'Org', 'CH2M Hill'],
#    [25, 26, 'Loc', 'Corvallis'],
#    [27, 28, 'Loc', 'Ore.']],
#   'relation_gts': [[9, 12, 13, 14, 'OrgBased_In', 'S.A. Healy Co.', 'McCook'],
#    [9, 12, 15, 16, 'OrgBased_In', 'S.A. Healy Co.', 'Ill.'],
#    [13, 14, 15, 16, 'Located_In', 'McCook', 'Ill.'],
#    [22, 24, 25, 26, 'OrgBased_In', 'CH2M Hill', 'Corvallis'],
#    [22, 24, 27, 28, 'OrgBased_In', 'CH2M Hill', 'Ore.'],
#    [25, 26, 27, 28, 'Located_In', 'Corvallis', 'Ore.']]},
#  {'tokens': ['LD0706183794',
#    'Riga',
#    'Radio',
#    'Riga',
#    'Network',
#    'in',
#    'Latvian',
#    '1700',
#    'GMT',
#    '7',
#    'Jun',
#    '94'],
#   'entities': [[1, 2, 'Loc', 'Riga'],
#    [2, 3, 'Org', 'Radio'],
#    [3, 5, 'Loc', 'Riga Network'],
#    [7, 9, 'Other', '1700 GMT'],
#    [9, 12, 'Other', '7 Jun 94']],
#   'relations': [[2, 3, 1, 2, 'OrgBased_In', 'Radio', 'Riga'],
#    [3, 5, 1, 2, 'OrgBased_In', 'Riga Network', 'Riga']],
#   'entity_gts': [[1, 2, 'Loc', 'Riga'],
#    [2, 5, 'Org', 'Radio Riga Network'],
#    [7, 9, 'Other', '1700 GMT'],
#    [9, 12, 'Other', '7 Jun 94']],
#   'relation_gts': [[2, 5, 1, 2, 'OrgBased_In', 'Radio Riga Network', 'Riga']]},
#  {'tokens': ['of',
#    'Shinseito',
#    '(',
#    'Japan',
#    'Renewal',
#    'Party',
#    ')',
#    ',',
#    'by',
#    'Takeshi',
#    'Sasaki',
#    ',',
#    'Tokyo',
#    'University',
#    'professor',
#    ',',
#    'on',
#    '13',
#    'February',
#    ',',
#    'moderated',
#    'by',
#    'Shoichi',
#    'Oikawa',
#    ',',
#    'YOMIURI',
#    'SHIMBUN',
#    'political',
#    'editor',
#    ';',
#    'place',
#    'not',
#    'given',
#    ';',
#    'first',
#    'paragraph',
#    'is',
#    'YOMIURI',
#    'SHIMBUN',
#    'introduction',
#    ')',
#    '(',
#    'Excerpts',
#    ')',
#    'After',
#    'the',
#    'passage',
#    'of',
#    'the',
#    'political',
#    'reform',
#    'laws',
#    ',',
#    'as',
#    'vigorous',
#    'moves',
#    'toward',
#    'the',
#    'realignment',
#    'of',
#    'the',
#    'political',
#    'world',
#    'become',
#    'apparent',
#    ',',
#    'YOMIURI',
#    'SHIMBUN',
#    'invited',
#    'Ichiro',
#    'Ozawa',
#    ',',
#    'secretary',
#    'of',
#    'Shinseito',
#    ',',
#    'on',
#    '13',
#    'February',
#    'to',
#    'talk',
#    'for',
#    'about',
#    'two',
#    'hours',
#    'on',
#    'the',
#    'possible',
#    'course',
#    'of',
#    'political',
#    'realignment',
#    ',',
#    'foreign',
#    'policy',
#    'and',
#    'security',
#    ',',
#    'international',
#    'contribution',
#    ',',
#    'and',
#    'his',
#    'assessment',
#    'of',
#    'postwar',
#    'politics',
#    '.'],
#   'entities': [[1, 2, 'Org', 'Shinseito'],
#    [3, 6, 'Loc', 'Japan Renewal Party'],
#    [9, 11, 'Peop', 'Takeshi Sasaki'],
#    [12, 14, 'Loc', 'Tokyo University'],
#    [22, 24, 'Peop', 'Shoichi Oikawa'],
#    [25, 27, 'Org', 'YOMIURI SHIMBUN'],
#    [37, 39, 'Org', 'YOMIURI SHIMBUN'],
#    [66, 68, 'Org', 'YOMIURI SHIMBUN'],
#    [69, 71, 'Peop', 'Ichiro Ozawa'],
#    [74, 75, 'Loc', 'Shinseito'],
#    [77, 78, 'Other', '13'],
#    [78, 79, 'Other', 'February']],
#   'relations': [[69,
#     71,
#     66,
#     68,
#     'Work_For',
#     'Ichiro Ozawa',
#     'YOMIURI SHIMBUN'],
#    [22, 24, 25, 27, 'Work_For', 'Shoichi Oikawa', 'YOMIURI SHIMBUN'],
#    [69, 71, 74, 75, 'Live_In', 'Ichiro Ozawa', 'Shinseito'],
#    [9, 11, 12, 14, 'Work_For', 'Takeshi Sasaki', 'Tokyo University']],
#   'entity_gts': [[1, 2, 'Org', 'Shinseito'],
#    [3, 6, 'Org', 'Japan Renewal Party'],
#    [9, 11, 'Peop', 'Takeshi Sasaki'],
#    [12, 14, 'Org', 'Tokyo University'],
#    [17, 19, 'Other', '13 February'],
#    [22, 24, 'Peop', 'Shoichi Oikawa'],
#    [25, 27, 'Org', 'YOMIURI SHIMBUN'],
#    [37, 39, 'Org', 'YOMIURI SHIMBUN'],
#    [66, 68, 'Org', 'YOMIURI SHIMBUN'],
#    [69, 71, 'Peop', 'Ichiro Ozawa'],
#    [74, 75, 'Org', 'Shinseito'],
#    [77, 79, 'Other', '13 February']],
#   'relation_gts': [[9,
#     11,
#     12,
#     14,
#     'Work_For',
#     'Takeshi Sasaki',
#     'Tokyo University'],
#    [22, 24, 25, 27, 'Work_For', 'Shoichi Oikawa', 'YOMIURI SHIMBUN'],
#    [22, 24, 37, 39, 'Work_For', 'Shoichi Oikawa', 'YOMIURI SHIMBUN'],
#    [22, 24, 66, 68, 'Work_For', 'Shoichi Oikawa', 'YOMIURI SHIMBUN'],
#    [69, 71, 1, 2, 'Work_For', 'Ichiro Ozawa', 'Shinseito'],
#    [69, 71, 74, 75, 'Work_For', 'Ichiro Ozawa', 'Shinseito']]},
#  {'tokens': ['Eaglebrook',
#    'East',
#    'opened',
#    'in',
#    'Middletown',
#    'in',
#    'April',
#    '.'],
#   'entities': [[0, 2, 'Org', 'Eaglebrook East'],
#    [4, 5, 'Loc', 'Middletown'],
#    [6, 7, 'Other', 'April']],
#   'relations': [[0, 2, 4, 5, 'Located_In', 'Eaglebrook East', 'Middletown']],
#   'entity_gts': [[0, 2, 'Org', 'Eaglebrook East'],
#    [4, 5, 'Loc', 'Middletown']],
#   'relation_gts': [[0,
#     2,
#     4,
#     5,
#     'OrgBased_In',
#     'Eaglebrook East',
#     'Middletown']]}]

# %%
verify_and_infer(data[67]['entities'], data[67]['relations'], inference_program, 'twoone')
# Out:
# CompletedProcess(args='conda activate clingo; clingo ../asp/compute.lp ../asp/p2.lp ../asp/p3.lp --outf=3', returncode=65, stdout=b'', stderr=b'\nCommandNotFoundError: Your shell has not been properly configured to use \'conda activate\'.\nTo initialize your shell, run\n\n    $ conda init <SHELL_NAME>\n\nCurrently supported shells are:\n  - bash\n  - fish\n  - tcsh\n  - xonsh\n  - zsh\n  - powershell\n\nSee \'conda init --help\' for more information and options.\n\nIMPORTANT: You may need to close and restart your shell after running \'conda init\'.\n\n\n*** ERROR: (clingo): ../asp/compute.lp:1:1-89:6: error: error executing python code:\n  Traceback (most recent call last):\n    File "<../asp/compute.lp:1:1-89:6>", line 9, in <module>\n  ModuleNotFoundError: No module named \'clingo.symbol\'; \'clingo\' is not a package\n\n')
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [46], in <cell line: 1>()
# ----> 1 verify_and_infer(data[67]['entities'], data[67]['relations'], inference_program, 'twoone')
#
# Input In [45], in verify_and_infer(entities, relations, inference_program, model_type)
#       9 r_atoms = convert_original_to_atoms(relations, 'relation')
#      10 program = concat_facts(e_atoms, r_atoms)
# ---> 11 answer_sets = solve_v2(program)
#      12 for answer_set in answer_sets:
#      13     es, rs = convert_solutions_back(answer_set)
#
# Input In [41], in solve_v2(program)
#      28 output = subprocess.run(drive_command, capture_output=True, shell=True)
#      29 print(output)
# ---> 30 result = ast.literal_eval(output.stdout.decode().split('\n')[-2])
#      31 return result
#
# IndexError: list index out of range

# %%
for i, row in enumerate(data):
    print(i)
    print(row)
    print('===============================================')
# Out:
# 0
# {'tokens': ['Newspaper', '`', 'Explains', "'", 'U.S.', 'Interests', 'Section', 'Events', 'FL1402001894', 'Havana', 'Radio', 'Reloj', 'Network', 'in', 'Spanish', '2100', 'GMT', '13', 'Feb', '94'], 'entities': [[4, 5, 'Loc', 'U.S.'], [9, 10, 'Loc', 'Havana'], [10, 13, 'Org', 'Radio Reloj Network'], [15, 17, 'Other', '2100 GMT'], [17, 20, 'Other', '13 Feb 94']], 'relations': [[10, 13, 9, 10, 'OrgBased_In', 'Radio Reloj Network', 'Havana'], [10, 13, 4, 5, 'OrgBased_In', 'Radio Reloj Network', 'U.S.']], 'entity_gts': [[4, 5, 'Loc', 'U.S.'], [9, 10, 'Loc', 'Havana'], [10, 13, 'Org', 'Radio Reloj Network'], [15, 17, 'Other', '2100 GMT'], [17, 20, 'Other', '13 Feb 94']], 'relation_gts': [[10, 13, 9, 10, 'OrgBased_In', 'Radio Reloj Network', 'Havana']]}
# ===============================================
# 1
# {'tokens': ['`', '`', 'If', 'it', 'does', 'not', 'snow', ',', 'and', 'a', 'lot', ',', 'within', 'this', 'month', 'we', 'will', 'have', 'no', 'water', 'to', 'submerge', '150', ',', '000', 'hectares', '(', '370', ',', '500', 'acres', ')', 'of', 'rice', ',', "'", "'", 'said', 'Bruno', 'Pusterla', ',', 'a', 'top', 'official', 'of', 'the', 'Italian', 'Agricultural', 'Confederation', '.'], 'entities': [[38, 40, 'Peop', 'Bruno Pusterla'], [46, 47, 'Loc', 'Italian']], 'relations': [], 'entity_gts': [[22, 26, 'Other', '150 , 000 hectares'], [27, 31, 'Other', '370 , 500 acres'], [33, 34, 'Other', 'rice'], [38, 40, 'Peop', 'Bruno Pusterla'], [46, 49, 'Org', 'Italian Agricultural Confederation']], 'relation_gts': [[38, 40, 46, 49, 'Work_For', 'Bruno Pusterla', 'Italian Agricultural Confederation']]}
# ===============================================
# 2
# {'tokens': ['The', 'self-propelled', 'rig', 'Avco', '5', 'was', 'headed', 'to', 'shore', 'with', '14', 'people', 'aboard', 'early', 'Monday', 'when', 'it', 'capsized', 'about', '20', 'miles', 'off', 'the', 'Louisiana', 'coast', ',', 'near', 'Morgan', 'City', ',', 'Lifa', 'said.'], 'entities': [[19, 20, 'Other', '20'], [23, 25, 'Loc', 'Louisiana coast'], [27, 29, 'Loc', 'Morgan City'], [30, 31, 'Peop', 'Lifa']], 'relations': [], 'entity_gts': [[19, 21, 'Other', '20 miles'], [23, 24, 'Loc', 'Louisiana'], [27, 29, 'Loc', 'Morgan City'], [30, 31, 'Peop', 'Lifa']], 'relation_gts': [[27, 29, 23, 24, 'Located_In', 'Morgan City', 'Louisiana']]}
# ===============================================
# 3
# {'tokens': ['Annie', 'Oakley', ',', 'also', 'known', 'as', 'Little', 'Miss', 'Sure', 'Shot', ',', 'was', 'born', 'Phoebe', 'Ann', 'Moses', 'in', 'Willowdell', ',', 'Darke', 'County', ',', 'in', '1860', '.'], 'entities': [[0, 2, 'Peop', 'Annie Oakley'], [13, 16, 'Peop', 'Phoebe Ann Moses'], [17, 18, 'Loc', 'Willowdell'], [19, 21, 'Loc', 'Darke County']], 'relations': [[13, 16, 17, 18, 'Live_In', 'Phoebe Ann Moses', 'Willowdell'], [13, 16, 19, 21, 'Live_In', 'Phoebe Ann Moses', 'Darke County']], 'entity_gts': [[0, 2, 'Peop', 'Annie Oakley'], [6, 10, 'Peop', 'Little Miss Sure Shot'], [13, 16, 'Peop', 'Phoebe Ann Moses'], [17, 21, 'Loc', 'Willowdell , Darke County']], 'relation_gts': [[0, 2, 17, 21, 'Live_In', 'Annie Oakley', 'Willowdell , Darke County'], [6, 10, 17, 21, 'Live_In', 'Little Miss Sure Shot', 'Willowdell , Darke County'], [13, 16, 17, 21, 'Live_In', 'Phoebe Ann Moses', 'Willowdell , Darke County']]}
# ===============================================
# 4
# {'tokens': ['Penry', 'raped', 'Pamela', 'Moseley', 'Carpenter', 'on', 'Oct.', '15', ',', '1979', ',', 'in', 'Livingston', ',', 'Texas', ',', 'then', 'stabbed', 'her', 'to', 'death', '.'], 'entities': [[0, 1, 'Peop', 'Penry'], [2, 5, 'Peop', 'Pamela Moseley Carpenter'], [6, 7, 'Other', 'Oct.'], [12, 13, 'Loc', 'Livingston'], [14, 15, 'Loc', 'Texas']], 'relations': [[12, 13, 14, 15, 'Located_In', 'Livingston', 'Texas']], 'entity_gts': [[0, 1, 'Peop', 'Penry'], [2, 5, 'Peop', 'Pamela Moseley Carpenter'], [6, 10, 'Other', 'Oct. 15 , 1979'], [12, 13, 'Loc', 'Livingston'], [14, 15, 'Loc', 'Texas']], 'relation_gts': [[12, 13, 14, 15, 'Located_In', 'Livingston', 'Texas']]}
# ===============================================
# 5
# {'tokens': ['Anhui', '`', 'Surplus', "'", 'Rural', 'Laborers', 'Move', 'to', 'Cities', 'OW1102132994', 'Beijing', 'XINHUA', 'in', 'English', '1313', 'GMT', '11', 'Feb', '94'], 'entities': [[10, 11, 'Loc', 'Beijing'], [11, 12, 'Org', 'XINHUA'], [14, 16, 'Other', '1313 GMT'], [16, 19, 'Other', '11 Feb 94']], 'relations': [[11, 12, 10, 11, 'OrgBased_In', 'XINHUA', 'Beijing']], 'entity_gts': [[10, 11, 'Loc', 'Beijing'], [11, 12, 'Org', 'XINHUA'], [14, 16, 'Other', '1313 GMT'], [16, 19, 'Other', '11 Feb 94']], 'relation_gts': [[11, 12, 10, 11, 'OrgBased_In', 'XINHUA', 'Beijing']]}
# ===============================================
# 6
# {'tokens': ['Meanwhile', ',', 'Shi', 'Liming', 'at', 'the', 'Institute', 'of', 'Zoology', 'of', 'Kunming', 'found', 'that', 'pandas', 'lack', 'variety', 'in', 'their', 'protein', 'heredity', ',', 'which', 'may', 'serve', 'as', 'one', 'of', 'the', 'major', 'reasons', 'for', 'pandas', "'", 'near', 'extinction', '.'], 'entities': [[2, 4, 'Peop', 'Shi Liming'], [10, 11, 'Loc', 'Kunming']], 'relations': [], 'entity_gts': [[2, 4, 'Peop', 'Shi Liming'], [6, 9, 'Org', 'Institute of Zoology'], [10, 11, 'Loc', 'Kunming']], 'relation_gts': [[2, 4, 6, 9, 'Work_For', 'Shi Liming', 'Institute of Zoology'], [6, 9, 10, 11, 'OrgBased_In', 'Institute of Zoology', 'Kunming']]}
# ===============================================
# 7
# {'tokens': ['Here', 'are', 'highlights', 'of', 'Lucille', 'Ball', "'s", 'career', ':', '1911', '_', 'Born', 'Aug.', '6', ',', '1911', 'in', 'Jamestown', 'N.Y.', ',', 'the', 'daughter', 'of', 'an', 'electrician', 'and', 'concert', 'pianist', 'Desiree', 'Ball.', '1926'], 'entities': [[4, 6, 'Peop', 'Lucille Ball'], [12, 13, 'Other', 'Aug.'], [17, 19, 'Loc', 'Jamestown N.Y.'], [28, 30, 'Peop', 'Desiree Ball.']], 'relations': [[4, 6, 17, 19, 'Live_In', 'Lucille Ball', 'Jamestown N.Y.']], 'entity_gts': [[4, 6, 'Peop', 'Lucille Ball'], [12, 13, 'Other', 'Aug.'], [17, 19, 'Loc', 'Jamestown N.Y.'], [28, 30, 'Peop', 'Desiree Ball.']], 'relation_gts': [[4, 6, 17, 19, 'Live_In', 'Lucille Ball', 'Jamestown N.Y.']]}
# ===============================================
# 8
# {'tokens': ['John', 'Wilkes', 'Booth', 'wasn', "'t", 'a', 'shiftless', 'actor', 'who', 'killed', 'Abraham', 'Lincoln', 'out', 'of', 'despondency', 'over', 'the', 'South', "'s", 'loss', 'in', 'the', 'Civil', 'War', ',', 'but', 'a', 'Confederate', 'intelligence', 'agent', ',', 'a', 'new', 'book', 'contends', '.'], 'entities': [[0, 3, 'Peop', 'John Wilkes Booth'], [10, 12, 'Peop', 'Abraham Lincoln']], 'relations': [], 'entity_gts': [[0, 3, 'Peop', 'John Wilkes Booth'], [10, 12, 'Peop', 'Abraham Lincoln'], [22, 24, 'Other', 'Civil War']], 'relation_gts': [[0, 3, 10, 12, 'Kill', 'John Wilkes Booth', 'Abraham Lincoln']]}
# ===============================================
# 9
# {'tokens': ['Rome', 'is', 'in', 'Lazio', 'province', 'and', 'Naples', 'in', 'Campania', '.'], 'entities': [[0, 1, 'Loc', 'Rome'], [3, 4, 'Loc', 'Lazio'], [6, 7, 'Loc', 'Naples'], [8, 9, 'Loc', 'Campania']], 'relations': [[0, 1, 3, 4, 'Located_In', 'Rome', 'Lazio'], [0, 1, 8, 9, 'Located_In', 'Rome', 'Campania'], [6, 7, 8, 9, 'Located_In', 'Naples', 'Campania']], 'entity_gts': [[0, 1, 'Loc', 'Rome'], [3, 4, 'Loc', 'Lazio'], [6, 7, 'Loc', 'Naples'], [8, 9, 'Loc', 'Campania']], 'relation_gts': [[0, 1, 3, 4, 'Located_In', 'Rome', 'Lazio'], [6, 7, 8, 9, 'Located_In', 'Naples', 'Campania']]}
# ===============================================
# 10
# {'tokens': ['(', 'By', 'ITAR-TASS', 'correspondent', 'Mikhail', 'Shevtsov', ')'], 'entities': [[2, 3, 'Org', 'ITAR-TASS'], [4, 6, 'Peop', 'Mikhail Shevtsov']], 'relations': [[4, 6, 2, 3, 'Work_For', 'Mikhail Shevtsov', 'ITAR-TASS']], 'entity_gts': [[2, 3, 'Org', 'ITAR-TASS'], [4, 6, 'Peop', 'Mikhail Shevtsov']], 'relation_gts': [[4, 6, 2, 3, 'Work_For', 'Mikhail Shevtsov', 'ITAR-TASS']]}
# ===============================================
# 11
# {'tokens': ['It', 'is', 'not', 'and', 'never', 'has', 'been', 'designed', 'or', 'advertised', 'as', 'a', 'threatening', 'or', 'abusive', 'type', 'of', 'thing', ',', "'", "'", 'said', 'XBT', 'spokesman', 'Allan', 'Fitzmaurice.'], 'entities': [[22, 23, 'Org', 'XBT'], [24, 26, 'Peop', 'Allan Fitzmaurice.']], 'relations': [[24, 26, 22, 23, 'Work_For', 'Allan Fitzmaurice.', 'XBT']], 'entity_gts': [[22, 23, 'Org', 'XBT'], [24, 26, 'Peop', 'Allan Fitzmaurice.']], 'relation_gts': [[24, 26, 22, 23, 'Work_For', 'Allan Fitzmaurice.', 'XBT']]}
# ===============================================
# 12
# {'tokens': ['In', '1752', ',', 'flagmaker', 'Betsy', 'Ross', 'was', 'born', 'in', 'Philadelphia', '.'], 'entities': [[4, 6, 'Peop', 'Betsy Ross'], [9, 10, 'Loc', 'Philadelphia']], 'relations': [[4, 6, 9, 10, 'Live_In', 'Betsy Ross', 'Philadelphia']], 'entity_gts': [[4, 6, 'Peop', 'Betsy Ross'], [9, 10, 'Loc', 'Philadelphia']], 'relation_gts': [[4, 6, 9, 10, 'Live_In', 'Betsy Ross', 'Philadelphia']]}
# ===============================================
# 13
# {'tokens': ['Fire', 'Island', 'National', 'Seashore', ',', 'Patchogue', ',', 'N.Y.', ';'], 'entities': [[0, 4, 'Loc', 'Fire Island National Seashore'], [5, 6, 'Loc', 'Patchogue'], [7, 8, 'Loc', 'N.Y.']], 'relations': [], 'entity_gts': [[0, 4, 'Loc', 'Fire Island National Seashore'], [5, 6, 'Loc', 'Patchogue'], [7, 8, 'Loc', 'N.Y.']], 'relation_gts': [[0, 4, 5, 6, 'Located_In', 'Fire Island National Seashore', 'Patchogue'], [0, 4, 7, 8, 'Located_In', 'Fire Island National Seashore', 'N.Y.'], [5, 6, 7, 8, 'Located_In', 'Patchogue', 'N.Y.']]}
# ===============================================
# 14
# {'tokens': ['OW3004022094', 'Beijing', 'XINHUA', 'Domestic', 'Service', 'in', 'Chinese', '1149', 'GMT', '29', 'Apr', '94'], 'entities': [[1, 2, 'Loc', 'Beijing'], [2, 3, 'Org', 'XINHUA'], [7, 9, 'Other', '1149 GMT'], [9, 12, 'Other', '29 Apr 94']], 'relations': [[2, 3, 1, 2, 'OrgBased_In', 'XINHUA', 'Beijing']], 'entity_gts': [[1, 2, 'Loc', 'Beijing'], [2, 3, 'Org', 'XINHUA'], [7, 9, 'Other', '1149 GMT'], [9, 12, 'Other', '29 Apr 94']], 'relation_gts': [[2, 3, 1, 2, 'OrgBased_In', 'XINHUA', 'Beijing']]}
# ===============================================
# 15
# {'tokens': ['In', 'Idaho', ',', 'where', '76', ',', '000', 'acres', 'have', 'been', 'blackened', ',', 'smoke', 'from', 'fires', 'miles', 'away', 'hung', 'over', 'Boise', 'but', 'no', 'warnings', 'were', 'issued', 'to', 'stay', 'indoors.'], 'entities': [[1, 2, 'Loc', 'Idaho'], [19, 20, 'Loc', 'Boise']], 'relations': [], 'entity_gts': [[1, 2, 'Loc', 'Idaho'], [4, 8, 'Other', '76 , 000 acres'], [19, 20, 'Loc', 'Boise']], 'relation_gts': [[19, 20, 1, 2, 'Located_In', 'Boise', 'Idaho']]}
# ===============================================
# 16
# {'tokens': ['The', 'strong', 'Santa', 'Ana', 'winds', 'that', 'earlier', 'produced', 'wind', 'gusts', 'as', 'high', 'as', '100', 'mph', 'in', 'Southern', 'California', ',', 'destroying', 'a', 'blimp', ',', 'shutting', 'down', 'an', 'airport', ',', 'and', 'cutting', 'power', 'to', 'thousands', 'of', 'utility', 'customers', 'were', 'subsiding', ',', 'officials', 'said', '.'], 'entities': [[2, 3, 'Loc', 'Santa'], [17, 18, 'Loc', 'California']], 'relations': [[2, 3, 17, 18, 'Located_In', 'Santa', 'California']], 'entity_gts': [[2, 4, 'Loc', 'Santa Ana'], [13, 15, 'Other', '100 mph'], [16, 18, 'Loc', 'Southern California']], 'relation_gts': [[2, 4, 16, 18, 'Located_In', 'Santa Ana', 'Southern California']]}
# ===============================================
# 17
# {'tokens': ['With', 'considerable', 'rough', 'sailing', 'and', 'difficulty', 'anticipated', 'in', 'the', 'process', 'of', 'ratification', 'by', 'the', 'U.S.', 'Congress', ',', 'the', 'Congress', 'is', 'hardly', 'expected', 'to', 'complete', 'the', 'ratification', 'process', 'within', 'the', 'time', 'limit', 'set', 'by', 'the', 'UR', 'agreement', '.'], 'entities': [[14, 15, 'Loc', 'U.S.'], [15, 16, 'Org', 'Congress'], [18, 19, 'Org', 'Congress']], 'relations': [[15, 16, 14, 15, 'OrgBased_In', 'Congress', 'U.S.'], [18, 19, 14, 15, 'OrgBased_In', 'Congress', 'U.S.']], 'entity_gts': [[14, 15, 'Loc', 'U.S.'], [15, 16, 'Org', 'Congress'], [18, 19, 'Org', 'Congress']], 'relation_gts': [[15, 16, 14, 15, 'OrgBased_In', 'Congress', 'U.S.'], [18, 19, 14, 15, 'OrgBased_In', 'Congress', 'U.S.']]}
# ===============================================
# 18
# {'tokens': ['In', 'another', 'scene', ',', 'President', 'James', 'Garfield', "'s", 'assassin', 'Charles', 'Guiteau', '(', 'Jonathan', 'Hadary', ')', 'prances', 'up', 'and', 'down', 'the', 'stairs', 'of', 'the', 'gallows', 'where', 'he', 'will', 'be', 'hanged', ',', 'all', 'the', 'while', 'singing', 'a', 'spirited', 'Gospel', 'tune', 'about', '"', 'going', 'to', 'the', 'Lordy', '.', '"'], 'entities': [[5, 7, 'Peop', 'James Garfield'], [9, 11, 'Peop', 'Charles Guiteau'], [12, 14, 'Peop', 'Jonathan Hadary']], 'relations': [], 'entity_gts': [[4, 7, 'Peop', 'President James Garfield'], [9, 11, 'Peop', 'Charles Guiteau'], [12, 14, 'Peop', 'Jonathan Hadary'], [36, 37, 'Other', 'Gospel'], [43, 44, 'Other', 'Lordy']], 'relation_gts': [[9, 11, 4, 7, 'Kill', 'Charles Guiteau', 'President James Garfield']]}
# ===============================================
# 19
# {'tokens': ['SPACE', 'CENTER', ',', 'Houston', '(', 'AP', ')'], 'entities': [[0, 2, 'Org', 'SPACE CENTER'], [3, 4, 'Loc', 'Houston'], [5, 6, 'Org', 'AP']], 'relations': [[0, 2, 3, 4, 'OrgBased_In', 'SPACE CENTER', 'Houston'], [5, 6, 3, 4, 'OrgBased_In', 'AP', 'Houston']], 'entity_gts': [[0, 2, 'Org', 'SPACE CENTER'], [3, 4, 'Loc', 'Houston'], [5, 6, 'Org', 'AP']], 'relation_gts': [[0, 2, 3, 4, 'OrgBased_In', 'SPACE CENTER', 'Houston']]}
# ===============================================
# 20
# {'tokens': ['Grant', 'B.', 'Cooper', ',', 'an', 'attorney', 'who', 'defended', 'Kennedy', 'assassin', 'Sirhan', 'B.', 'Sirhan', ',', 'has', 'died', 'at', 'age', '87.'], 'entities': [[0, 3, 'Peop', 'Grant B. Cooper'], [8, 9, 'Peop', 'Kennedy'], [10, 13, 'Peop', 'Sirhan B. Sirhan']], 'relations': [[10, 13, 8, 9, 'Kill', 'Sirhan B. Sirhan', 'Kennedy'], [0, 3, 8, 9, 'Kill', 'Grant B. Cooper', 'Kennedy']], 'entity_gts': [[0, 3, 'Peop', 'Grant B. Cooper'], [8, 9, 'Peop', 'Kennedy'], [10, 13, 'Peop', 'Sirhan B. Sirhan']], 'relation_gts': [[10, 13, 8, 9, 'Kill', 'Sirhan B. Sirhan', 'Kennedy']]}
# ===============================================
# 21
# {'tokens': ['Woodrow', 'Wilson', '(', '28th', 'President', ')', ':', 'Born', 'at', 'about', 'midnight', ',', 'leaving', 'the', 'date', 'in', 'doubt', ',', 'Dec.', '28', 'or', '29', ',', '1856', ',', 'in', 'a', 'Presbyterian', 'manse', 'in', 'Staunton', ',', 'Va', '.'], 'entities': [[0, 2, 'Peop', 'Woodrow Wilson'], [30, 33, 'Loc', 'Staunton , Va']], 'relations': [[0, 2, 30, 33, 'Live_In', 'Woodrow Wilson', 'Staunton , Va']], 'entity_gts': [[0, 2, 'Peop', 'Woodrow Wilson'], [18, 19, 'Other', 'Dec.'], [30, 33, 'Loc', 'Staunton , Va']], 'relation_gts': [[0, 2, 30, 33, 'Live_In', 'Woodrow Wilson', 'Staunton , Va']]}
# ===============================================
# 22
# {'tokens': ['`', '`', 'I', "'m", 'delighted', ',', "'", "'", 'said', 'Peter', 'Butler', ',', 'attorney', 'for', 'A.', 'Copeland', 'Enterprises', 'Inc.', '_', 'the', 'company', 'which', 'owns', 'New', 'Orleans-based', 'Popeyes', 'Famous', 'Fried', 'Chicken', '_', 'after', 'Judge', 'Henry', 'A.', 'Politz', 'announced', 'the', 'decision', 'for', 'the', 'three-judge', '5th', 'U.S.', 'Circuit', 'Court', 'of', 'Appeals', 'panel', '.'], 'entities': [[9, 11, 'Peop', 'Peter Butler'], [14, 18, 'Peop', 'A. Copeland Enterprises Inc.'], [23, 24, 'Loc', 'New'], [25, 26, 'Org', 'Popeyes'], [32, 35, 'Peop', 'Henry A. Politz'], [42, 43, 'Loc', 'U.S.']], 'relations': [[14, 18, 23, 24, 'Live_In', 'A. Copeland Enterprises Inc.', 'New']], 'entity_gts': [[9, 11, 'Peop', 'Peter Butler'], [14, 18, 'Org', 'A. Copeland Enterprises Inc.'], [25, 29, 'Org', 'Popeyes Famous Fried Chicken'], [32, 35, 'Peop', 'Henry A. Politz'], [41, 47, 'Org', '5th U.S. Circuit Court of Appeals']], 'relation_gts': [[9, 11, 14, 18, 'Work_For', 'Peter Butler', 'A. Copeland Enterprises Inc.'], [32, 35, 41, 47, 'Work_For', 'Henry A. Politz', '5th U.S. Circuit Court of Appeals']]}
# ===============================================
# 23
# {'tokens': ['PURCHASE', ',', 'N.Y', '.'], 'entities': [[0, 1, 'Loc', 'PURCHASE'], [2, 3, 'Loc', 'N.Y']], 'relations': [], 'entity_gts': [[0, 1, 'Loc', 'PURCHASE'], [2, 4, 'Loc', 'N.Y .']], 'relation_gts': [[0, 1, 2, 4, 'Located_In', 'PURCHASE', 'N.Y .']]}
# ===============================================
# 24
# {'tokens': ['In', '1782', ',', 'the', 'first', 'president', 'who', 'was', 'a', 'native', 'citizen', 'of', 'the', 'United', 'States', ',', 'Martin', 'Van', 'Buren', ',', 'was', 'born', 'in', 'Kinderhook', ',', 'N.Y.', 'In', '1791', ',', 'composer', 'Wolfgang', 'Amadeus', 'Mozart', 'died', 'in', 'Vienna', ',', 'Austria', ',', 'at', 'the', 'age', 'of', '35', '.'], 'entities': [[13, 15, 'Loc', 'United States'], [16, 19, 'Peop', 'Martin Van Buren'], [23, 26, 'Loc', 'Kinderhook , N.Y.'], [30, 33, 'Peop', 'Wolfgang Amadeus Mozart'], [35, 38, 'Loc', 'Vienna , Austria']], 'relations': [[30, 33, 35, 38, 'Live_In', 'Wolfgang Amadeus Mozart', 'Vienna , Austria'], [30, 33, 23, 26, 'Live_In', 'Wolfgang Amadeus Mozart', 'Kinderhook , N.Y.'], [16, 19, 23, 26, 'Live_In', 'Martin Van Buren', 'Kinderhook , N.Y.']], 'entity_gts': [[13, 15, 'Loc', 'United States'], [16, 19, 'Peop', 'Martin Van Buren'], [23, 26, 'Loc', 'Kinderhook , N.Y.'], [30, 33, 'Peop', 'Wolfgang Amadeus Mozart'], [35, 38, 'Loc', 'Vienna , Austria']], 'relation_gts': [[16, 19, 23, 26, 'Live_In', 'Martin Van Buren', 'Kinderhook , N.Y.']]}
# ===============================================
# 25
# {'tokens': ['U.S.', 'Coast', 'Guard', 'Training', 'Center', ',', 'Petaluma', ',', 'Calif.', ';'], 'entities': [[0, 1, 'Loc', 'U.S.'], [1, 3, 'Org', 'Coast Guard'], [6, 7, 'Loc', 'Petaluma'], [8, 9, 'Loc', 'Calif.']], 'relations': [[1, 3, 6, 7, 'OrgBased_In', 'Coast Guard', 'Petaluma'], [1, 3, 0, 1, 'OrgBased_In', 'Coast Guard', 'U.S.'], [6, 7, 8, 9, 'Located_In', 'Petaluma', 'Calif.'], [1, 3, 8, 9, 'OrgBased_In', 'Coast Guard', 'Calif.']], 'entity_gts': [[0, 5, 'Org', 'U.S. Coast Guard Training Center'], [6, 7, 'Loc', 'Petaluma'], [8, 9, 'Loc', 'Calif.']], 'relation_gts': [[0, 5, 6, 7, 'OrgBased_In', 'U.S. Coast Guard Training Center', 'Petaluma'], [0, 5, 8, 9, 'OrgBased_In', 'U.S. Coast Guard Training Center', 'Calif.'], [6, 7, 8, 9, 'Located_In', 'Petaluma', 'Calif.']]}
# ===============================================
# 26
# {'tokens': ['PM2303111794', 'Moscow', 'IZVESTIYA', 'in', 'Russian', '23', 'Mar', '94', 'p', '3'], 'entities': [[1, 2, 'Loc', 'Moscow'], [2, 3, 'Org', 'IZVESTIYA'], [5, 8, 'Other', '23 Mar 94']], 'relations': [[2, 3, 1, 2, 'OrgBased_In', 'IZVESTIYA', 'Moscow']], 'entity_gts': [[1, 2, 'Loc', 'Moscow'], [2, 3, 'Org', 'IZVESTIYA'], [5, 8, 'Other', '23 Mar 94']], 'relation_gts': [[2, 3, 1, 2, 'OrgBased_In', 'IZVESTIYA', 'Moscow']]}
# ===============================================
# 27
# {'tokens': ['Pepperell', ',', 'based', 'in', 'West', 'Point', ',', 'Ga.', ',', 'manufactures', 'Martex', 'towels', 'and', 'Arrow', 'shirts', 'and', 'has', 'about', 'a', 'quarter', 'of', 'the', 'nation', "'s", 'home', 'fashion', 'textile', 'market', '.'], 'entities': [[0, 1, 'Peop', 'Pepperell'], [4, 6, 'Loc', 'West Point'], [7, 8, 'Loc', 'Ga.'], [10, 11, 'Org', 'Martex']], 'relations': [[0, 1, 7, 8, 'Live_In', 'Pepperell', 'Ga.']], 'entity_gts': [[0, 1, 'Org', 'Pepperell'], [4, 6, 'Loc', 'West Point'], [7, 8, 'Loc', 'Ga.']], 'relation_gts': [[0, 1, 4, 6, 'OrgBased_In', 'Pepperell', 'West Point'], [0, 1, 7, 8, 'OrgBased_In', 'Pepperell', 'Ga.'], [4, 6, 7, 8, 'Located_In', 'West Point', 'Ga.']]}
# ===============================================
# 28
# {'tokens': ['In', 'a', 'brief', 'order', ',', 'the', 'justices', 'refused', 'to', 'reinstate', 'the', 'death', 'sentence', 'of', 'John', 'Harvey', 'Adamson', ',', 'who', 'was', 'convicted', 'of', 'murdering', 'Phoenix', 'newspaper', 'reporter', 'Don', 'Bolles', 'in', '1976', '.'], 'entities': [[14, 17, 'Peop', 'John Harvey Adamson'], [23, 24, 'Loc', 'Phoenix'], [26, 28, 'Peop', 'Don Bolles']], 'relations': [[26, 28, 23, 24, 'Live_In', 'Don Bolles', 'Phoenix']], 'entity_gts': [[14, 17, 'Peop', 'John Harvey Adamson'], [23, 24, 'Loc', 'Phoenix'], [26, 28, 'Peop', 'Don Bolles']], 'relation_gts': [[14, 17, 26, 28, 'Kill', 'John Harvey Adamson', 'Don Bolles']]}
# ===============================================
# 29
# {'tokens': ['Michael', 'R.', 'Gordon', ',', 'chairman', 'of', 'the', 'Montgomery', 'County', 'House', 'delegation', ',', 'thinks', 'Ms.', 'Toth', 'is', 'in', 'an', '`', '`', 'embarrassing', "'", "'", 'position', '.'], 'entities': [[0, 3, 'Peop', 'Michael R. Gordon'], [7, 10, 'Org', 'Montgomery County House'], [13, 15, 'Peop', 'Ms. Toth']], 'relations': [[0, 3, 7, 10, 'Work_For', 'Michael R. Gordon', 'Montgomery County House']], 'entity_gts': [[0, 3, 'Peop', 'Michael R. Gordon'], [7, 11, 'Org', 'Montgomery County House delegation'], [13, 15, 'Peop', 'Ms. Toth']], 'relation_gts': [[0, 3, 7, 11, 'Work_For', 'Michael R. Gordon', 'Montgomery County House delegation']]}
# ===============================================
# 30
# {'tokens': ['(', 'Text', ')', 'Vyacheslav', 'Chornovil', ',', 'leader', 'of', 'the', 'Ukrainian', 'Popular', 'Rukh', ',', 'intends', 'to', 'run', 'for', 'the', 'presidency', 'in', 'the', '26', 'June', ',', '1994', 'elections', ',', 'officials', 'in', 'the', 'Rukh', 'press', 'service', 'told', 'INTERFAX-Ukraine', '.'], 'entities': [[3, 5, 'Peop', 'Vyacheslav Chornovil'], [34, 35, 'Org', 'INTERFAX-Ukraine']], 'relations': [], 'entity_gts': [[3, 5, 'Peop', 'Vyacheslav Chornovil'], [9, 12, 'Org', 'Ukrainian Popular Rukh'], [21, 25, 'Other', '26 June , 1994'], [30, 32, 'Org', 'Rukh press'], [34, 35, 'Org', 'INTERFAX-Ukraine']], 'relation_gts': [[3, 5, 9, 12, 'Work_For', 'Vyacheslav Chornovil', 'Ukrainian Popular Rukh']]}
# ===============================================
# 31
# {'tokens': ['Slavko', 'Mestrovic', ',', 'secretary', 'of', 'the', 'Croatian', 'People', "'s", 'Party', ',', 'welcomes', 'the', 'deceleration', 'in', 'the', 'case', 'if', 'it', 'leads', 'toward', 'a', 'just', 'peace', ',', 'the', 'reintegration', 'of', 'the', 'occupied', 'Croatian', 'territories', ',', 'the', 'return', 'of', 'the', 'refugees', 'to', 'their', 'homes', ',', 'and', 'the', 'cessation', 'of', 'the', 'war', '.'], 'entities': [[0, 2, 'Peop', 'Slavko Mestrovic'], [6, 8, 'Org', 'Croatian People'], [30, 31, 'Loc', 'Croatian']], 'relations': [[0, 2, 6, 8, 'Work_For', 'Slavko Mestrovic', 'Croatian People']], 'entity_gts': [[0, 2, 'Peop', 'Slavko Mestrovic'], [6, 10, 'Org', "Croatian People 's Party"]], 'relation_gts': [[0, 2, 6, 10, 'Work_For', 'Slavko Mestrovic', "Croatian People 's Party"]]}
# ===============================================
# 32
# {'tokens': ['CDT', 'Tuesday', 'in', 'the', 'area', 'of', 'Port', 'Arther', 'and', 'Galveston', ',', 'Texas.'], 'entities': [[6, 8, 'Loc', 'Port Arther'], [9, 10, 'Loc', 'Galveston'], [11, 12, 'Loc', 'Texas.']], 'relations': [[6, 8, 11, 12, 'Located_In', 'Port Arther', 'Texas.'], [9, 10, 11, 12, 'Located_In', 'Galveston', 'Texas.'], [6, 8, 9, 10, 'Located_In', 'Port Arther', 'Galveston']], 'entity_gts': [[6, 8, 'Loc', 'Port Arther'], [9, 10, 'Loc', 'Galveston'], [11, 12, 'Loc', 'Texas.']], 'relation_gts': [[6, 8, 11, 12, 'Located_In', 'Port Arther', 'Texas.'], [9, 10, 11, 12, 'Located_In', 'Galveston', 'Texas.']]}
# ===============================================
# 33
# {'tokens': ['KAL', 'attorney', 'George', 'Tompkins', 'countered', 'that', 'the', 'main', 'evidence', 'in', 'the', 'case', 'is', 'a', 'line', 'drawn', 'by', 'Soviet', 'officials', 'on', 'a', 'map', 'showing', 'an', 'off-course', 'Flight', '007', 'flying', 'for', 'several', 'hours', 'over', 'Russian', 'airspace', 'hundreds', 'of', 'miles', 'to', 'the', 'west', 'of', 'its', 'planned', 'route.'], 'entities': [[2, 4, 'Peop', 'George Tompkins'], [17, 18, 'Loc', 'Soviet']], 'relations': [], 'entity_gts': [[0, 1, 'Org', 'KAL'], [2, 4, 'Peop', 'George Tompkins'], [17, 18, 'Loc', 'Soviet'], [25, 27, 'Other', 'Flight 007']], 'relation_gts': [[2, 4, 0, 1, 'Work_For', 'George Tompkins', 'KAL']]}
# ===============================================
# 34
# {'tokens': ['Jacobs', ',', '20', ',', 'and', 'Eddie', 'Hatcher', ',', '31', ',', 'were', 'charged', 'in', 'the', '1988', 'takeover', 'in', 'Lumberton', ',', 'N.C.'], 'entities': [[0, 1, 'Peop', 'Jacobs'], [5, 7, 'Peop', 'Eddie Hatcher'], [14, 15, 'Other', '1988'], [17, 18, 'Loc', 'Lumberton'], [19, 20, 'Loc', 'N.C.']], 'relations': [[17, 18, 19, 20, 'Located_In', 'Lumberton', 'N.C.'], [5, 7, 19, 20, 'Live_In', 'Eddie Hatcher', 'N.C.']], 'entity_gts': [[0, 1, 'Peop', 'Jacobs'], [5, 7, 'Peop', 'Eddie Hatcher'], [17, 18, 'Loc', 'Lumberton'], [19, 20, 'Loc', 'N.C.']], 'relation_gts': [[17, 18, 19, 20, 'Located_In', 'Lumberton', 'N.C.']]}
# ===============================================
# 35
# {'tokens': ['Jack', 'Ruby', 'bought', 'the', 'revolver', 'for', '$62.50', 'in', 'a', 'Dallas', 'gun', 'shop', 'and', 'used', 'it', 'to', 'shoot', 'Oswald', 'two', 'days', 'after', 'Kennedy', 'was', 'assassinated.'], 'entities': [[0, 2, 'Peop', 'Jack Ruby'], [9, 10, 'Loc', 'Dallas'], [17, 18, 'Peop', 'Oswald'], [21, 22, 'Peop', 'Kennedy']], 'relations': [[17, 18, 21, 22, 'Kill', 'Oswald', 'Kennedy']], 'entity_gts': [[0, 2, 'Peop', 'Jack Ruby'], [9, 10, 'Loc', 'Dallas'], [17, 18, 'Peop', 'Oswald'], [21, 22, 'Peop', 'Kennedy']], 'relation_gts': [[0, 2, 17, 18, 'Kill', 'Jack Ruby', 'Oswald']]}
# ===============================================
# 36
# {'tokens': ['In', 'the', 'communique', ',', 'the', 'Group', 'of', 'Rio', 'states', 'that', '"', 'the', 'Haitian', 'crisis', 'can', 'be', 'resolved', 'only', 'if', 'unrestricted', 'respect', 'is', 'shown', 'for', 'the', 'Governor', "'s", 'Island', 'Agreement', 'which', 'calls', 'for', 'the', 'prompt', 'return', 'of', 'Haitian', 'President', 'Jean', 'Bertrand', 'Aristide', 'to', 'the', 'exercise', 'of', 'his', 'constitutional', 'powers', 'in', 'Haiti', '.'], 'entities': [[12, 13, 'Loc', 'Haitian'], [25, 26, 'Loc', 'Governor'], [36, 37, 'Loc', 'Haitian'], [38, 41, 'Peop', 'Jean Bertrand Aristide'], [49, 50, 'Loc', 'Haiti']], 'relations': [], 'entity_gts': [[5, 8, 'Org', 'Group of Rio'], [38, 41, 'Peop', 'Jean Bertrand Aristide'], [49, 50, 'Loc', 'Haiti']], 'relation_gts': [[38, 41, 49, 50, 'Live_In', 'Jean Bertrand Aristide', 'Haiti']]}
# ===============================================
# 37
# {'tokens': ['In', '1882', ',', 'the', 'notorious', 'outlaw', 'Jesse', 'James', 'was', 'shot', 'to', 'death', 'in', 'St.', 'Joseph', ',', 'Mo.', ',', 'by', 'Robert', 'Ford', ',', 'a', 'member', 'of', 'his', 'own', 'gang', '.'], 'entities': [[6, 8, 'Peop', 'Jesse James'], [13, 17, 'Loc', 'St. Joseph , Mo.'], [19, 21, 'Peop', 'Robert Ford']], 'relations': [[19, 21, 6, 8, 'Kill', 'Robert Ford', 'Jesse James']], 'entity_gts': [[6, 8, 'Peop', 'Jesse James'], [13, 17, 'Loc', 'St. Joseph , Mo.'], [19, 21, 'Peop', 'Robert Ford']], 'relation_gts': [[19, 21, 6, 8, 'Kill', 'Robert Ford', 'Jesse James']]}
# ===============================================
# 38
# {'tokens': ['Robert', 'Bernero', ',', 'chief', 'of', 'waste', 'disposal', 'for', 'the', 'NRC', ',', 'said', 'the', 'shafts', 'would', 'be', '`', '`', 'the', 'first', 'major', 'holes', 'to', 'be', 'dug', 'into', 'the', 'Yucca', 'Mountain', 'formation.', "'", "'"], 'entities': [[0, 2, 'Peop', 'Robert Bernero'], [9, 10, 'Org', 'NRC'], [27, 28, 'Loc', 'Yucca']], 'relations': [[0, 2, 9, 10, 'Work_For', 'Robert Bernero', 'NRC']], 'entity_gts': [[0, 2, 'Peop', 'Robert Bernero'], [9, 10, 'Org', 'NRC'], [27, 29, 'Loc', 'Yucca Mountain']], 'relation_gts': [[0, 2, 9, 10, 'Work_For', 'Robert Bernero', 'NRC']]}
# ===============================================
# 39
# {'tokens': ['Datuk', 'Sri', 'Dr.', 'Mahathir', 'said', 'the', 'two', 'leaders', 'had', 'invited', 'him', 'to', 'make', 'an', 'official', 'visit', 'to', 'South', 'Africa', 'and', 'he', 'also', 'had', 'extended', 'invitations', 'to', 'the', 'two', 'to', 'make', 'a', 'similar', 'visit', 'to', 'Malaysia', '.'], 'entities': [[3, 4, 'Peop', 'Mahathir'], [17, 19, 'Loc', 'South Africa'], [34, 35, 'Loc', 'Malaysia']], 'relations': [[3, 4, 34, 35, 'Live_In', 'Mahathir', 'Malaysia']], 'entity_gts': [[0, 4, 'Peop', 'Datuk Sri Dr. Mahathir'], [17, 19, 'Loc', 'South Africa'], [34, 35, 'Loc', 'Malaysia']], 'relation_gts': [[0, 4, 34, 35, 'Live_In', 'Datuk Sri Dr. Mahathir', 'Malaysia']]}
# ===============================================
# 40
# {'tokens': ['Moscow', 'ITAR-TASS'], 'entities': [[0, 2, 'Loc', 'Moscow ITAR-TASS']], 'relations': [], 'entity_gts': [[0, 1, 'Loc', 'Moscow'], [1, 2, 'Org', 'ITAR-TASS']], 'relation_gts': [[1, 2, 0, 1, 'OrgBased_In', 'ITAR-TASS', 'Moscow']]}
# ===============================================
# 41
# {'tokens': ['The', 'Environmental', 'Protection', 'Agency', 'is', 'working', 'on', 'a', 'brochure', 'advising', 'diabetics', 'of', 'the', 'best', 'way', 'to', 'dispose', 'of', 'needles', ',', 'said', 'Robin', 'Woods', ',', 'a', 'spokeswoman', 'for', 'the', 'agency', 'in', 'Washington', ',', 'D.C.', 'It', 'will', 'suggest', 'that', 'diabetics', 'place', '`', '`', 'sharps', "'", "'", '_', 'the', 'needle', 'end', 'of', 'a', 'syringe', '_', 'in', 'a', 'hard', 'plastic', 'or', 'metal', 'container', 'like', 'a', 'coffee', 'can', 'before', 'throwing', 'it', 'in', 'the', 'trash', ',', 'Woods', 'said.'], 'entities': [[1, 4, 'Org', 'Environmental Protection Agency'], [21, 23, 'Peop', 'Robin Woods'], [30, 31, 'Loc', 'Washington'], [32, 33, 'Loc', 'D.C.'], [70, 71, 'Peop', 'Woods']], 'relations': [], 'entity_gts': [[0, 4, 'Org', 'The Environmental Protection Agency'], [21, 23, 'Peop', 'Robin Woods'], [30, 33, 'Loc', 'Washington , D.C.'], [70, 71, 'Peop', 'Woods']], 'relation_gts': [[0, 4, 30, 33, 'OrgBased_In', 'The Environmental Protection Agency', 'Washington , D.C.'], [21, 23, 0, 4, 'Work_For', 'Robin Woods', 'The Environmental Protection Agency'], [70, 71, 0, 4, 'Work_For', 'Woods', 'The Environmental Protection Agency']]}
# ===============================================
# 42
# {'tokens': ['True', ',', 'Woodrow', 'Wilson', 'was', 'born', 'in', 'Virginia', ',', 'but', 'he', 'won', 'his', 'political', 'fame', 'as', 'governor', 'of', 'New', 'Jersey', ',', 'so', 'he', 'hardly', 'counted', 'as', 'a', 'Southerner', 'in', 'political', 'terms', '.'], 'entities': [[2, 4, 'Peop', 'Woodrow Wilson'], [7, 8, 'Loc', 'Virginia'], [18, 20, 'Loc', 'New Jersey']], 'relations': [[2, 4, 18, 20, 'Live_In', 'Woodrow Wilson', 'New Jersey'], [2, 4, 7, 8, 'Live_In', 'Woodrow Wilson', 'Virginia']], 'entity_gts': [[2, 4, 'Peop', 'Woodrow Wilson'], [7, 8, 'Loc', 'Virginia'], [18, 20, 'Loc', 'New Jersey'], [27, 28, 'Other', 'Southerner']], 'relation_gts': [[2, 4, 7, 8, 'Live_In', 'Woodrow Wilson', 'Virginia']]}
# ===============================================
# 43
# {'tokens': ['`', '`', 'You', 'can', 'count', 'it', 'on', 'your', 'fingertips', ',', "'", "'", 'said', 'veteran', 'Miami', 'Beach', 'political', 'Gerald', 'Schwartz.'], 'entities': [[14, 16, 'Loc', 'Miami Beach'], [17, 19, 'Peop', 'Gerald Schwartz.']], 'relations': [[17, 19, 14, 16, 'Live_In', 'Gerald Schwartz.', 'Miami Beach']], 'entity_gts': [[14, 16, 'Loc', 'Miami Beach'], [17, 19, 'Peop', 'Gerald Schwartz.']], 'relation_gts': [[17, 19, 14, 16, 'Live_In', 'Gerald Schwartz.', 'Miami Beach']]}
# ===============================================
# 44
# {'tokens': ['Not', 'content', 'with', 'that', 'major', 'error', ',', 'the', 'Journal', 'editorial', 'illustrated', 'a', 'lack', 'of', 'understanding', 'of', 'the', 'overwhelming', 'evidence', 'in', 'the', 'Warren', 'Commission', 'Report', 'proving', 'that', 'Lee', 'Harvey', 'Oswald', 'was', 'the', 'lone', 'gunman', 'who', 'killed', 'President', 'Kennedy', 'and', 'who', '45', 'minutes', 'later', 'killed', 'Dallas', 'Police', 'Officer', 'J.D.', 'Tippit.'], 'entities': [[8, 9, 'Org', 'Journal'], [21, 23, 'Org', 'Warren Commission'], [26, 29, 'Peop', 'Lee Harvey Oswald'], [35, 37, 'Peop', 'President Kennedy'], [43, 45, 'Loc', 'Dallas Police']], 'relations': [[26, 29, 35, 37, 'Kill', 'Lee Harvey Oswald', 'President Kennedy']], 'entity_gts': [[8, 9, 'Org', 'Journal'], [21, 24, 'Other', 'Warren Commission Report'], [26, 29, 'Peop', 'Lee Harvey Oswald'], [35, 37, 'Peop', 'President Kennedy'], [43, 48, 'Peop', 'Dallas Police Officer J.D. Tippit.']], 'relation_gts': [[26, 29, 35, 37, 'Kill', 'Lee Harvey Oswald', 'President Kennedy'], [26, 29, 43, 48, 'Kill', 'Lee Harvey Oswald', 'Dallas Police Officer J.D. Tippit.']]}
# ===============================================
# 45
# {'tokens': ['Meanwhile', ',', 'on', 'a', 'separate', 'occasion', ',', 'Prince', 'Ranariddh', ',', 'first', 'prime', 'of', 'Cambodia', ',', 'reiterated', 'the', 'Phnom', 'Penh', 'government', "'s", 'wish', 'to', 'open', 'a', 'Cambodian', 'Embassy', 'in', 'Jakarta', 'as', 'soon', 'as', 'possible', '.'], 'entities': [[13, 14, 'Loc', 'Cambodia'], [17, 19, 'Loc', 'Phnom Penh'], [28, 29, 'Loc', 'Jakarta']], 'relations': [], 'entity_gts': [[7, 9, 'Peop', 'Prince Ranariddh'], [13, 14, 'Loc', 'Cambodia'], [17, 20, 'Org', 'Phnom Penh government'], [28, 29, 'Loc', 'Jakarta']], 'relation_gts': [[7, 9, 13, 14, 'Live_In', 'Prince Ranariddh', 'Cambodia'], [7, 9, 17, 20, 'Work_For', 'Prince Ranariddh', 'Phnom Penh government'], [17, 20, 13, 14, 'OrgBased_In', 'Phnom Penh government', 'Cambodia']]}
# ===============================================
# 46
# {'tokens': ['Church', "'s", 'is', 'headquartered', 'in', 'San', 'Antonio', '.'], 'entities': [[0, 1, 'Peop', 'Church'], [5, 7, 'Loc', 'San Antonio']], 'relations': [], 'entity_gts': [[0, 2, 'Org', "Church 's"], [5, 7, 'Loc', 'San Antonio']], 'relation_gts': [[0, 2, 5, 7, 'OrgBased_In', "Church 's", 'San Antonio']]}
# ===============================================
# 47
# {'tokens': ['He', 'graduated', 'from', 'high', 'school', 'from', 'Benton', ',', 'Tenn.', 'and', 'from', 'Tennessee', 'Tech', 'in', 'Cookville', ',', 'and', 'holds', 'a', 'doctorate', 'in', 'physics', 'from', 'Virginia', 'Tech', '.'], 'entities': [[6, 7, 'Loc', 'Benton'], [8, 9, 'Loc', 'Tenn.'], [11, 13, 'Loc', 'Tennessee Tech'], [14, 15, 'Loc', 'Cookville'], [23, 25, 'Org', 'Virginia Tech']], 'relations': [[6, 7, 8, 9, 'Located_In', 'Benton', 'Tenn.']], 'entity_gts': [[6, 7, 'Loc', 'Benton'], [8, 9, 'Loc', 'Tenn.'], [11, 13, 'Org', 'Tennessee Tech'], [14, 15, 'Loc', 'Cookville'], [23, 25, 'Org', 'Virginia Tech']], 'relation_gts': [[6, 7, 8, 9, 'Located_In', 'Benton', 'Tenn.'], [11, 13, 8, 9, 'OrgBased_In', 'Tennessee Tech', 'Tenn.'], [11, 13, 14, 15, 'OrgBased_In', 'Tennessee Tech', 'Cookville'], [14, 15, 8, 9, 'Located_In', 'Cookville', 'Tenn.']]}
# ===============================================
# 48
# {'tokens': ['In', '1893', ',', 'comedian', 'Harold', 'Lloyd', 'was', 'born', 'in', 'Burchard', ',', 'Neb', '.'], 'entities': [[4, 6, 'Peop', 'Harold Lloyd'], [9, 12, 'Loc', 'Burchard , Neb']], 'relations': [[4, 6, 9, 12, 'Live_In', 'Harold Lloyd', 'Burchard , Neb']], 'entity_gts': [[4, 6, 'Peop', 'Harold Lloyd'], [9, 12, 'Loc', 'Burchard , Neb']], 'relation_gts': [[4, 6, 9, 12, 'Live_In', 'Harold Lloyd', 'Burchard , Neb']]}
# ===============================================
# 49
# {'tokens': ['Sofia', 'BTA'], 'entities': [[0, 1, 'Loc', 'Sofia'], [1, 2, 'Org', 'BTA']], 'relations': [[1, 2, 0, 1, 'OrgBased_In', 'BTA', 'Sofia']], 'entity_gts': [[0, 1, 'Loc', 'Sofia'], [1, 2, 'Org', 'BTA']], 'relation_gts': [[1, 2, 0, 1, 'OrgBased_In', 'BTA', 'Sofia']]}
# ===============================================
# 50
# {'tokens': ['In', '1752', ',', 'flagmaker', 'Betsy', 'Ross', 'was', 'born', 'in', 'Philadelphia', '.'], 'entities': [[4, 6, 'Peop', 'Betsy Ross'], [9, 10, 'Loc', 'Philadelphia']], 'relations': [[4, 6, 9, 10, 'Live_In', 'Betsy Ross', 'Philadelphia']], 'entity_gts': [[4, 6, 'Peop', 'Betsy Ross'], [9, 10, 'Loc', 'Philadelphia']], 'relation_gts': [[4, 6, 9, 10, 'Live_In', 'Betsy Ross', 'Philadelphia']]}
# ===============================================
# 51
# {'tokens': ['GSA', 'Depot', ',', 'Davisville', ',', 'R.I.', ';', 'and', 'Mineral', 'Wells', ',', 'Texas', '.'], 'entities': [[0, 1, 'Org', 'GSA'], [3, 4, 'Loc', 'Davisville'], [5, 6, 'Loc', 'R.I.'], [8, 9, 'Loc', 'Mineral'], [9, 10, 'Loc', 'Wells'], [11, 12, 'Loc', 'Texas']], 'relations': [[0, 1, 9, 10, 'OrgBased_In', 'GSA', 'Wells'], [0, 1, 8, 9, 'OrgBased_In', 'GSA', 'Mineral'], [8, 9, 11, 12, 'Located_In', 'Mineral', 'Texas'], [3, 4, 5, 6, 'Located_In', 'Davisville', 'R.I.'], [0, 1, 3, 4, 'OrgBased_In', 'GSA', 'Davisville'], [9, 10, 11, 12, 'Located_In', 'Wells', 'Texas']], 'entity_gts': [[0, 2, 'Loc', 'GSA Depot'], [3, 4, 'Loc', 'Davisville'], [5, 6, 'Loc', 'R.I.'], [8, 10, 'Loc', 'Mineral Wells'], [11, 12, 'Loc', 'Texas']], 'relation_gts': [[0, 2, 3, 4, 'Located_In', 'GSA Depot', 'Davisville'], [0, 2, 5, 6, 'Located_In', 'GSA Depot', 'R.I.'], [3, 4, 5, 6, 'Located_In', 'Davisville', 'R.I.'], [8, 10, 11, 12, 'Located_In', 'Mineral Wells', 'Texas']]}
# ===============================================
# 52
# {'tokens': ['King', 'rose', 'to', 'prominence', 'after', 'Mrs.', 'Parks', "'", 'action', 'in', 'December', '1955', 'in', 'Montgomery', ',', 'Ala.', ',', 'set', 'the', 'stage', 'for', 'a', 'boycott', 'and', 'subsequent', 'demonstrations', 'that', 'caught', 'the', 'nation', 'by', 'surprise', '.'], 'entities': [[0, 1, 'Peop', 'King'], [5, 7, 'Peop', 'Mrs. Parks'], [13, 14, 'Loc', 'Montgomery'], [15, 16, 'Loc', 'Ala.']], 'relations': [[13, 14, 15, 16, 'Located_In', 'Montgomery', 'Ala.'], [5, 7, 13, 14, 'Live_In', 'Mrs. Parks', 'Montgomery']], 'entity_gts': [[0, 1, 'Peop', 'King'], [5, 7, 'Peop', 'Mrs. Parks'], [11, 12, 'Other', '1955'], [13, 14, 'Loc', 'Montgomery'], [15, 16, 'Loc', 'Ala.']], 'relation_gts': [[5, 7, 13, 14, 'Live_In', 'Mrs. Parks', 'Montgomery'], [5, 7, 15, 16, 'Live_In', 'Mrs. Parks', 'Ala.'], [13, 14, 15, 16, 'Located_In', 'Montgomery', 'Ala.']]}
# ===============================================
# 53
# {'tokens': ['Kennedy', 'had', 'just', 'won', 'California', "'s", 'Democratic', 'presidential', 'primary', 'when', 'Sirhan', 'shot', 'him', 'in', 'Los', 'Angeles', 'on', 'June', '5', ',', '1968', '.'], 'entities': [[0, 1, 'Peop', 'Kennedy'], [4, 5, 'Loc', 'California'], [10, 11, 'Peop', 'Sirhan'], [14, 16, 'Loc', 'Los Angeles'], [17, 18, 'Other', 'June']], 'relations': [[10, 11, 0, 1, 'Kill', 'Sirhan', 'Kennedy']], 'entity_gts': [[0, 1, 'Peop', 'Kennedy'], [4, 5, 'Loc', 'California'], [10, 11, 'Peop', 'Sirhan'], [14, 16, 'Loc', 'Los Angeles'], [17, 18, 'Other', 'June']], 'relation_gts': [[10, 11, 0, 1, 'Kill', 'Sirhan', 'Kennedy']]}
# ===============================================
# 54
# {'tokens': ['Dan', 'Quayle', "'s", 'first', 'trip', 'out', 'of', 'the', 'country', 'as', 'vice', 'is', 'likely', 'to', 'be', 'to', 'Caracas', ',', 'Venezuela', ',', 'for', 'Carlos', 'Andres', 'Perez', "'s", 'presidential', 'inauguration', 'on', 'Feb.', '2', ',', 'an', 'official', 'in', 'President-elect', 'Bush', "'s", 'transition', 'said', 'Thursday', '.'], 'entities': [[0, 2, 'Peop', 'Dan Quayle'], [16, 17, 'Loc', 'Caracas'], [18, 19, 'Loc', 'Venezuela'], [21, 24, 'Peop', 'Carlos Andres Perez'], [28, 30, 'Other', 'Feb. 2']], 'relations': [[16, 17, 18, 19, 'Located_In', 'Caracas', 'Venezuela']], 'entity_gts': [[0, 2, 'Peop', 'Dan Quayle'], [16, 17, 'Loc', 'Caracas'], [18, 19, 'Loc', 'Venezuela'], [21, 24, 'Peop', 'Carlos Andres Perez'], [28, 31, 'Other', 'Feb. 2 ,']], 'relation_gts': [[16, 17, 18, 19, 'Located_In', 'Caracas', 'Venezuela'], [21, 24, 16, 17, 'Live_In', 'Carlos Andres Perez', 'Caracas'], [21, 24, 18, 19, 'Live_In', 'Carlos Andres Perez', 'Venezuela']]}
# ===============================================
# 55
# {'tokens': ['Rogers', ',', 'a', 'native', 'of', 'Fort', 'Worth', ',', 'Texas', ',', 'has', 'a', 'dry', 'wit', 'and', 'so', 'much', 'of', 'the', 'American', 'southwest', 'in', 'his', 'manner', 'and', 'voice', 'that', 'he', 'spends', 'a', 'lot', 'of', 'time', 'denying', 'he', "'s", 'related', 'to', 'the', 'famous', 'Oklahoma', 'cowboy', 'humorist', 'Will', 'Rogers', '.'], 'entities': [[0, 1, 'Peop', 'Rogers'], [5, 7, 'Loc', 'Fort Worth'], [8, 9, 'Loc', 'Texas'], [40, 41, 'Loc', 'Oklahoma'], [43, 45, 'Peop', 'Will Rogers']], 'relations': [[0, 1, 5, 7, 'Live_In', 'Rogers', 'Fort Worth'], [43, 45, 40, 41, 'Live_In', 'Will Rogers', 'Oklahoma'], [5, 7, 8, 9, 'Located_In', 'Fort Worth', 'Texas']], 'entity_gts': [[0, 1, 'Peop', 'Rogers'], [5, 9, 'Loc', 'Fort Worth , Texas'], [40, 41, 'Loc', 'Oklahoma'], [43, 45, 'Peop', 'Will Rogers']], 'relation_gts': [[0, 1, 5, 9, 'Live_In', 'Rogers', 'Fort Worth , Texas']]}
# ===============================================
# 56
# {'tokens': ['The', 'registrar', 'of', 'the', 'University', 'of', 'Nigeria', "'s", 'Nsukka', 'campus', ',', 'U.', 'Umeh', ',', 'said', 'he', 'had', 'closed', 'the', 'university', 'on', 'the', 'advice', 'of', 'the', 'government', '.'], 'entities': [[4, 5, 'Org', 'University'], [6, 7, 'Loc', 'Nigeria'], [8, 9, 'Loc', 'Nsukka'], [11, 13, 'Peop', 'U. Umeh']], 'relations': [[11, 13, 8, 9, 'Live_In', 'U. Umeh', 'Nsukka'], [11, 13, 6, 7, 'Live_In', 'U. Umeh', 'Nigeria'], [11, 13, 4, 5, 'Work_For', 'U. Umeh', 'University'], [4, 5, 6, 7, 'OrgBased_In', 'University', 'Nigeria']], 'entity_gts': [[4, 5, 'Other', 'University'], [6, 7, 'Loc', 'Nigeria'], [8, 9, 'Loc', 'Nsukka'], [11, 13, 'Other', 'U. Umeh']], 'relation_gts': [[8, 9, 6, 7, 'Located_In', 'Nsukka', 'Nigeria']]}
# ===============================================
# 57
# {'tokens': ['In', 'Colorado', ',', '13', 'inches', 'of', 'snow', 'in', 'Denver', 'Wednesday', 'prompted', 'officials', 'to', 'close', 'Interstate', '270', 'temporarily', '.'], 'entities': [[1, 2, 'Loc', 'Colorado'], [3, 4, 'Other', '13'], [8, 9, 'Loc', 'Denver']], 'relations': [[8, 9, 1, 2, 'Located_In', 'Denver', 'Colorado']], 'entity_gts': [[1, 2, 'Loc', 'Colorado'], [3, 5, 'Other', '13 inches'], [8, 9, 'Loc', 'Denver']], 'relation_gts': [[8, 9, 1, 2, 'Located_In', 'Denver', 'Colorado']]}
# ===============================================
# 58
# {'tokens': ['Edward', 'Marks', ',', 'an', 'official', 'with', 'the', 'Montgomery', 'County', 'Democratic', 'Party', ',', 'argued', 'that', 'if', 'Ms.', 'Toth', 'is', 'not', 'interested', 'in', 'the', 'job', ',', '`', '`', 'she', 'should', 'get', 'out.', '..', '.'], 'entities': [[0, 2, 'Peop', 'Edward Marks'], [7, 11, 'Org', 'Montgomery County Democratic Party'], [15, 17, 'Peop', 'Ms. Toth']], 'relations': [[0, 2, 7, 11, 'Work_For', 'Edward Marks', 'Montgomery County Democratic Party']], 'entity_gts': [[0, 2, 'Peop', 'Edward Marks'], [7, 11, 'Org', 'Montgomery County Democratic Party'], [15, 17, 'Peop', 'Ms. Toth']], 'relation_gts': [[0, 2, 7, 11, 'Work_For', 'Edward Marks', 'Montgomery County Democratic Party']]}
# ===============================================
# 59
# {'tokens': ['Moscow', 'IZVESTIYA'], 'entities': [[0, 2, 'Loc', 'Moscow IZVESTIYA']], 'relations': [], 'entity_gts': [[0, 1, 'Loc', 'Moscow'], [1, 2, 'Org', 'IZVESTIYA']], 'relation_gts': [[1, 2, 0, 1, 'OrgBased_In', 'IZVESTIYA', 'Moscow']]}
# ===============================================
# 60
# {'tokens': ['He', 'said', 'he', 'only', 'learned', 'his', 'father', 'was', 'a', 'war-stress', 'patient', 'at', 'St.', 'Nicholas', 'Hospital', 'in', 'Gosforth', 'in', 'northeast', 'England', 'after', 'he', 'died', 'two', 'years', 'ago', '.'], 'entities': [[12, 13, 'Loc', 'St.'], [16, 17, 'Loc', 'Gosforth'], [18, 19, 'Loc', 'northeast'], [19, 20, 'Loc', 'England']], 'relations': [[16, 17, 19, 20, 'Located_In', 'Gosforth', 'England'], [16, 17, 18, 19, 'Located_In', 'Gosforth', 'northeast']], 'entity_gts': [[12, 15, 'Org', 'St. Nicholas Hospital'], [16, 17, 'Loc', 'Gosforth'], [19, 20, 'Loc', 'England'], [23, 25, 'Other', 'two years']], 'relation_gts': [[12, 15, 16, 17, 'OrgBased_In', 'St. Nicholas Hospital', 'Gosforth'], [12, 15, 19, 20, 'OrgBased_In', 'St. Nicholas Hospital', 'England'], [16, 17, 19, 20, 'Located_In', 'Gosforth', 'England']]}
# ===============================================
# 61
# {'tokens': ['ROYAL', 'OAK', ',', 'Mich', '.'], 'entities': [[0, 1, 'Loc', 'ROYAL'], [1, 2, 'Loc', 'OAK']], 'relations': [], 'entity_gts': [[0, 2, 'Loc', 'ROYAL OAK'], [3, 5, 'Loc', 'Mich .']], 'relation_gts': [[0, 2, 3, 5, 'Located_In', 'ROYAL OAK', 'Mich .']]}
# ===============================================
# 62
# {'tokens': ['The', 'Coast', 'Guard', 'rescued', 'seven', 'people', 'from', 'a', 'sinking', 'shrimp', 'boat', 'near', 'the', 'Sabine', 'Pass', 'station', ',', 'said', 'station', 'chief', 'Kenneth', 'Compton.'], 'entities': [[1, 3, 'Org', 'Coast Guard'], [13, 15, 'Loc', 'Sabine Pass'], [20, 22, 'Peop', 'Kenneth Compton.']], 'relations': [[20, 22, 1, 3, 'Work_For', 'Kenneth Compton.', 'Coast Guard']], 'entity_gts': [[1, 3, 'Org', 'Coast Guard'], [13, 16, 'Loc', 'Sabine Pass station'], [20, 22, 'Peop', 'Kenneth Compton.']], 'relation_gts': [[20, 22, 1, 3, 'Work_For', 'Kenneth Compton.', 'Coast Guard']]}
# ===============================================
# 63
# {'tokens': ['Most', 'of', 'the', 'work', 'conducted', 'by', 'the', 'Warren', 'Commission', ',', 'which', 'concluded', 'that', 'Lee', 'Harvey', 'Oswald', 'acted', 'alone', 'in', 'the', 'Kennedy', 'slaying', ',', 'has', 'been', 'opened', 'to', 'the', 'public', ',', 'a', 'move', 'that', 'has', 'helped', 'researchers', 'evaluate', '_', 'and', 'in', 'many', 'cases', 'strongly', 'criticize', '_', 'that', 'investigation', '.'], 'entities': [[7, 9, 'Org', 'Warren Commission'], [13, 16, 'Peop', 'Lee Harvey Oswald'], [20, 21, 'Peop', 'Kennedy']], 'relations': [[13, 16, 20, 21, 'Kill', 'Lee Harvey Oswald', 'Kennedy']], 'entity_gts': [[7, 9, 'Org', 'Warren Commission'], [13, 16, 'Peop', 'Lee Harvey Oswald'], [20, 21, 'Peop', 'Kennedy']], 'relation_gts': [[13, 16, 20, 21, 'Kill', 'Lee Harvey Oswald', 'Kennedy']]}
# ===============================================
# 64
# {'tokens': ['In', '1898', ',', 'composer', 'George', 'Gershwin', 'was', 'born', 'in', 'New', 'York', '.'], 'entities': [[4, 6, 'Peop', 'George Gershwin'], [9, 11, 'Loc', 'New York']], 'relations': [[4, 6, 9, 11, 'Live_In', 'George Gershwin', 'New York']], 'entity_gts': [[4, 6, 'Peop', 'George Gershwin'], [9, 11, 'Loc', 'New York']], 'relation_gts': [[4, 6, 9, 11, 'Live_In', 'George Gershwin', 'New York']]}
# ===============================================
# 65
# {'tokens': ['He', 'disclosed', 'that', 'engineers', 'at', 'the', 'St.', 'Petersburg', 'branch', 'of', 'the', 'Atomenergoproekt', 'institute', 'were', 'completing', 'work', 'on', 'the', 'design', 'of', 'a', 'new', 'NP-500', 'reactor', '.'], 'entities': [[6, 7, 'Loc', 'St.'], [7, 8, 'Loc', 'Petersburg']], 'relations': [], 'entity_gts': [[6, 8, 'Loc', 'St. Petersburg'], [11, 13, 'Org', 'Atomenergoproekt institute']], 'relation_gts': [[11, 13, 6, 8, 'OrgBased_In', 'Atomenergoproekt institute', 'St. Petersburg']]}
# ===============================================
# 66
# {'tokens': ['But', 'four', 'years', 'later', ',', 'Wright', 'said', 'he', 'would', 'vote', 'against', 'Barry', 'Goldwater', 'because', 'he', 'felt', 'the', 'Arizona', 'senator', 'supported', 'a', '`', '`', 'slowdown', 'on', 'civil', 'rights', "'", "'", 'and', 'would', 'take', 'a', '`', '`', 'harder', ',', 'more', 'dangerous', 'line', 'on', 'foreign', 'relations.', "'", "'"], 'entities': [[5, 6, 'Peop', 'Wright'], [11, 13, 'Peop', 'Barry Goldwater'], [17, 18, 'Loc', 'Arizona'], [25, 27, 'Loc', 'civil rights']], 'relations': [[11, 13, 17, 18, 'Live_In', 'Barry Goldwater', 'Arizona']], 'entity_gts': [[1, 3, 'Other', 'four years'], [5, 6, 'Peop', 'Wright'], [11, 13, 'Peop', 'Barry Goldwater'], [17, 18, 'Loc', 'Arizona']], 'relation_gts': [[11, 13, 17, 18, 'Live_In', 'Barry Goldwater', 'Arizona']]}
# ===============================================
# 67
# ...
# ===============================================
# 813
# {'tokens': ['Police', 'Major', 'Pramot', 'said', 'that', 'even', 'though', 'officials', 'managed', 'to', 'destroy', 'a', 'large', 'number', 'of', 'poppy', 'plants', ',', 'he', 'ordered', 'Police', 'Colonel', 'Suraphong', 'Khemasingkhi', ',', 'the', 'superintendent', 'of', 'BPP', 'Unit', '24', ',', 'to', 'mobilize', 'a', 'team', 'of', 'BPP', 'officials', 'and', 'asked', 'for', 'the', 'cooperation', 'of', 'the', 'units', 'concerned', 'to', 'destroy', 'the', 'rest', '.'], 'entities': [[2, 3, 'Peop', 'Pramot'], [22, 24, 'Peop', 'Suraphong Khemasingkhi'], [28, 29, 'Org', 'BPP'], [37, 38, 'Org', 'BPP']], 'relations': [[22, 24, 28, 29, 'Work_For', 'Suraphong Khemasingkhi', 'BPP']], 'entity_gts': [[2, 3, 'Peop', 'Pramot'], [22, 24, 'Peop', 'Suraphong Khemasingkhi'], [28, 31, 'Org', 'BPP Unit 24']], 'relation_gts': [[22, 24, 28, 31, 'Work_For', 'Suraphong Khemasingkhi', 'BPP Unit 24']]}
# ===============================================
# 814
# {'tokens': ['(', 'Editorial', 'Report', ')', 'The', '11', 'April', 'Jakarta', 'BISNIS', 'INDONESIA', 'in', 'Indonesian', 'on', 'page', '5', 'reported', 'that', 'the', 'recently', 'established', 'East', 'Asian', 'Growth', 'Area', '(', 'EAGA', ')', 'encompassing', 'the', 'eastern', 'region', 'of', 'Indonesia', ',', 'the', 'Malaysian', 'states', 'of', 'Sabah', 'and', 'Sarawak', ',', 'Brunei', ',', 'and', 'the', 'Mindanao', 'islands', 'of', 'the', 'Philippines', '-', '-', 'is', 'expected', 'to', 'increase', 'Indonesia', "'s", 'exports', 'from', 'its', 'eastern', 'region.'], 'entities': [[5, 7, 'Other', '11 April'], [7, 10, 'Loc', 'Jakarta BISNIS INDONESIA'], [20, 24, 'Org', 'East Asian Growth Area'], [25, 26, 'Org', 'EAGA'], [32, 33, 'Loc', 'Indonesia'], [38, 39, 'Loc', 'Sabah'], [40, 41, 'Loc', 'Sarawak'], [42, 43, 'Loc', 'Brunei'], [46, 47, 'Loc', 'Mindanao'], [50, 51, 'Loc', 'Philippines'], [57, 58, 'Loc', 'Indonesia']], 'relations': [], 'entity_gts': [[5, 7, 'Other', '11 April'], [7, 8, 'Loc', 'Jakarta'], [8, 10, 'Org', 'BISNIS INDONESIA'], [20, 24, 'Loc', 'East Asian Growth Area'], [25, 26, 'Loc', 'EAGA'], [32, 33, 'Loc', 'Indonesia'], [38, 39, 'Loc', 'Sabah'], [40, 41, 'Loc', 'Sarawak'], [42, 43, 'Loc', 'Brunei'], [46, 48, 'Loc', 'Mindanao islands'], [49, 51, 'Loc', 'the Philippines'], [57, 58, 'Loc', 'Indonesia']], 'relation_gts': [[8, 10, 32, 33, 'OrgBased_In', 'BISNIS INDONESIA', 'Indonesia'], [8, 10, 57, 58, 'OrgBased_In', 'BISNIS INDONESIA', 'Indonesia'], [46, 48, 49, 51, 'Located_In', 'Mindanao islands', 'the Philippines']]}
# ===============================================
# 815
# {'tokens': ['PA2105201294', 'Panama', 'City', 'ACAN', 'in', 'Spanish', '1742', 'GMT', '21', 'May', '94'], 'entities': [[1, 3, 'Loc', 'Panama City'], [6, 8, 'Other', '1742 GMT'], [8, 11, 'Other', '21 May 94']], 'relations': [], 'entity_gts': [[1, 3, 'Loc', 'Panama City'], [3, 4, 'Org', 'ACAN'], [6, 8, 'Other', '1742 GMT'], [8, 11, 'Other', '21 May 94']], 'relation_gts': [[3, 4, 1, 3, 'OrgBased_In', 'ACAN', 'Panama City']]}
# ===============================================
# 816
# {'tokens': ['Washington', ':', 'About', '110', 'firefighters', 'cut', 'a', 'containment', 'line', 'most', 'of', 'the', 'way', 'around', 'an', '850-acre', 'forest', 'fire', 'in', 'the', 'Pasayten', 'Wilderness', 'near', 'the', 'Canadian', 'border', 'Tuesday.'], 'entities': [[0, 1, 'Loc', 'Washington'], [20, 22, 'Loc', 'Pasayten Wilderness'], [24, 25, 'Loc', 'Canadian']], 'relations': [], 'entity_gts': [[0, 1, 'Loc', 'Washington'], [20, 22, 'Loc', 'Pasayten Wilderness']], 'relation_gts': [[20, 22, 0, 1, 'Located_In', 'Pasayten Wilderness', 'Washington']]}
# ===============================================
# 817
# {'tokens': ['SOVETSKAYA', 'ROSSIA', '(', 'opposition', 'newspaper', ')', 'gives', 'a', 'digest', 'of', 'the', 'report', 'on', 'social', 'and', 'economic', 'situation', 'in', 'Russia', 'compiled', 'by', 'the', 'Russian', 'Statistics', 'Committee', ',', 'which', 'was', 'circulated', 'in', 'the', 'Kremlin', 'among', 'participants', 'in', 'the', 'enlarged', 'meeting', 'of', 'the', 'government', '.'], 'entities': [[0, 2, 'Loc', 'SOVETSKAYA ROSSIA'], [18, 19, 'Loc', 'Russia']], 'relations': [], 'entity_gts': [[18, 19, 'Loc', 'Russia'], [22, 25, 'Org', 'Russian Statistics Committee'], [31, 32, 'Loc', 'Kremlin']], 'relation_gts': [[22, 25, 18, 19, 'OrgBased_In', 'Russian Statistics Committee', 'Russia']]}
# ===============================================
# 818
# {'tokens': ['Historic', 'Movie', 'House', 'May', 'Close', ':', 'The', 'Texas', 'Theater', ',', 'the', 'Dallas', 'movie', 'house', 'where', 'Lee', 'Harvey', 'Oswald', 'was', 'arrested', 'after', 'the', 'assassination', 'of', 'President', 'John', 'F.', 'Kennedy', ',', 'may', 'be', 'closing', 'soon', '.'], 'entities': [[7, 9, 'Loc', 'Texas Theater'], [11, 12, 'Loc', 'Dallas'], [15, 18, 'Peop', 'Lee Harvey Oswald'], [25, 28, 'Peop', 'John F. Kennedy']], 'relations': [[15, 18, 25, 28, 'Kill', 'Lee Harvey Oswald', 'John F. Kennedy']], 'entity_gts': [[0, 4, 'Other', 'Historic Movie House May'], [7, 9, 'Loc', 'Texas Theater'], [11, 12, 'Loc', 'Dallas'], [15, 18, 'Peop', 'Lee Harvey Oswald'], [24, 28, 'Peop', 'President John F. Kennedy']], 'relation_gts': [[15, 18, 24, 28, 'Kill', 'Lee Harvey Oswald', 'President John F. Kennedy']]}
# ===============================================
# 819
# {'tokens': ['In', 'Washington', ',', 'U.S.', 'strategists', 'upgraded', 'the', 'missile', 'threat', 'from', 'Pyongyang', 'from', 'potential', 'to', 'real', 'and', 'decided', 'that', 'the', 'communist', 'country', 'required', 'high-level', 'attention', '.'], 'entities': [[1, 2, 'Loc', 'Washington'], [3, 4, 'Loc', 'U.S.'], [10, 11, 'Loc', 'Pyongyang']], 'relations': [[1, 2, 3, 4, 'Located_In', 'Washington', 'U.S.']], 'entity_gts': [[1, 2, 'Loc', 'Washington'], [3, 4, 'Loc', 'U.S.'], [10, 11, 'Loc', 'Pyongyang'], [19, 20, 'Org', 'communist']], 'relation_gts': [[1, 2, 3, 4, 'Located_In', 'Washington', 'U.S.']]}
# ===============================================
# 820
# {'tokens': ['LD0706183794', 'Riga', 'Radio', 'Riga', 'Network', 'in', 'Latvian', '1700', 'GMT', '7', 'Jun', '94'], 'entities': [[1, 2, 'Loc', 'Riga'], [2, 3, 'Org', 'Radio'], [3, 5, 'Loc', 'Riga Network'], [7, 9, 'Other', '1700 GMT'], [9, 12, 'Other', '7 Jun 94']], 'relations': [[2, 3, 1, 2, 'OrgBased_In', 'Radio', 'Riga'], [3, 5, 1, 2, 'OrgBased_In', 'Riga Network', 'Riga']], 'entity_gts': [[1, 2, 'Loc', 'Riga'], [2, 5, 'Org', 'Radio Riga Network'], [7, 9, 'Other', '1700 GMT'], [9, 12, 'Other', '7 Jun 94']], 'relation_gts': [[2, 5, 1, 2, 'OrgBased_In', 'Radio Riga Network', 'Riga']]}
# ===============================================
# 821
# {'tokens': ['Lehi', ',', 'also', 'known', 'as', 'the', 'Stern', 'Gang', ',', 'assassinated', 'the', 'British', 'colonial', 'minister', ',', 'Lord', 'Moyne', ',', 'and', 'the', 'Swedish', 'U.N.', 'mediator', ',', 'Count', 'Folke', 'Bernadotte.', ';'], 'entities': [[6, 7, 'Other', 'Stern'], [15, 17, 'Peop', 'Lord Moyne'], [20, 21, 'Loc', 'Swedish'], [21, 22, 'Org', 'U.N.'], [25, 27, 'Peop', 'Folke Bernadotte.']], 'relations': [[25, 27, 21, 22, 'Work_For', 'Folke Bernadotte.', 'U.N.'], [15, 17, 21, 22, 'Work_For', 'Lord Moyne', 'U.N.']], 'entity_gts': [[0, 1, 'Peop', 'Lehi'], [6, 8, 'Peop', 'Stern Gang'], [15, 17, 'Peop', 'Lord Moyne'], [21, 22, 'Org', 'U.N.'], [25, 27, 'Peop', 'Folke Bernadotte.']], 'relation_gts': [[0, 1, 15, 17, 'Kill', 'Lehi', 'Lord Moyne'], [0, 1, 25, 27, 'Kill', 'Lehi', 'Folke Bernadotte.'], [6, 8, 15, 17, 'Kill', 'Stern Gang', 'Lord Moyne'], [6, 8, 25, 27, 'Kill', 'Stern Gang', 'Folke Bernadotte.']]}
# ===============================================
# 822
# {'tokens': ['of', 'Shinseito', '(', 'Japan', 'Renewal', 'Party', ')', ',', 'by', 'Takeshi', 'Sasaki', ',', 'Tokyo', 'University', 'professor', ',', 'on', '13', 'February', ',', 'moderated', 'by', 'Shoichi', 'Oikawa', ',', 'YOMIURI', 'SHIMBUN', 'political', 'editor', ';', 'place', 'not', 'given', ';', 'first', 'paragraph', 'is', 'YOMIURI', 'SHIMBUN', 'introduction', ')', '(', 'Excerpts', ')', 'After', 'the', 'passage', 'of', 'the', 'political', 'reform', 'laws', ',', 'as', 'vigorous', 'moves', 'toward', 'the', 'realignment', 'of', 'the', 'political', 'world', 'become', 'apparent', ',', 'YOMIURI', 'SHIMBUN', 'invited', 'Ichiro', 'Ozawa', ',', 'secretary', 'of', 'Shinseito', ',', 'on', '13', 'February', 'to', 'talk', 'for', 'about', 'two', 'hours', 'on', 'the', 'possible', 'course', 'of', 'political', 'realignment', ',', 'foreign', 'policy', 'and', 'security', ',', 'international', 'contribution', ',', 'and', 'his', 'assessment', 'of', 'postwar', 'politics', '.'], 'entities': [[1, 2, 'Org', 'Shinseito'], [3, 6, 'Loc', 'Japan Renewal Party'], [9, 11, 'Peop', 'Takeshi Sasaki'], [12, 14, 'Loc', 'Tokyo University'], [22, 24, 'Peop', 'Shoichi Oikawa'], [25, 27, 'Org', 'YOMIURI SHIMBUN'], [37, 39, 'Org', 'YOMIURI SHIMBUN'], [66, 68, 'Org', 'YOMIURI SHIMBUN'], [69, 71, 'Peop', 'Ichiro Ozawa'], [74, 75, 'Loc', 'Shinseito'], [77, 78, 'Other', '13'], [78, 79, 'Other', 'February']], 'relations': [[69, 71, 66, 68, 'Work_For', 'Ichiro Ozawa', 'YOMIURI SHIMBUN'], [22, 24, 25, 27, 'Work_For', 'Shoichi Oikawa', 'YOMIURI SHIMBUN'], [69, 71, 74, 75, 'Live_In', 'Ichiro Ozawa', 'Shinseito'], [9, 11, 12, 14, 'Work_For', 'Takeshi Sasaki', 'Tokyo University']], 'entity_gts': [[1, 2, 'Org', 'Shinseito'], [3, 6, 'Org', 'Japan Renewal Party'], [9, 11, 'Peop', 'Takeshi Sasaki'], [12, 14, 'Org', 'Tokyo University'], [17, 19, 'Other', '13 February'], [22, 24, 'Peop', 'Shoichi Oikawa'], [25, 27, 'Org', 'YOMIURI SHIMBUN'], [37, 39, 'Org', 'YOMIURI SHIMBUN'], [66, 68, 'Org', 'YOMIURI SHIMBUN'], [69, 71, 'Peop', 'Ichiro Ozawa'], [74, 75, 'Org', 'Shinseito'], [77, 79, 'Other', '13 February']], 'relation_gts': [[9, 11, 12, 14, 'Work_For', 'Takeshi Sasaki', 'Tokyo University'], [22, 24, 25, 27, 'Work_For', 'Shoichi Oikawa', 'YOMIURI SHIMBUN'], [22, 24, 37, 39, 'Work_For', 'Shoichi Oikawa', 'YOMIURI SHIMBUN'], [22, 24, 66, 68, 'Work_For', 'Shoichi Oikawa', 'YOMIURI SHIMBUN'], [69, 71, 1, 2, 'Work_For', 'Ichiro Ozawa', 'Shinseito'], [69, 71, 74, 75, 'Work_For', 'Ichiro Ozawa', 'Shinseito']]}
# ===============================================
# 823
# {'tokens': ['In', '1822', ',', 'the', '18th', 'president', 'of', 'the', 'United', 'States', ',', 'Ulysses', 'S.', 'Grant', ',', 'was', 'born', 'in', 'Point', 'Pleasant', ',', 'Ohio', '.'], 'entities': [[8, 10, 'Loc', 'United States'], [11, 14, 'Peop', 'Ulysses S. Grant'], [18, 22, 'Loc', 'Point Pleasant , Ohio']], 'relations': [[11, 14, 18, 22, 'Live_In', 'Ulysses S. Grant', 'Point Pleasant , Ohio']], 'entity_gts': [[8, 10, 'Loc', 'United States'], [11, 14, 'Peop', 'Ulysses S. Grant'], [18, 22, 'Loc', 'Point Pleasant , Ohio']], 'relation_gts': [[11, 14, 18, 22, 'Live_In', 'Ulysses S. Grant', 'Point Pleasant , Ohio']]}
# ===============================================
# 824
# {'tokens': ['Wang', 'Shaohua', ',', 'an', 'official', 'with', 'China', "'s", 'consulate', 'in', 'San', 'Francisco', ',', 'said', 'those', 'who', 'fled', '`', '`', 'were', 'instigated', 'by', 'people', 'with', 'motives', 'to', 'bring', 'damage', 'to', 'China.', "'", "'"], 'entities': [[0, 2, 'Peop', 'Wang Shaohua'], [6, 7, 'Loc', 'China'], [10, 12, 'Loc', 'San Francisco'], [29, 30, 'Loc', 'China.']], 'relations': [[0, 2, 6, 7, 'Live_In', 'Wang Shaohua', 'China']], 'entity_gts': [[0, 2, 'Peop', 'Wang Shaohua'], [6, 7, 'Loc', 'China'], [10, 12, 'Loc', 'San Francisco'], [29, 30, 'Loc', 'China.']], 'relation_gts': [[0, 2, 10, 12, 'Live_In', 'Wang Shaohua', 'San Francisco']]}
# ===============================================
# 825
# {'tokens': ['Her', 'husband', "'s", 'assassin', ',', 'Mark', 'David', 'Chapman', ',', 'said', 'he', 'had', 'decided', 'to', 'kill', 'John', 'Lennon', 'in', '1980', 'after', 'reading', 'an', 'article', 'about', 'the', 'former', 'Beatle', 'in', 'a', 'magazine', ',', 'Ono', 'said', '.'], 'entities': [[5, 8, 'Peop', 'Mark David Chapman'], [15, 17, 'Peop', 'John Lennon'], [31, 32, 'Peop', 'Ono']], 'relations': [[5, 8, 15, 17, 'Kill', 'Mark David Chapman', 'John Lennon']], 'entity_gts': [[5, 8, 'Peop', 'Mark David Chapman'], [15, 17, 'Peop', 'John Lennon'], [26, 27, 'Other', 'Beatle'], [31, 32, 'Peop', 'Ono']], 'relation_gts': [[5, 8, 15, 17, 'Kill', 'Mark David Chapman', 'John Lennon']]}
# ===============================================
# 826
# {'tokens': ['An-a-one', ',', 'an-a-two', ',', 'an-a-three', 'billion', ')', 'Taxpayers', 'will', 'be', 'pleased', 'to', 'learn', 'that', 'a', 'federal', 'grant', 'for', 'Lawrence', 'Welk', "'s", 'North', 'Dakota', 'birthplace', 'has', 'finally', 'been', 'buried', ',', 'nine', 'months', 'after', 'an', 'embarrassed', 'Congress', 'voted', 'to', 'kill', 'it', '.'], 'entities': [[18, 20, 'Peop', 'Lawrence Welk'], [21, 23, 'Loc', 'North Dakota'], [29, 30, 'Other', 'nine'], [34, 35, 'Org', 'Congress']], 'relations': [[18, 20, 21, 23, 'Live_In', 'Lawrence Welk', 'North Dakota']], 'entity_gts': [[0, 1, 'Other', 'An-a-one'], [18, 20, 'Peop', 'Lawrence Welk'], [21, 23, 'Loc', 'North Dakota'], [34, 35, 'Org', 'Congress']], 'relation_gts': [[18, 20, 21, 23, 'Live_In', 'Lawrence Welk', 'North Dakota']]}
# ===============================================
# 827
# {'tokens': ['(', 'Text', ')', 'Following', 'the', 'conclusion', 'of', 'the', 'Geneva', 'negotiations', 'today', ',', 'Ejup', 'Ganic', ',', 'head', 'of', 'the', 'Bosnia-Herzegovina', 'delegation', 'and', 'vice', 'of', 'the', 'Federation', 'of', 'Bosnia-Herzegovina', ',', 'made', 'the', 'following', 'statement', 'for', 'Bosnia-Herzegovina', 'Radio', 'and', 'TV', ':', '(', 'Begin', 'Ganic', 'recording', ')', 'The', 'delegation', 'acted', 'in', 'accordance', 'with', 'the', 'Assembly', 'guidelines', '.'], 'entities': [[8, 9, 'Loc', 'Geneva'], [18, 19, 'Loc', 'Bosnia-Herzegovina'], [33, 34, 'Loc', 'Bosnia-Herzegovina'], [34, 35, 'Org', 'Radio']], 'relations': [], 'entity_gts': [[8, 9, 'Loc', 'Geneva'], [12, 14, 'Peop', 'Ejup Ganic'], [24, 27, 'Loc', 'Federation of Bosnia-Herzegovina'], [33, 37, 'Org', 'Bosnia-Herzegovina Radio and TV']], 'relation_gts': [[12, 14, 24, 27, 'Live_In', 'Ejup Ganic', 'Federation of Bosnia-Herzegovina'], [33, 37, 24, 27, 'OrgBased_In', 'Bosnia-Herzegovina Radio and TV', 'Federation of Bosnia-Herzegovina']]}
# ===============================================
# 828
# {'tokens': ['Eaglebrook', 'East', 'opened', 'in', 'Middletown', 'in', 'April', '.'], 'entities': [[0, 2, 'Org', 'Eaglebrook East'], [4, 5, 'Loc', 'Middletown'], [6, 7, 'Other', 'April']], 'relations': [[0, 2, 4, 5, 'Located_In', 'Eaglebrook East', 'Middletown']], 'entity_gts': [[0, 2, 'Org', 'Eaglebrook East'], [4, 5, 'Loc', 'Middletown']], 'relation_gts': [[0, 2, 4, 5, 'OrgBased_In', 'Eaglebrook East', 'Middletown']]}
# ===============================================
# 829
# {'tokens': ['Scattered', 'among', 'reams', 'of', 'FBI', 'and', 'Secret', 'Service', 'reports', 'are', 'fragments', 'of', 'the', 'lonely', 'life', 'of', 'Oswald', ',', 'a', 'Marxist', 'who', 'lived', 'in', 'obscurity', 'and', 'died', 'in', 'infamy', 'and', 'who', 'the', 'Warren', 'Commission', 'concluded', 'was', 'acting', 'alone', 'when', 'he', 'killed', 'Kennedy', '.'], 'entities': [[4, 5, 'Org', 'FBI'], [16, 17, 'Peop', 'Oswald'], [31, 33, 'Org', 'Warren Commission'], [40, 41, 'Peop', 'Kennedy']], 'relations': [[16, 17, 40, 41, 'Kill', 'Oswald', 'Kennedy']], 'entity_gts': [[4, 5, 'Org', 'FBI'], [6, 8, 'Org', 'Secret Service'], [16, 17, 'Peop', 'Oswald'], [31, 33, 'Org', 'Warren Commission'], [40, 41, 'Peop', 'Kennedy']], 'relation_gts': [[16, 17, 40, 41, 'Kill', 'Oswald', 'Kennedy']]}
# ===============================================

# %% [markdown]
# ## Hypothesis 1: increase number of training points also increase the number of atoms per sentences

# %%
with open('../datasets/conll04_10/folds/10/labeled.json', 'r') as f:
    data_labeled = json.load(f)
with open('../datasets/conll04_10/folds/10/unlabeled.json', 'r') as f:
    data_unlabeled = json.load(f)

# %%
len(data_unlabeled)
# Out:
# 830

# %%
indicies = list(range(830))
random.shuffle(indicies)

# %%
part1 = []
part2 = []
for i in indicies[:len(data_unlabeled) // 10]:
    part1.append(data_unlabeled[i])
    
for i in indicies[len(data_unlabeled) // 10 + 1:2 * len(data_unlabeled) // 10]:
    part2.append(data_unlabeled[i])

# %% [markdown]
# ## Hypothesis 2: model can predict the number of non-empty entries pretty well with less data
